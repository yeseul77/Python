# %%
import pandas as pd
import my_utils as mu

# %%
df = mu.get_rawdata('GOLD')
# Out:
# get summonerId....
# 100%|██████████| 4/4 [00:02<00:00,  1.59it/s]
# get puuId.....
# 100%|██████████| 12/12 [00:06<00:00,  1.93it/s]
# get match_id....
# 100%|██████████| 12/12 [00:07<00:00,  1.70it/s]
# get matches & timeline....
# 100%|██████████| 36/36 [00:49<00:00,  1.37s/it]

# %%
df.iloc[0].matches['info']['participants'][2]['kills']
# Out:
# 14

# %% [markdown]
# ## 티어는 상관없이 로우데이터를 통해서 원하는 데이터를 뽑아내기
#
# ## 팀끼리 롤데이터를 가지고 3가지의 흥미로운 주제를 만들기
# # (지금은 기획만)
# ## 두가지는 그래프를 사용해서 뽑아내기 (미니프로젝트 대비)
#
# ## 데이터를 팀끼리 미리 정하고, insert

# %% [markdown]
# # matchId, gameDuration, gameVersion, riotIdGameName,riotIdTagline, summonerLevel, participantId, championName, champExperience, teamPosition, teamId, win, kills, deaths, assists, totalDamageDealtToChampions, totalDamageTaken

# %%
df.iloc[0].match_id
# Out:
# 'KR_6817651119'

# %%
df.iloc[0].matches['info']['gameDuration']
# Out:
# 1278

# %%
df.iloc[0].matches['info']['participants'][0]['item0']
# Out:
# 6672

# %%
df
# Out:
#          match_id                                            matches  \
# 0   KR_6851524682  {'metadata': {'dataVersion': '2', 'matchId': '...
# 1   KR_6851451412  {'metadata': {'dataVersion': '2', 'matchId': '...
# 2   KR_6851341004  {'metadata': {'dataVersion': '2', 'matchId': '...
# 3   KR_6853023010  {'metadata': {'dataVersion': '2', 'matchId': '...
# 4   KR_6852954512  {'metadata': {'dataVersion': '2', 'matchId': '...
# 5   KR_6843739249  {'metadata': {'dataVersion': '2', 'matchId': '...
# 6   KR_6829342771  {'metadata': {'dataVersion': '2', 'matchId': '...
# 7   KR_6818110901  {'metadata': {'dataVersion': '2', 'matchId': '...
# 8   KR_6816314539  {'metadata': {'dataVersion': '2', 'matchId': '...
# 9   KR_6854759098  {'metadata': {'dataVersion': '2', 'matchId': '...
# 10  KR_6854667019  {'metadata': {'dataVersion': '2', 'matchId': '...
# 11  KR_6832861198  {'metadata': {'dataVersion': '2', 'matchId': '...
# 12  KR_6769422558  {'metadata': {'dataVersion': '2', 'matchId': '...
# 13  KR_6769380635  {'metadata': {'dataVersion': '2', 'matchId': '...
# 14  KR_6769351157  {'metadata': {'dataVersion': '2', 'matchId': '...
# 15  KR_6860845107  {'metadata': {'dataVersion': '2', 'matchId': '...
# 16  KR_6860831207  {'metadata': {'dataVersion': '2', 'matchId': '...
# 17  KR_6860821375  {'metadata': {'dataVersion': '2', 'matchId': '...
# 18  KR_6853661559  {'metadata': {'dataVersion': '2', 'matchId': '...
# 19  KR_6853563448  {'metadata': {'dataVersion': '2', 'matchId': '...
# 20  KR_6853445416  {'metadata': {'dataVersion': '2', 'matchId': '...
# 21  KR_6859085966  {'metadata': {'dataVersion': '2', 'matchId': '...
# 22  KR_6851605857  {'metadata': {'dataVersion': '2', 'matchId': '...
# 23  KR_6851577730  {'metadata': {'dataVersion': '2', 'matchId': '...
# 24  KR_6834545075  {'metadata': {'dataVersion': '2', 'matchId': '...
# 25  KR_6834395046  {'metadata': {'dataVersion': '2', 'matchId': '...
# 26  KR_6775666663  {'status': {'message': 'Rate limit exceeded', ...
# 27  KR_6803863197  {'status': {'message': 'Rate limit exceeded', ...
# 28  KR_6803776472  {'status': {'message': 'Rate limit exceeded', ...
# 29  KR_6803690441  {'status': {'message': 'Rate limit exceeded', ...
# 30  KR_6860352835  {'status': {'message': 'Rate limit exceeded', ...
# 31  KR_6860290852  {'status': {'message': 'Rate limit exceeded', ...
# 32  KR_6860227251  {'status': {'message': 'Rate limit exceeded', ...
# 33  KR_6858642353  {'status': {'message': 'Rate limit exceeded', ...
# 34  KR_6832665554  {'status': {'message': 'Rate limit exceeded', ...
# 35  KR_6832626555  {'status': {'message': 'Rate limit exceeded', ...
#
#                                             timelines
# 0   {'metadata': {'dataVersion': '2', 'matchId': '...
# 1   {'metadata': {'dataVersion': '2', 'matchId': '...
# 2   {'metadata': {'dataVersion': '2', 'matchId': '...
# 3   {'metadata': {'dataVersion': '2', 'matchId': '...
# 4   {'metadata': {'dataVersion': '2', 'matchId': '...
# 5   {'metadata': {'dataVersion': '2', 'matchId': '...
# 6   {'metadata': {'dataVersion': '2', 'matchId': '...
# 7   {'metadata': {'dataVersion': '2', 'matchId': '...
# 8   {'metadata': {'dataVersion': '2', 'matchId': '...
# 9   {'metadata': {'dataVersion': '2', 'matchId': '...
# 10  {'metadata': {'dataVersion': '2', 'matchId': '...
# 11  {'metadata': {'dataVersion': '2', 'matchId': '...
# 12  {'metadata': {'dataVersion': '2', 'matchId': '...
# 13  {'metadata': {'dataVersion': '2', 'matchId': '...
# 14  {'metadata': {'dataVersion': '2', 'matchId': '...
# 15  {'metadata': {'dataVersion': '2', 'matchId': '...
# 16  {'metadata': {'dataVersion': '2', 'matchId': '...
# 17  {'metadata': {'dataVersion': '2', 'matchId': '...
# 18  {'metadata': {'dataVersion': '2', 'matchId': '...
# 19  {'metadata': {'dataVersion': '2', 'matchId': '...
# 20  {'metadata': {'dataVersion': '2', 'matchId': '...
# 21  {'metadata': {'dataVersion': '2', 'matchId': '...
# 22  {'metadata': {'dataVersion': '2', 'matchId': '...
# 23  {'metadata': {'dataVersion': '2', 'matchId': '...
# 24  {'metadata': {'dataVersion': '2', 'matchId': '...
# 25  {'metadata': {'dataVersion': '2', 'matchId': '...
# 26  {'status': {'message': 'Rate limit exceeded', ...
# 27  {'status': {'message': 'Rate limit exceeded', ...
# 28  {'status': {'message': 'Rate limit exceeded', ...
# 29  {'status': {'message': 'Rate limit exceeded', ...
# 30  {'status': {'message': 'Rate limit exceeded', ...
# 31  {'status': {'message': 'Rate limit exceeded', ...
# 32  {'status': {'message': 'Rate limit exceeded', ...
# 33  {'status': {'message': 'Rate limit exceeded', ...
# 34  {'status': {'message': 'Rate limit exceeded', ...
# 35  {'status': {'message': 'Rate limit exceeded', ...

# %% [markdown]
# # raw_data를 바탕으로 한 소환사당 한 컬럼을 차지하는 데이터프레임을 만들어주세요

# %%
df_creates = []
for i in range(len(df)):
    match = df.iloc[i].matches['info']['participants']
    for j in range(len(match)):
        match_id = df.iloc[i].match_id
        game_duration = df.iloc[i].matches['info']['gameDuration']
        game_version = df.iloc[i].matches['info']['gameVersion']
        try:
            riotIdGameName = match[j]['riotIdGameName']
        except:
            riotIdGameName = ''
        try:
            riotIdTagline = match[j]['riotIdTagline']
        except:
            riotIdTagline = ''
        summoner_level = match[j]['summonerLevel']
        participants_id = match[j]['participantId']
        champion_name = match[j]['championName']
        champ_experience = match[j]['champExperience']
        team_position = match[j]['teamPosition']
        team_id = match[j]['teamId']
        win = match[j]['win']
        kills = match[j]['kills']
        deaths = match[j]['deaths']
        assists = match[j]['assists']
        total_damage_dealt = match[j]['totalDamageDealtToChampions']
        total_damage_taken = match[j]['totalDamageTaken']
        df_creates.append([match_id,game_duration,game_version,riotIdGameName,riotIdTagline,summoner_level,participants_id,
                          champion_name,champ_experience,team_position,team_id,win,kills,deaths,assists,total_damage_dealt,total_damage_taken])
columns =['matchId', 'gameDuration', 'gameVersion', 'riotIdGameName','riotIdTagline', 
           'summonerLevel', 'participantId', 'championName', 'champExperience', 
           'teamPosition', 'teamId', 'win', 'kills', 'deaths', 'assists', 'totalDamageDealtToChampions', 'totalDamageTaken']
df2 = pd.DataFrame(df_creates , columns = columns)

# %%
match[j]
# Out:
# {'allInPings': 0,
#  'assistMePings': 0,
#  'assists': 14,
#  'baitPings': 0,
#  'baronKills': 0,
#  'basicPings': 0,
#  'bountyLevel': 0,
#  'challenges': {'12AssistStreakCount': 0,
#   'abilityUses': 230,
#   'acesBefore15Minutes': 2,
#   'alliedJungleMonsterKills': 0,
#   'baronTakedowns': 0,
#   'blastConeOppositeOpponentCount': 0,
#   'bountyGold': 900,
#   'buffsStolen': 0,
#   'completeSupportQuestInTime': 0,
#   'controlWardsPlaced': 0,
#   'damagePerMinute': 1157.8695984458288,
#   'damageTakenOnTeamPercentage': 0.1795998404272442,
#   'dancedWithRiftHerald': 0,
#   'deathsByEnemyChamps': 11,
#   'dodgeSkillShotsSmallWindow': 0,
#   'doubleAces': 0,
#   'dragonTakedowns': 0,
#   'effectiveHealAndShielding': 0,
#   'elderDragonKillsWithOpposingSoul': 0,
#   'elderDragonMultikills': 0,
#   'enemyChampionImmobilizations': 37,
#   'enemyJungleMonsterKills': 0,
#   'epicMonsterKillsNearEnemyJungler': 0,
#   'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#   'epicMonsterSteals': 0,
#   'epicMonsterStolenWithoutSmite': 0,
#   'firstTurretKilled': 1,
#   'firstTurretKilledTime': 555.5397561,
#   'flawlessAces': 2,
#   'fullTeamTakedown': 5,
#   'gameLength': 1278.1046818,
#   'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#   'goldPerMinute': 708.2313534122522,
#   'hadOpenNexus': 0,
#   'immobilizeAndKillWithAlly': 12,
#   'initialBuffCount': 0,
#   'initialCrabCount': 0,
#   'jungleCsBefore10Minutes': 0,
#   'junglerTakedownsNearDamagedEpicMonster': 0,
#   'kTurretsDestroyedBeforePlatesFall': 2,
#   'kda': 2.0833333333333335,
#   'killAfterHiddenWithAlly': 10,
#   'killParticipation': 0.5952380952380952,
#   'killedChampTookFullTeamDamageSurvived': 0,
#   'killingSprees': 2,
#   'killsNearEnemyTurret': 0,
#   'killsOnOtherLanesEarlyJungleAsLaner': 0,
#   'killsOnRecentlyHealedByAramPack': 0,
#   'killsUnderOwnTurret': 4,
#   'killsWithHelpFromEpicMonster': 0,
#   'knockEnemyIntoTeamAndKill': 0,
#   'landSkillShotsEarlyGame': 9,
#   'laneMinionsFirst10Minutes': 38,
#   'legendaryCount': 0,
#   'lostAnInhibitor': 0,
#   'maxKillDeficit': 0,
#   'mejaisFullStackInTime': 0,
#   'moreEnemyJungleThanOpponent': 0,
#   'multiKillOneSpell': 0,
#   'multiTurretRiftHeraldCount': 0,
#   'multikills': 4,
#   'multikillsAfterAggressiveFlash': 2,
#   'mythicItemUsed': 3031,
#   'outerTurretExecutesBefore10Minutes': 0,
#   'outnumberedKills': 3,
#   'outnumberedNexusKill': 0,
#   'perfectDragonSoulsTaken': 0,
#   'perfectGame': 0,
#   'pickKillWithAlly': 17,
#   'poroExplosions': 0,
#   'quickCleanse': 0,
#   'quickFirstTurret': 1,
#   'quickSoloKills': 0,
#   'riftHeraldTakedowns': 0,
#   'saveAllyFromDeath': 0,
#   'scuttleCrabKills': 0,
#   'shortestTimeToAceFromFirstTakedown': 8.026302200000032,
#   'skillshotsDodged': 15,
#   'skillshotsHit': 21,
#   'snowballsHit': 9,
#   'soloBaronKills': 0,
#   'soloKills': 1,
#   'stealthWardsPlaced': 0,
#   'survivedSingleDigitHpCount': 0,
#   'survivedThreeImmobilizesInFight': 0,
#   'takedownOnFirstTurret': 0,
#   'takedowns': 25,
#   'takedownsAfterGainingLevelAdvantage': 0,
#   'takedownsBeforeJungleMinionSpawn': 0,
#   'takedownsFirstXMinutes': 21,
#   'takedownsInAlcove': 0,
#   'takedownsInEnemyFountain': 0,
#   'teamBaronKills': 0,
#   'teamDamagePercentage': 0.2049339270981659,
#   'teamElderDragonKills': 0,
#   'teamRiftHeraldKills': 0,
#   'tookLargeDamageSurvived': 0,
#   'turretPlatesTaken': 0,
#   'turretTakedowns': 2,
#   'turretsTakenWithRiftHerald': 0,
#   'twentyMinionsIn3SecondsCount': 0,
#   'twoWardsOneSweeperCount': 0,
#   'unseenRecalls': 0,
#   'visionScorePerMinute': 0,
#   'wardTakedowns': 0,
#   'wardTakedownsBefore20M': 0,
#   'wardsGuarded': 0},
#  'champExperience': 17301,
#  'champLevel': 17,
#  'championId': 157,
#  'championName': 'Yasuo',
#  'championTransform': 0,
#  'commandPings': 8,
#  'consumablesPurchased': 2,
#  'damageDealtToBuildings': 2502,
#  'damageDealtToObjectives': 2502,
#  'damageDealtToTurrets': 2502,
#  'damageSelfMitigated': 38323,
#  'dangerPings': 0,
#  'deaths': 12,
#  'detectorWardsPlaced': 0,
#  'doubleKills': 2,
#  'dragonKills': 0,
#  'eligibleForProgression': True,
#  'enemyMissingPings': 0,
#  'enemyVisionPings': 0,
#  'firstBloodAssist': False,
#  'firstBloodKill': False,
#  'firstTowerAssist': True,
#  'firstTowerKill': False,
#  'gameEndedInEarlySurrender': False,
#  'gameEndedInSurrender': False,
#  'getBackPings': 1,
#  'goldEarned': 15086,
#  'goldSpent': 14900,
#  'holdPings': 0,
#  'individualPosition': 'Invalid',
#  'inhibitorKills': 1,
#  'inhibitorTakedowns': 1,
#  'inhibitorsLost': 2,
#  'item0': 6672,
#  'item1': 3006,
#  'item2': 6333,
#  'item3': 3031,
#  'item4': 3156,
#  'item5': 1053,
#  'item6': 0,
#  'itemsPurchased': 19,
#  'killingSprees': 2,
#  'kills': 11,
#  'lane': 'TOP',
#  'largestCriticalStrike': 746,
#  'largestKillingSpree': 4,
#  'largestMultiKill': 4,
#  'longestTimeSpentLiving': 136,
#  'magicDamageDealt': 5078,
#  'magicDamageDealtToChampions': 830,
#  'magicDamageTaken': 10062,
#  'missions': {'playerScore0': 0,
#   'playerScore1': 0,
#   'playerScore10': 0,
#   'playerScore11': 0,
#   'playerScore2': 0,
#   'playerScore3': 0,
#   'playerScore4': 0,
#   'playerScore5': 0,
#   'playerScore6': 0,
#   'playerScore7': 0,
#   'playerScore8': 0,
#   'playerScore9': 0},
#  'needVisionPings': 0,
#  'neutralMinionsKilled': 0,
#  'nexusKills': 0,
#  'nexusLost': 1,
#  'nexusTakedowns': 0,
#  'objectivesStolen': 0,
#  'objectivesStolenAssists': 0,
#  'onMyWayPings': 1,
#  'participantId': 1,
#  'pentaKills': 0,
#  'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#   'styles': [{'description': 'primaryStyle',
#     'selections': [{'perk': 8008, 'var1': 23, 'var2': 1, 'var3': 0},
#      {'perk': 9111, 'var1': 1001, 'var2': 250, 'var3': 0},
#      {'perk': 9104, 'var1': 7, 'var2': 0, 'var3': 0},
#      {'perk': 8014, 'var1': 908, 'var2': 0, 'var3': 0}],
#     'style': 8000},
#    {'description': 'subStyle',
#     'selections': [{'perk': 8139, 'var1': 815, 'var2': 0, 'var3': 0},
#      {'perk': 8134, 'var1': 4, 'var2': 5, 'var3': 0}],
#     'style': 8100}]},
#  'physicalDamageDealt': 77126,
#  'physicalDamageDealtToChampions': 22729,
#  'physicalDamageTaken': 12974,
#  'placement': 0,
#  'playerAugment1': 0,
#  'playerAugment2': 0,
#  'playerAugment3': 0,
#  'playerAugment4': 0,
#  'playerScore0': 0,
#  'playerScore1': 0,
#  'playerScore10': 0,
#  'playerScore11': 0,
#  'playerScore2': 0,
#  'playerScore3': 0,
#  'playerScore4': 0,
#  'playerScore5': 0,
#  'playerScore6': 0,
#  'playerScore7': 0,
#  'playerScore8': 0,
#  'playerScore9': 0,
#  'playerSubteamId': 0,
#  'profileIcon': 5410,
#  'pushPings': 0,
#  'puuid': 'bjJDDKsW5VHeRhyJBXWUGpdGAilokAL9ejp63Epj-ihXTyUCBctLsf0Ly_84aAqTdhW-k8lDfwjKjg',
#  'quadraKills': 1,
#  'riotIdGameName': '무악동불지옥',
#  'riotIdTagline': 'KR1',
#  'role': 'SUPPORT',
#  'sightWardsBoughtInGame': 0,
#  'spell1Casts': 151,
#  'spell2Casts': 17,
#  'spell3Casts': 55,
#  'spell4Casts': 7,
#  'subteamPlacement': 0,
#  'summoner1Casts': 17,
#  'summoner1Id': 32,
#  'summoner2Casts': 4,
#  'summoner2Id': 4,
#  'summonerId': 'DSAJu7ujwROCeqC6l52f1um-ZCn6CZwtgMXTEBgY7S4B5hQ',
#  'summonerLevel': 298,
#  'summonerName': '무악동불지옥',
#  'teamEarlySurrendered': False,
#  'teamId': 100,
#  'teamPosition': '',
#  'timeCCingOthers': 34,
#  'timePlayed': 1278,
#  'totalAllyJungleMinionsKilled': 0,
#  'totalDamageDealt': 83309,
#  'totalDamageDealtToChampions': 24664,
#  'totalDamageShieldedOnTeammates': 0,
#  'totalDamageTaken': 26915,
#  'totalEnemyJungleMinionsKilled': 0,
#  'totalHeal': 2476,
#  'totalHealsOnTeammates': 0,
#  'totalMinionsKilled': 74,
#  'totalTimeCCDealt': 114,
#  'totalTimeSpentDead': 286,
#  'totalUnitsHealed': 1,
#  'tripleKills': 1,
#  'trueDamageDealt': 1104,
#  'trueDamageDealtToChampions': 1104,
#  'trueDamageTaken': 3878,
#  'turretKills': 0,
#  'turretTakedowns': 2,
#  'turretsLost': 4,
#  'unrealKills': 0,
#  'visionClearedPings': 0,
#  'visionScore': 0,
#  'visionWardsBoughtInGame': 0,
#  'wardsKilled': 0,
#  'wardsPlaced': 0,
#  'win': False}

# %%
df2
# Out:
#            matchId  gameDuration     gameVersion riotIdGameName riotIdTagline  \
# 0    KR_6817651119          1278  13.23.544.5515         무악동불지옥           KR1
# 1    KR_6817651119          1278  13.23.544.5515          탑1452           KR1
# 2    KR_6817651119          1278  13.23.544.5515        Dante J           KR1
# 3    KR_6817651119          1278  13.23.544.5515            알민강           KR1
# 4    KR_6817651119          1278  13.23.544.5515           고담시티           KR1
# ..             ...           ...             ...            ...           ...
# 349  KR_6859088545          1272  13.24.547.9214       도둑고양이성지훈           KR1
# 350  KR_6859088545          1272  13.24.547.9214        멋지다 에스파           KR1
# 351  KR_6859088545          1272  13.24.547.9214          난허선도임           KR1
# 352  KR_6859088545          1272  13.24.547.9214          Lee하루           KR1
# 353  KR_6859088545          1272  13.24.547.9214            이대영          5900
#
#      summonerLevel  participantId championName  champExperience teamPosition  \
# 0              298              1        Yasuo            17301
# 1              476              2          Zac            19000
# 2              550              3     Aphelios            18088
# 3              249              4    Lissandra            19582
# 4              208              5         Lulu            20702
# ..             ...            ...          ...              ...          ...
# 349             91              4       Illaoi            17000
# 350            424              5        Teemo            12546
# 351            144              6        Shaco            12500
# 352            429              7         Ornn            17000
# 353            329              8        Briar            17000
#
#      teamId    win  kills  deaths  assists  totalDamageDealtToChampions  \
# 0       100  False     11      12       14                        24664
# 1       100  False      3      12       25                        18848
# 2       100  False     14      10       14                        39687
# 3       100  False     12      12       20                        29534
# 4       100  False      2       5       31                         7619
# ..      ...    ...    ...     ...      ...                          ...
# 349     100   True      8       9       12                        54749
# 350     200  False      4       7        4                        33018
# 351     200  False      4       7        4                        17967
# 352     100   True      8       5        9                        46420
# 353     100   True      8      13        4                        47126
#
#      totalDamageTaken
# 0               26915
# 1               53985
# 2               25271
# 3               30490
# 4               13199
# ..                ...
# 349             90925
# 350             18172
# 351             14457
# 352             75473
# 353             38180
#
# [354 rows x 17 columns]

# %%
df.iloc[0].matches['info']
# Out:
# {'gameCreation': 1700992337365,
#  'gameDuration': 1278,
#  'gameEndTimestamp': 1700993677442,
#  'gameId': 6817651119,
#  'gameMode': 'ARAM',
#  'gameName': 'teambuilder-match-6817651119',
#  'gameStartTimestamp': 1700992399475,
#  'gameType': 'MATCHED_GAME',
#  'gameVersion': '13.23.544.5515',
#  'mapId': 12,
#  'participants': [{'allInPings': 0,
#    'assistMePings': 0,
#    'assists': 14,
#    'baitPings': 0,
#    'baronKills': 0,
#    'basicPings': 0,
#    'bountyLevel': 0,
#    'challenges': {'12AssistStreakCount': 0,
#     'abilityUses': 230,
#     'acesBefore15Minutes': 2,
#     'alliedJungleMonsterKills': 0,
#     'baronTakedowns': 0,
#     'blastConeOppositeOpponentCount': 0,
#     'bountyGold': 900,
#     'buffsStolen': 0,
#     'completeSupportQuestInTime': 0,
#     'controlWardsPlaced': 0,
#     'damagePerMinute': 1157.8695984458288,
#     'damageTakenOnTeamPercentage': 0.1795998404272442,
#     'dancedWithRiftHerald': 0,
#     'deathsByEnemyChamps': 11,
#     'dodgeSkillShotsSmallWindow': 0,
#     'doubleAces': 0,
#     'dragonTakedowns': 0,
#     'effectiveHealAndShielding': 0,
#     'elderDragonKillsWithOpposingSoul': 0,
#     'elderDragonMultikills': 0,
#     'enemyChampionImmobilizations': 37,
#     'enemyJungleMonsterKills': 0,
#     'epicMonsterKillsNearEnemyJungler': 0,
#     'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#     'epicMonsterSteals': 0,
#     'epicMonsterStolenWithoutSmite': 0,
#     'firstTurretKilled': 1,
#     'firstTurretKilledTime': 555.5397561,
#     'flawlessAces': 2,
#     'fullTeamTakedown': 5,
#     'gameLength': 1278.1046818,
#     'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#     'goldPerMinute': 708.2313534122522,
#     'hadOpenNexus': 0,
#     'immobilizeAndKillWithAlly': 12,
#     'initialBuffCount': 0,
#     'initialCrabCount': 0,
#     'jungleCsBefore10Minutes': 0,
#     'junglerTakedownsNearDamagedEpicMonster': 0,
#     'kTurretsDestroyedBeforePlatesFall': 2,
#     'kda': 2.0833333333333335,
#     'killAfterHiddenWithAlly': 10,
#     'killParticipation': 0.5952380952380952,
#     'killedChampTookFullTeamDamageSurvived': 0,
#     'killingSprees': 2,
#     'killsNearEnemyTurret': 0,
#     'killsOnOtherLanesEarlyJungleAsLaner': 0,
#     'killsOnRecentlyHealedByAramPack': 0,
#     'killsUnderOwnTurret': 4,
#     'killsWithHelpFromEpicMonster': 0,
#     'knockEnemyIntoTeamAndKill': 0,
#     'landSkillShotsEarlyGame': 9,
#     'laneMinionsFirst10Minutes': 38,
#     'legendaryCount': 0,
#     'lostAnInhibitor': 0,
#     'maxKillDeficit': 0,
#     'mejaisFullStackInTime': 0,
#     'moreEnemyJungleThanOpponent': 0,
#     'multiKillOneSpell': 0,
#     'multiTurretRiftHeraldCount': 0,
#     'multikills': 4,
#     'multikillsAfterAggressiveFlash': 2,
#     'mythicItemUsed': 3031,
#     'outerTurretExecutesBefore10Minutes': 0,
#     'outnumberedKills': 3,
#     'outnumberedNexusKill': 0,
#     'perfectDragonSoulsTaken': 0,
#     'perfectGame': 0,
#     'pickKillWithAlly': 17,
#     'poroExplosions': 0,
#     'quickCleanse': 0,
#     'quickFirstTurret': 1,
#     'quickSoloKills': 0,
#     'riftHeraldTakedowns': 0,
#     'saveAllyFromDeath': 0,
#     'scuttleCrabKills': 0,
#     'shortestTimeToAceFromFirstTakedown': 8.026302200000032,
#     'skillshotsDodged': 15,
#     'skillshotsHit': 21,
#     'snowballsHit': 9,
#     'soloBaronKills': 0,
#     'soloKills': 1,
#     'stealthWardsPlaced': 0,
#     'survivedSingleDigitHpCount': 0,
#     'survivedThreeImmobilizesInFight': 0,
#     'takedownOnFirstTurret': 0,
#     'takedowns': 25,
#     'takedownsAfterGainingLevelAdvantage': 0,
#     'takedownsBeforeJungleMinionSpawn': 0,
#     'takedownsFirstXMinutes': 21,
#     'takedownsInAlcove': 0,
#     'takedownsInEnemyFountain': 0,
#     'teamBaronKills': 0,
#     'teamDamagePercentage': 0.2049339270981659,
#     'teamElderDragonKills': 0,
#     'teamRiftHeraldKills': 0,
#     'tookLargeDamageSurvived': 0,
#     'turretPlatesTaken': 0,
#     'turretTakedowns': 2,
#     'turretsTakenWithRiftHerald': 0,
#     'twentyMinionsIn3SecondsCount': 0,
#     'twoWardsOneSweeperCount': 0,
#     'unseenRecalls': 0,
#     'visionScorePerMinute': 0,
#     'wardTakedowns': 0,
#     'wardTakedownsBefore20M': 0,
#     'wardsGuarded': 0},
#    'champExperience': 17301,
#    'champLevel': 17,
#    'championId': 157,
#    'championName': 'Yasuo',
#    'championTransform': 0,
#    'commandPings': 8,
#    'consumablesPurchased': 2,
#    'damageDealtToBuildings': 2502,
#    'damageDealtToObjectives': 2502,
#    'damageDealtToTurrets': 2502,
#    'damageSelfMitigated': 38323,
#    'dangerPings': 0,
#    'deaths': 12,
#    'detectorWardsPlaced': 0,
#    'doubleKills': 2,
#    'dragonKills': 0,
#    'eligibleForProgression': True,
#    'enemyMissingPings': 0,
#    'enemyVisionPings': 0,
#    'firstBloodAssist': False,
#    'firstBloodKill': False,
#    'firstTowerAssist': True,
#    'firstTowerKill': False,
#    'gameEndedInEarlySurrender': False,
#    'gameEndedInSurrender': False,
#    'getBackPings': 1,
#    'goldEarned': 15086,
#    'goldSpent': 14900,
#    'holdPings': 0,
#    'individualPosition': 'Invalid',
#    'inhibitorKills': 1,
#    'inhibitorTakedowns': 1,
#    'inhibitorsLost': 2,
#    'item0': 6672,
#    'item1': 3006,
#    'item2': 6333,
#    'item3': 3031,
#    'item4': 3156,
#    'item5': 1053,
#    'item6': 0,
#    'itemsPurchased': 19,
#    'killingSprees': 2,
#    'kills': 11,
#    'lane': 'TOP',
#    'largestCriticalStrike': 746,
#    'largestKillingSpree': 4,
#    'largestMultiKill': 4,
#    'longestTimeSpentLiving': 136,
#    'magicDamageDealt': 5078,
#    'magicDamageDealtToChampions': 830,
#    'magicDamageTaken': 10062,
#    'missions': {'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore10': 0,
#     'playerScore11': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0},
#    'needVisionPings': 0,
#    'neutralMinionsKilled': 0,
#    'nexusKills': 0,
#    'nexusLost': 1,
#    'nexusTakedowns': 0,
#    'objectivesStolen': 0,
#    'objectivesStolenAssists': 0,
#    'onMyWayPings': 1,
#    'participantId': 1,
#    'pentaKills': 0,
#    'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#     'styles': [{'description': 'primaryStyle',
#       'selections': [{'perk': 8008, 'var1': 23, 'var2': 1, 'var3': 0},
#        {'perk': 9111, 'var1': 1001, 'var2': 250, 'var3': 0},
#        {'perk': 9104, 'var1': 7, 'var2': 0, 'var3': 0},
#        {'perk': 8014, 'var1': 908, 'var2': 0, 'var3': 0}],
#       'style': 8000},
#      {'description': 'subStyle',
#       'selections': [{'perk': 8139, 'var1': 815, 'var2': 0, 'var3': 0},
#        {'perk': 8134, 'var1': 4, 'var2': 5, 'var3': 0}],
#       'style': 8100}]},
#    'physicalDamageDealt': 77126,
#    'physicalDamageDealtToChampions': 22729,
#    'physicalDamageTaken': 12974,
#    'placement': 0,
#    'playerAugment1': 0,
#    'playerAugment2': 0,
#    'playerAugment3': 0,
#    'playerAugment4': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore10': 0,
#    'playerScore11': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'playerSubteamId': 0,
#    'profileIcon': 5410,
#    'pushPings': 0,
#    'puuid': 'bjJDDKsW5VHeRhyJBXWUGpdGAilokAL9ejp63Epj-ihXTyUCBctLsf0Ly_84aAqTdhW-k8lDfwjKjg',
#    'quadraKills': 1,
#    'riotIdGameName': '무악동불지옥',
#    'riotIdTagline': 'KR1',
#    'role': 'SUPPORT',
#    'sightWardsBoughtInGame': 0,
#    'spell1Casts': 151,
#    'spell2Casts': 17,
#    'spell3Casts': 55,
#    'spell4Casts': 7,
#    'subteamPlacement': 0,
#    'summoner1Casts': 17,
#    'summoner1Id': 32,
#    'summoner2Casts': 4,
#    'summoner2Id': 4,
#    'summonerId': 'DSAJu7ujwROCeqC6l52f1um-ZCn6CZwtgMXTEBgY7S4B5hQ',
#    'summonerLevel': 298,
#    'summonerName': '무악동불지옥',
#    'teamEarlySurrendered': False,
#    'teamId': 100,
#    'teamPosition': '',
#    'timeCCingOthers': 34,
#    'timePlayed': 1278,
#    'totalAllyJungleMinionsKilled': 0,
#    'totalDamageDealt': 83309,
#    'totalDamageDealtToChampions': 24664,
#    'totalDamageShieldedOnTeammates': 0,
#    'totalDamageTaken': 26915,
#    'totalEnemyJungleMinionsKilled': 0,
#    'totalHeal': 2476,
#    'totalHealsOnTeammates': 0,
#    'totalMinionsKilled': 74,
#    'totalTimeCCDealt': 114,
#    'totalTimeSpentDead': 286,
#    'totalUnitsHealed': 1,
#    'tripleKills': 1,
#    'trueDamageDealt': 1104,
#    'trueDamageDealtToChampions': 1104,
#    'trueDamageTaken': 3878,
#    'turretKills': 0,
#    'turretTakedowns': 2,
#    'turretsLost': 4,
#    'unrealKills': 0,
#    'visionClearedPings': 0,
#    'visionScore': 0,
#    'visionWardsBoughtInGame': 0,
#    'wardsKilled': 0,
#    'wardsPlaced': 0,
#    'win': False},
#   {'allInPings': 0,
#    'assistMePings': 0,
#    'assists': 25,
#    'baitPings': 0,
#    'baronKills': 0,
#    'basicPings': 0,
#    'bountyLevel': 0,
#    'challenges': {'12AssistStreakCount': 1,
#     'abilityUses': 138,
#     'acesBefore15Minutes': 2,
#     'alliedJungleMonsterKills': 0,
#     'baronTakedowns': 0,
#     'blastConeOppositeOpponentCount': 0,
#     'bountyGold': 150,
#     'buffsStolen': 0,
#     'completeSupportQuestInTime': 0,
#     'controlWardsPlaced': 0,
#     'damagePerMinute': 884.83005014488,
#     'damageTakenOnTeamPercentage': 0.3602299964199088,
#     'dancedWithRiftHerald': 0,
#     'deathsByEnemyChamps': 12,
#     'dodgeSkillShotsSmallWindow': 0,
#     'doubleAces': 0,
#     'dragonTakedowns': 0,
#     'effectiveHealAndShielding': 2817.26708984375,
#     'elderDragonKillsWithOpposingSoul': 0,
#     'elderDragonMultikills': 0,
#     'enemyChampionImmobilizations': 147,
#     'enemyJungleMonsterKills': 0,
#     'epicMonsterKillsNearEnemyJungler': 0,
#     'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#     'epicMonsterSteals': 0,
#     'epicMonsterStolenWithoutSmite': 0,
#     'firstTurretKilled': 1,
#     'firstTurretKilledTime': 555.5397561,
#     'flawlessAces': 2,
#     'fullTeamTakedown': 5,
#     'gameLength': 1278.1046818,
#     'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#     'goldPerMinute': 587.994906575539,
#     'hadOpenNexus': 0,
#     'immobilizeAndKillWithAlly': 22,
#     'initialBuffCount': 0,
#     'initialCrabCount': 0,
#     'jungleCsBefore10Minutes': 0,
#     'junglerTakedownsNearDamagedEpicMonster': 0,
#     'kTurretsDestroyedBeforePlatesFall': 2,
#     'kda': 2.3333333333333335,
#     'killAfterHiddenWithAlly': 6,
#     'killParticipation': 0.6666666666666666,
#     'killedChampTookFullTeamDamageSurvived': 0,
#     'killingSprees': 0,
#     'killsNearEnemyTurret': 0,
#     'killsOnOtherLanesEarlyJungleAsLaner': 0,
#     'killsOnRecentlyHealedByAramPack': 0,
#     'killsUnderOwnTurret': 0,
#     'killsWithHelpFromEpicMonster': 0,
#     'knockEnemyIntoTeamAndKill': 16,
#     'landSkillShotsEarlyGame': 6,
#     'laneMinionsFirst10Minutes': 3,
#     'legendaryCount': 0,
#     'lostAnInhibitor': 0,
#     'maxKillDeficit': 0,
#     'mejaisFullStackInTime': 0,
#     'moreEnemyJungleThanOpponent': 0,
#     'multiKillOneSpell': 0,
#     'multiTurretRiftHeraldCount': 0,
#     'multikills': 1,
#     'multikillsAfterAggressiveFlash': 0,
#     'mythicItemUsed': 6667,
#     'outerTurretExecutesBefore10Minutes': 0,
#     'outnumberedKills': 2,
#     'outnumberedNexusKill': 0,
#     'perfectDragonSoulsTaken': 0,
#     'perfectGame': 0,
#     'pickKillWithAlly': 23,
#     'poroExplosions': 0,
#     'quickCleanse': 0,
#     'quickFirstTurret': 1,
#     'quickSoloKills': 0,
#     'riftHeraldTakedowns': 0,
#     'saveAllyFromDeath': 7,
#     'scuttleCrabKills': 0,
#     'shortestTimeToAceFromFirstTakedown': 8.026302200000032,
#     'skillshotsDodged': 25,
#     'skillshotsHit': 25,
#     'snowballsHit': 5,
#     'soloBaronKills': 0,
#     'soloKills': 0,
#     'stealthWardsPlaced': 0,
#     'survivedSingleDigitHpCount': 0,
#     'survivedThreeImmobilizesInFight': 8,
#     'takedownOnFirstTurret': 0,
#     'takedowns': 28,
#     'takedownsAfterGainingLevelAdvantage': 0,
#     'takedownsBeforeJungleMinionSpawn': 0,
#     'takedownsFirstXMinutes': 20,
#     'takedownsInAlcove': 0,
#     'takedownsInEnemyFountain': 0,
#     'teamBaronKills': 0,
#     'teamDamagePercentage': 0.15660804742956635,
#     'teamElderDragonKills': 0,
#     'teamRiftHeraldKills': 0,
#     'tookLargeDamageSurvived': 1,
#     'turretPlatesTaken': 0,
#     'turretTakedowns': 2,
#     'turretsTakenWithRiftHerald': 0,
#     'twentyMinionsIn3SecondsCount': 0,
#     'twoWardsOneSweeperCount': 0,
#     'unseenRecalls': 0,
#     'visionScorePerMinute': 0,
#     'wardTakedowns': 0,
#     'wardTakedownsBefore20M': 0,
#     'wardsGuarded': 0},
#    'champExperience': 19000,
#    'champLevel': 18,
#    'championId': 154,
#    'championName': 'Zac',
#    'championTransform': 0,
#    'commandPings': 0,
#    'consumablesPurchased': 0,
#    'damageDealtToBuildings': 609,
#    'damageDealtToObjectives': 609,
#    'damageDealtToTurrets': 609,
#    'damageSelfMitigated': 79006,
#    'dangerPings': 0,
#    'deaths': 12,
#    'detectorWardsPlaced': 0,
#    'doubleKills': 1,
#    'dragonKills': 0,
#    'eligibleForProgression': True,
#    'enemyMissingPings': 0,
#    'enemyVisionPings': 0,
#    'firstBloodAssist': False,
#    'firstBloodKill': False,
#    'firstTowerAssist': True,
#    'firstTowerKill': False,
#    'gameEndedInEarlySurrender': False,
#    'gameEndedInSurrender': False,
#    'getBackPings': 0,
#    'goldEarned': 12525,
#    'goldSpent': 12250,
#    'holdPings': 0,
#    'individualPosition': 'Invalid',
#    'inhibitorKills': 1,
#    'inhibitorTakedowns': 2,
#    'inhibitorsLost': 2,
#    'item0': 6667,
#    'item1': 3065,
#    'item2': 3075,
#    'item3': 3111,
#    'item4': 3068,
#    'item5': 0,
#    'item6': 2052,
#    'itemsPurchased': 21,
#    'killingSprees': 1,
#    'kills': 3,
#    'lane': 'MIDDLE',
#    'largestCriticalStrike': 0,
#    'largestKillingSpree': 2,
#    'largestMultiKill': 2,
#    'longestTimeSpentLiving': 176,
#    'magicDamageDealt': 33132,
#    'magicDamageDealtToChampions': 16848,
#    'magicDamageTaken': 23807,
#    'missions': {'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore10': 0,
#     'playerScore11': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0},
#    'needVisionPings': 0,
#    'neutralMinionsKilled': 0,
#    'nexusKills': 0,
#    'nexusLost': 1,
#    'nexusTakedowns': 0,
#    'objectivesStolen': 0,
#    'objectivesStolenAssists': 0,
#    'onMyWayPings': 0,
#    'participantId': 2,
#    'pentaKills': 0,
#    'perks': {'statPerks': {'defense': 5001, 'flex': 5002, 'offense': 5007},
#     'styles': [{'description': 'primaryStyle',
#       'selections': [{'perk': 8439, 'var1': 1897, 'var2': 3588, 'var3': 0},
#        {'perk': 8463, 'var1': 2582, 'var2': 0, 'var3': 0},
#        {'perk': 8429, 'var1': 62, 'var2': 15, 'var3': 14},
#        {'perk': 8453, 'var1': 4065, 'var2': 642, 'var3': 0}],
#       'style': 8400},
#      {'description': 'subStyle',
#       'selections': [{'perk': 9105, 'var1': 8, 'var2': 40, 'var3': 0},
#        {'perk': 9111, 'var1': 1937, 'var2': 280, 'var3': 0}],
#       'style': 8000}]},
#    'physicalDamageDealt': 2820,
#    'physicalDamageDealtToChampions': 517,
#    'physicalDamageTaken': 19268,
#    'placement': 0,
#    'playerAugment1': 0,
#    'playerAugment2': 0,
#    'playerAugment3': 0,
#    'playerAugment4': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore10': 0,
#    'playerScore11': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'playerSubteamId': 0,
#    'profileIcon': 4568,
#    'pushPings': 0,
#    'puuid': 'Vdf3RQ-tQCBfLbAjg4f4TPgREuNQQwsKmK_ifUKOA_PGMjYnyntE4VU5SOx060QQiiUnZH3lCurJmQ',
#    'quadraKills': 0,
#    'riotIdGameName': '탑1452',
#    'riotIdTagline': 'KR1',
#    'role': 'CARRY',
#    'sightWardsBoughtInGame': 0,
#    'spell1Casts': 37,
#    'spell2Casts': 61,
#    'spell3Casts': 31,
#    'spell4Casts': 9,
#    'subteamPlacement': 0,
#    'summoner1Casts': 14,
#    'summoner1Id': 32,
#    'summoner2Casts': 5,
#    'summoner2Id': 4,
#    'summonerId': 'xJLGzm6EaGTj2sMWoB3vCxlLRqv2OOgErEq4rPv8cZy41w',
#    'summonerLevel': 476,
#    'summonerName': '탑1452',
#    'teamEarlySurrendered': False,
#    'teamId': 100,
#    'teamPosition': '',
#    'timeCCingOthers': 64,
#    'timePlayed': 1278,
#    'totalAllyJungleMinionsKilled': 0,
#    'totalDamageDealt': 39206,
#    'totalDamageDealtToChampions': 18848,
#    'totalDamageShieldedOnTeammates': 0,
#    'totalDamageTaken': 53985,
#    'totalEnemyJungleMinionsKilled': 0,
#    'totalHeal': 32192,
#    'totalHealsOnTeammates': 2817,
#    'totalMinionsKilled': 18,
#    'totalTimeCCDealt': 232,
#    'totalTimeSpentDead': 284,
#    'totalUnitsHealed': 5,
#    'tripleKills': 0,
#    'trueDamageDealt': 3252,
#    'trueDamageDealtToChampions': 1482,
#    'trueDamageTaken': 10908,
#    'turretKills': 0,
#    'turretTakedowns': 2,
#    'turretsLost': 4,
#    'unrealKills': 0,
#    'visionClearedPings': 0,
#    'visionScore': 0,
#    'visionWardsBoughtInGame': 0,
#    'wardsKilled': 0,
#    'wardsPlaced': 0,
#    'win': False},
#   {'allInPings': 0,
#    'assistMePings': 0,
#    'assists': 14,
#    'baitPings': 0,
#    'baronKills': 0,
#    'basicPings': 0,
#    'bountyLevel': 0,
#    'challenges': {'12AssistStreakCount': 0,
#     'abilityUses': 216,
#     'acesBefore15Minutes': 2,
#     'alliedJungleMonsterKills': 0,
#     'baronTakedowns': 0,
#     'blastConeOppositeOpponentCount': 0,
#     'bountyGold': 750,
#     'buffsStolen': 0,
#     'completeSupportQuestInTime': 0,
#     'controlWardsPlaced': 0,
#     'damagePerMinute': 1863.0952653239863,
#     'damageTakenOnTeamPercentage': 0.16863095985149984,
#     'dancedWithRiftHerald': 0,
#     'deathsByEnemyChamps': 10,
#     'dodgeSkillShotsSmallWindow': 0,
#     'doubleAces': 0,
#     'dragonTakedowns': 0,
#     'effectiveHealAndShielding': 0,
#     'elderDragonKillsWithOpposingSoul': 0,
#     'elderDragonMultikills': 0,
#     'enemyChampionImmobilizations': 15,
#     'enemyJungleMonsterKills': 0,
#     'epicMonsterKillsNearEnemyJungler': 0,
#     'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#     'epicMonsterSteals': 0,
#     'epicMonsterStolenWithoutSmite': 0,
#     'firstTurretKilled': 1,
#     'firstTurretKilledTime': 555.5397561,
#     'flawlessAces': 2,
#     'fullTeamTakedown': 5,
#     'gameLength': 1278.1046818,
#     'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#     'goldPerMinute': 759.976766467432,
#     'hadOpenNexus': 0,
#     'highestChampionDamage': 1,
#     'immobilizeAndKillWithAlly': 6,
#     'initialBuffCount': 0,
#     'initialCrabCount': 0,
#     'jungleCsBefore10Minutes': 0,
#     'junglerTakedownsNearDamagedEpicMonster': 0,
#     'kTurretsDestroyedBeforePlatesFall': 2,
#     'kda': 2.8,
#     'killAfterHiddenWithAlly': 1,
#     'killParticipation': 0.6666666666666666,
#     'killedChampTookFullTeamDamageSurvived': 0,
#     'killingSprees': 3,
#     'killsNearEnemyTurret': 0,
#     'killsOnOtherLanesEarlyJungleAsLaner': 0,
#     'killsOnRecentlyHealedByAramPack': 0,
#     'killsUnderOwnTurret': 3,
#     'killsWithHelpFromEpicMonster': 0,
#     'knockEnemyIntoTeamAndKill': 0,
#     'landSkillShotsEarlyGame': 40,
#     'laneMinionsFirst10Minutes': 40,
#     'legendaryCount': 0,
#     'lostAnInhibitor': 0,
#     'maxKillDeficit': 0,
#     'mejaisFullStackInTime': 0,
#     'moreEnemyJungleThanOpponent': 0,
#     'multiKillOneSpell': 0,
#     'multiTurretRiftHeraldCount': 0,
#     'multikills': 6,
#     'multikillsAfterAggressiveFlash': 0,
#     'mythicItemUsed': 6671,
#     'outerTurretExecutesBefore10Minutes': 0,
#     'outnumberedKills': 0,
#     'outnumberedNexusKill': 0,
#     'perfectDragonSoulsTaken': 0,
#     'perfectGame': 0,
#     'pickKillWithAlly': 17,
#     'poroExplosions': 0,
#     'quickCleanse': 0,
#     'quickFirstTurret': 1,
#     'quickSoloKills': 0,
#     'riftHeraldTakedowns': 0,
#     'saveAllyFromDeath': 0,
#     'scuttleCrabKills': 0,
#     'shortestTimeToAceFromFirstTakedown': 8.026302200000032,
#     'skillshotsDodged': 11,
#     'skillshotsHit': 106,
#     'snowballsHit': 0,
#     'soloBaronKills': 0,
#     'soloKills': 0,
#     'stealthWardsPlaced': 0,
#     'survivedSingleDigitHpCount': 0,
#     'survivedThreeImmobilizesInFight': 2,
#     'takedownOnFirstTurret': 0,
#     'takedowns': 28,
#     'takedownsAfterGainingLevelAdvantage': 1,
#     'takedownsBeforeJungleMinionSpawn': 0,
#     'takedownsFirstXMinutes': 22,
#     'takedownsInAlcove': 0,
#     'takedownsInEnemyFountain': 0,
#     'teamBaronKills': 0,
#     'teamDamagePercentage': 0.3297533934679147,
#     'teamElderDragonKills': 0,
#     'teamRiftHeraldKills': 0,
#     'tookLargeDamageSurvived': 0,
#     'turretPlatesTaken': 0,
#     'turretTakedowns': 2,
#     'turretsTakenWithRiftHerald': 0,
#     'twentyMinionsIn3SecondsCount': 0,
#     'twoWardsOneSweeperCount': 0,
#     'unseenRecalls': 0,
#     'visionScorePerMinute': 0,
#     'wardTakedowns': 0,
#     'wardTakedownsBefore20M': 0,
#     'wardsGuarded': 0},
#    'champExperience': 18088,
#    'champLevel': 17,
#    'championId': 523,
#    'championName': 'Aphelios',
#    'championTransform': 0,
#    'commandPings': 2,
#    'consumablesPurchased': 0,
#    'damageDealtToBuildings': 2949,
#    'damageDealtToObjectives': 2949,
#    'damageDealtToTurrets': 2949,
#    'damageSelfMitigated': 14274,
#    'dangerPings': 0,
#    'deaths': 10,
#    'detectorWardsPlaced': 0,
#    'doubleKills': 4,
#    'dragonKills': 0,
#    'eligibleForProgression': True,
#    'enemyMissingPings': 1,
#    'enemyVisionPings': 0,
#    'firstBloodAssist': False,
#    'firstBloodKill': False,
#    'firstTowerAssist': True,
#    'firstTowerKill': False,
#    'gameEndedInEarlySurrender': False,
#    'gameEndedInSurrender': False,
#    'getBackPings': 2,
#    'goldEarned': 16188,
#    'goldSpent': 15150,
#    'holdPings': 0,
#    'individualPosition': 'Invalid',
#    'inhibitorKills': 0,
#    'inhibitorTakedowns': 2,
#    'inhibitorsLost': 2,
#    'item0': 6671,
#    'item1': 3006,
#    'item2': 6672,
#    'item3': 3085,
#    'item4': 3072,
#    'item5': 3035,
#    'item6': 2052,
#    'itemsPurchased': 17,
#    'killingSprees': 4,
#    'kills': 14,
#    'lane': 'TOP',
#    'largestCriticalStrike': 594,
#    'largestKillingSpree': 4,
#    'largestMultiKill': 4,
#    'longestTimeSpentLiving': 287,
#    'magicDamageDealt': 7288,
#    'magicDamageDealtToChampions': 2450,
#    'magicDamageTaken': 16384,
#    'missions': {'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore10': 0,
#     'playerScore11': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0},
#    'needVisionPings': 0,
#    'neutralMinionsKilled': 0,
#    'nexusKills': 0,
#    'nexusLost': 1,
#    'nexusTakedowns': 0,
#    'objectivesStolen': 0,
#    'objectivesStolenAssists': 0,
#    'onMyWayPings': 1,
#    'participantId': 3,
#    'pentaKills': 0,
#    'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#     'styles': [{'description': 'primaryStyle',
#       'selections': [{'perk': 8008, 'var1': 60, 'var2': 11, 'var3': 0},
#        {'perk': 8009, 'var1': 2252, 'var2': 0, 'var3': 0},
#        {'perk': 9103, 'var1': 10, 'var2': 30, 'var3': 0},
#        {'perk': 8014, 'var1': 1032, 'var2': 0, 'var3': 0}],
#       'style': 8000},
#      {'description': 'subStyle',
#       'selections': [{'perk': 8139, 'var1': 1201, 'var2': 0, 'var3': 0},
#        {'perk': 8135, 'var1': 450, 'var2': 5, 'var3': 0}],
#       'style': 8100}]},
#    'physicalDamageDealt': 118516,
#    'physicalDamageDealtToChampions': 35958,
#    'physicalDamageTaken': 6981,
#    'placement': 0,
#    'playerAugment1': 0,
#    'playerAugment2': 0,
#    'playerAugment3': 0,
#    'playerAugment4': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore10': 0,
#    'playerScore11': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'playerSubteamId': 0,
#    'profileIcon': 5722,
#    'pushPings': 0,
#    'puuid': 'xdEKrqwyBY5Y1FL6hxseQjfgXCs4RIwEctuq1UckUJnginZBE_15uocm_E53j3esJcURop4gf3Ot-Q',
#    'quadraKills': 1,
#    'riotIdGameName': 'Dante J',
#    'riotIdTagline': 'KR1',
#    'role': 'DUO',
#    'sightWardsBoughtInGame': 0,
#    'spell1Casts': 76,
#    'spell2Casts': 132,
#    'spell3Casts': 0,
#    'spell4Casts': 8,
#    'subteamPlacement': 0,
#    'summoner1Casts': 8,
#    'summoner1Id': 6,
#    'summoner2Casts': 3,
#    'summoner2Id': 4,
#    'summonerId': '3ON3xevpRYC8n8imaPF5BSv9RBzbzxNtd10cbT25GmOmDMw',
#    'summonerLevel': 550,
#    'summonerName': 'Dante J',
#    'teamEarlySurrendered': False,
#    'teamId': 100,
#    'teamPosition': '',
#    'timeCCingOthers': 17,
#    'timePlayed': 1278,
#    'totalAllyJungleMinionsKilled': 0,
#    'totalDamageDealt': 127082,
#    'totalDamageDealtToChampions': 39687,
#    'totalDamageShieldedOnTeammates': 0,
#    'totalDamageTaken': 25271,
#    'totalEnemyJungleMinionsKilled': 0,
#    'totalHeal': 5130,
#    'totalHealsOnTeammates': 0,
#    'totalMinionsKilled': 94,
#    'totalTimeCCDealt': 91,
#    'totalTimeSpentDead': 280,
#    'totalUnitsHealed': 1,
#    'tripleKills': 1,
#    'trueDamageDealt': 1277,
#    'trueDamageDealtToChampions': 1277,
#    'trueDamageTaken': 1905,
#    'turretKills': 1,
#    'turretTakedowns': 2,
#    'turretsLost': 4,
#    'unrealKills': 0,
#    'visionClearedPings': 0,
#    'visionScore': 0,
#    'visionWardsBoughtInGame': 0,
#    'wardsKilled': 0,
#    'wardsPlaced': 0,
#    'win': False},
#   {'allInPings': 0,
#    'assistMePings': 0,
#    'assists': 20,
#    'baitPings': 0,
#    'baronKills': 0,
#    'basicPings': 0,
#    'bountyLevel': 0,
#    'challenges': {'12AssistStreakCount': 0,
#     'abilityUses': 174,
#     'acesBefore15Minutes': 2,
#     'alliedJungleMonsterKills': 0,
#     'baronTakedowns': 0,
#     'blastConeOppositeOpponentCount': 0,
#     'bountyGold': 750,
#     'buffsStolen': 0,
#     'completeSupportQuestInTime': 0,
#     'controlWardsPlaced': 0,
#     'damagePerMinute': 1386.4783670863633,
#     'damageTakenOnTeamPercentage': 0.2034588476537631,
#     'dancedWithRiftHerald': 0,
#     'deathsByEnemyChamps': 12,
#     'dodgeSkillShotsSmallWindow': 0,
#     'doubleAces': 0,
#     'dragonTakedowns': 0,
#     'effectiveHealAndShielding': 0,
#     'elderDragonKillsWithOpposingSoul': 0,
#     'elderDragonMultikills': 0,
#     'enemyChampionImmobilizations': 31,
#     'enemyJungleMonsterKills': 0,
#     'epicMonsterKillsNearEnemyJungler': 0,
#     'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#     'epicMonsterSteals': 0,
#     'epicMonsterStolenWithoutSmite': 0,
#     'firstTurretKilled': 1,
#     'firstTurretKilledTime': 555.5397561,
#     'flawlessAces': 2,
#     'fullTeamTakedown': 5,
#     'gameLength': 1278.1046818,
#     'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#     'goldPerMinute': 696.7125272670681,
#     'hadOpenNexus': 0,
#     'immobilizeAndKillWithAlly': 10,
#     'initialBuffCount': 0,
#     'initialCrabCount': 0,
#     'jungleCsBefore10Minutes': 0,
#     'junglerTakedownsNearDamagedEpicMonster': 0,
#     'kTurretsDestroyedBeforePlatesFall': 2,
#     'kda': 2.6666666666666665,
#     'killAfterHiddenWithAlly': 16,
#     'killParticipation': 0.7619047619047619,
#     'killedChampTookFullTeamDamageSurvived': 0,
#     'killingSprees': 1,
#     'killsNearEnemyTurret': 1,
#     'killsOnOtherLanesEarlyJungleAsLaner': 0,
#     'killsOnRecentlyHealedByAramPack': 0,
#     'killsUnderOwnTurret': 3,
#     'killsWithHelpFromEpicMonster': 0,
#     'knockEnemyIntoTeamAndKill': 0,
#     'landSkillShotsEarlyGame': 18,
#     'laneMinionsFirst10Minutes': 26,
#     'legendaryCount': 0,
#     'lostAnInhibitor': 0,
#     'maxKillDeficit': 0,
#     'mejaisFullStackInTime': 0,
#     'moreEnemyJungleThanOpponent': 0,
#     'multiKillOneSpell': 0,
#     'multiTurretRiftHeraldCount': 0,
#     'multikills': 5,
#     'multikillsAfterAggressiveFlash': 0,
#     'mythicItemUsed': 6653,
#     'outerTurretExecutesBefore10Minutes': 0,
#     'outnumberedKills': 3,
#     'outnumberedNexusKill': 0,
#     'perfectDragonSoulsTaken': 0,
#     'perfectGame': 0,
#     'pickKillWithAlly': 21,
#     'poroExplosions': 0,
#     'quickCleanse': 0,
#     'quickFirstTurret': 1,
#     'quickSoloKills': 0,
#     'riftHeraldTakedowns': 0,
#     'saveAllyFromDeath': 0,
#     'scuttleCrabKills': 0,
#     'shortestTimeToAceFromFirstTakedown': 16.07759109999995,
#     'skillshotsDodged': 19,
#     'skillshotsHit': 56,
#     'snowballsHit': 8,
#     'soloBaronKills': 0,
#     'soloKills': 1,
#     'stealthWardsPlaced': 0,
#     'survivedSingleDigitHpCount': 0,
#     'survivedThreeImmobilizesInFight': 2,
#     'takedownOnFirstTurret': 0,
#     'takedowns': 32,
#     'takedownsAfterGainingLevelAdvantage': 1,
#     'takedownsBeforeJungleMinionSpawn': 0,
#     'takedownsFirstXMinutes': 25,
#     'takedownsInAlcove': 0,
#     'takedownsInEnemyFountain': 0,
#     'teamBaronKills': 0,
#     'teamDamagePercentage': 0.2453959038090715,
#     'teamElderDragonKills': 0,
#     'teamRiftHeraldKills': 0,
#     'tookLargeDamageSurvived': 0,
#     'turretPlatesTaken': 0,
#     'turretTakedowns': 2,
#     'turretsTakenWithRiftHerald': 0,
#     'twentyMinionsIn3SecondsCount': 0,
#     'twoWardsOneSweeperCount': 0,
#     'unseenRecalls': 0,
#     'visionScorePerMinute': 0,
#     'wardTakedowns': 0,
#     'wardTakedownsBefore20M': 0,
#     'wardsGuarded': 0},
#    'champExperience': 19582,
#    'champLevel': 18,
#    'championId': 127,
#    'championName': 'Lissandra',
#    'championTransform': 0,
#    'commandPings': 0,
#    'consumablesPurchased': 0,
#    'damageDealtToBuildings': 1384,
#    'damageDealtToObjectives': 1384,
#    'damageDealtToTurrets': 1384,
#    'damageSelfMitigated': 16023,
#    'dangerPings': 0,
#    'deaths': 12,
#    'detectorWardsPlaced': 0,
#    'doubleKills': 2,
#    'dragonKills': 0,
#    'eligibleForProgression': True,
#    'enemyMissingPings': 0,
#    'enemyVisionPings': 0,
#    'firstBloodAssist': False,
#    'firstBloodKill': False,
#    'firstTowerAssist': True,
#    'firstTowerKill': False,
#    'gameEndedInEarlySurrender': False,
#    'gameEndedInSurrender': False,
#    'getBackPings': 0,
#    'goldEarned': 14841,
#    'goldSpent': 14100,
#    'holdPings': 0,
#    'individualPosition': 'Invalid',
#    'inhibitorKills': 0,
#    'inhibitorTakedowns': 2,
#    'inhibitorsLost': 2,
#    'item0': 6653,
#    'item1': 3157,
#    'item2': 3916,
#    'item3': 3020,
#    'item4': 4645,
#    'item5': 4637,
#    'item6': 2052,
#    'itemsPurchased': 12,
#    'killingSprees': 3,
#    'kills': 12,
#    'lane': 'TOP',
#    'largestCriticalStrike': 0,
#    'largestKillingSpree': 7,
#    'largestMultiKill': 5,
#    'longestTimeSpentLiving': 180,
#    'magicDamageDealt': 80057,
#    'magicDamageDealtToChampions': 26560,
#    'magicDamageTaken': 17635,
#    'missions': {'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore10': 0,
#     'playerScore11': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0},
#    'needVisionPings': 0,
#    'neutralMinionsKilled': 0,
#    'nexusKills': 0,
#    'nexusLost': 1,
#    'nexusTakedowns': 0,
#    'objectivesStolen': 0,
#    'objectivesStolenAssists': 0,
#    'onMyWayPings': 0,
#    'participantId': 4,
#    'pentaKills': 1,
#    'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5008},
#     'styles': [{'description': 'primaryStyle',
#       'selections': [{'perk': 8128, 'var1': 1224, 'var2': 21, 'var3': 0},
#        {'perk': 8126, 'var1': 1176, 'var2': 0, 'var3': 0},
#        {'perk': 8138, 'var1': 30, 'var2': 0, 'var3': 0},
#        {'perk': 8106, 'var1': 5, 'var2': 0, 'var3': 0}],
#       'style': 8100},
#      {'description': 'subStyle',
#       'selections': [{'perk': 8009, 'var1': 3853, 'var2': 0, 'var3': 0},
#        {'perk': 8014, 'var1': 1086, 'var2': 0, 'var3': 0}],
#       'style': 8000}]},
#    'physicalDamageDealt': 2160,
#    'physicalDamageDealtToChampions': 649,
#    'physicalDamageTaken': 11393,
#    'placement': 0,
#    'playerAugment1': 0,
#    'playerAugment2': 0,
#    'playerAugment3': 0,
#    'playerAugment4': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore10': 0,
#    'playerScore11': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'playerSubteamId': 0,
#    'profileIcon': 5119,
#    'pushPings': 0,
#    'puuid': 'Ct9XmJVvevuSZ6tNu5LiCk5V1cfgE08cbzp3kVM2sAVD3J2FoBfofPLx1F_GhGHhURhtujbQqyd2TA',
#    'quadraKills': 1,
#    'riotIdGameName': '알민강',
#    'riotIdTagline': 'KR1',
#    'role': 'SUPPORT',
#    'sightWardsBoughtInGame': 0,
#    'spell1Casts': 94,
#    'spell2Casts': 27,
#    'spell3Casts': 38,
#    'spell4Casts': 15,
#    'subteamPlacement': 0,
#    'summoner1Casts': 5,
#    'summoner1Id': 4,
#    'summoner2Casts': 20,
#    'summoner2Id': 32,
#    'summonerId': 'b3Kxpgv0UaKF2B0XC6Cg37qs5EfD8RekGfe8bwm1FyTIClI',
#    'summonerLevel': 249,
#    'summonerName': '알민강',
#    'teamEarlySurrendered': False,
#    'teamId': 100,
#    'teamPosition': '',
#    'timeCCingOthers': 54,
#    'timePlayed': 1278,
#    'totalAllyJungleMinionsKilled': 0,
#    'totalDamageDealt': 84693,
#    'totalDamageDealtToChampions': 29534,
#    'totalDamageShieldedOnTeammates': 0,
#    'totalDamageTaken': 30490,
#    'totalEnemyJungleMinionsKilled': 0,
#    'totalHeal': 5736,
#    'totalHealsOnTeammates': 0,
#    'totalMinionsKilled': 65,
#    'totalTimeCCDealt': 416,
#    'totalTimeSpentDead': 284,
#    'totalUnitsHealed': 1,
#    'tripleKills': 1,
#    'trueDamageDealt': 2475,
#    'trueDamageDealtToChampions': 2325,
#    'trueDamageTaken': 1461,
#    'turretKills': 0,
#    'turretTakedowns': 2,
#    'turretsLost': 4,
#    'unrealKills': 0,
#    'visionClearedPings': 0,
#    'visionScore': 0,
#    'visionWardsBoughtInGame': 0,
#    'wardsKilled': 0,
#    'wardsPlaced': 0,
#    'win': False},
#   {'allInPings': 0,
#    'assistMePings': 0,
#    'assists': 31,
#    'baitPings': 0,
#    'baronKills': 0,
#    'basicPings': 0,
#    'bountyLevel': 0,
#    'challenges': {'12AssistStreakCount': 2,
#     'abilityUses': 184,
#     'acesBefore15Minutes': 2,
#     'alliedJungleMonsterKills': 0,
#     'baronTakedowns': 0,
#     'blastConeOppositeOpponentCount': 0,
#     'bountyGold': 150,
#     'buffsStolen': 0,
#     'completeSupportQuestInTime': 0,
#     'controlWardsPlaced': 0,
#     'damagePerMinute': 357.6921241472797,
#     'damageTakenOnTeamPercentage': 0.08808035564758401,
#     'dancedWithRiftHerald': 0,
#     'deathsByEnemyChamps': 5,
#     'dodgeSkillShotsSmallWindow': 0,
#     'doubleAces': 0,
#     'dragonTakedowns': 0,
#     'effectiveHealAndShielding': 16350.220703125,
#     'elderDragonKillsWithOpposingSoul': 0,
#     'elderDragonMultikills': 0,
#     'enemyChampionImmobilizations': 13,
#     'enemyJungleMonsterKills': 0,
#     'epicMonsterKillsNearEnemyJungler': 0,
#     'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#     'epicMonsterSteals': 0,
#     'epicMonsterStolenWithoutSmite': 0,
#     'firstTurretKilled': 1,
#     'firstTurretKilledTime': 555.5397561,
#     'flawlessAces': 2,
#     'fullTeamTakedown': 5,
#     'gameLength': 1278.1046818,
#     'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#     'goldPerMinute': 574.886843675006,
#     'hadOpenNexus': 0,
#     'immobilizeAndKillWithAlly': 6,
#     'initialBuffCount': 0,
#     'initialCrabCount': 0,
#     'jungleCsBefore10Minutes': 0,
#     'junglerTakedownsNearDamagedEpicMonster': 0,
#     'kTurretsDestroyedBeforePlatesFall': 2,
#     'kda': 6.6,
#     'killAfterHiddenWithAlly': 9,
#     'killParticipation': 0.7857142857142857,
#     'killedChampTookFullTeamDamageSurvived': 0,
#     'killingSprees': 0,
#     'killsNearEnemyTurret': 0,
#     'killsOnOtherLanesEarlyJungleAsLaner': 0,
#     'killsOnRecentlyHealedByAramPack': 0,
#     'killsUnderOwnTurret': 1,
#     'killsWithHelpFromEpicMonster': 0,
#     'knockEnemyIntoTeamAndKill': 0,
#     'landSkillShotsEarlyGame': 26,
#     'laneMinionsFirst10Minutes': 0,
#     'legendaryCount': 0,
#     'lostAnInhibitor': 0,
#     'maxKillDeficit': 0,
#     'mejaisFullStackInTime': 0,
#     'moreEnemyJungleThanOpponent': 0,
#     'multiKillOneSpell': 0,
#     'multiTurretRiftHeraldCount': 0,
#     'multikills': 0,
#     'multikillsAfterAggressiveFlash': 0,
#     'mythicItemUsed': 2065,
#     'outerTurretExecutesBefore10Minutes': 0,
#     'outnumberedKills': 1,
#     'outnumberedNexusKill': 0,
#     'perfectDragonSoulsTaken': 0,
#     'perfectGame': 0,
#     'pickKillWithAlly': 22,
#     'poroExplosions': 0,
#     'quickCleanse': 0,
#     'quickFirstTurret': 1,
#     'quickSoloKills': 0,
#     'riftHeraldTakedowns': 0,
#     'saveAllyFromDeath': 2,
#     'scuttleCrabKills': 0,
#     'shortestTimeToAceFromFirstTakedown': 8.026302200000032,
#     'skillshotsDodged': 16,
#     'skillshotsHit': 62,
#     'snowballsHit': 0,
#     'soloBaronKills': 0,
#     'soloKills': 0,
#     'stealthWardsPlaced': 0,
#     'survivedSingleDigitHpCount': 0,
#     'survivedThreeImmobilizesInFight': 0,
#     'takedownOnFirstTurret': 1,
#     'takedowns': 33,
#     'takedownsAfterGainingLevelAdvantage': 0,
#     'takedownsBeforeJungleMinionSpawn': 0,
#     'takedownsFirstXMinutes': 21,
#     'takedownsInAlcove': 0,
#     'takedownsInEnemyFountain': 0,
#     'teamBaronKills': 0,
#     'teamDamagePercentage': 0.06330872819528151,
#     'teamElderDragonKills': 0,
#     'teamRiftHeraldKills': 0,
#     'tookLargeDamageSurvived': 0,
#     'turretPlatesTaken': 0,
#     'turretTakedowns': 2,
#     'turretsTakenWithRiftHerald': 0,
#     'twentyMinionsIn3SecondsCount': 0,
#     'twoWardsOneSweeperCount': 0,
#     'unseenRecalls': 0,
#     'visionScorePerMinute': 0,
#     'wardTakedowns': 0,
#     'wardTakedownsBefore20M': 0,
#     'wardsGuarded': 0},
#    'champExperience': 20702,
#    'champLevel': 18,
#    'championId': 117,
#    'championName': 'Lulu',
#    'championTransform': 0,
#    'commandPings': 1,
#    'consumablesPurchased': 2,
#    'damageDealtToBuildings': 662,
#    'damageDealtToObjectives': 662,
#    'damageDealtToTurrets': 662,
#    'damageSelfMitigated': 6322,
#    'dangerPings': 0,
#    'deaths': 5,
#    'detectorWardsPlaced': 0,
#    'doubleKills': 0,
#    'dragonKills': 0,
#    'eligibleForProgression': True,
#    'enemyMissingPings': 0,
#    'enemyVisionPings': 0,
#    'firstBloodAssist': False,
#    'firstBloodKill': False,
#    'firstTowerAssist': False,
#    'firstTowerKill': True,
#    'gameEndedInEarlySurrender': False,
#    'gameEndedInSurrender': False,
#    'getBackPings': 0,
#    'goldEarned': 12246,
#    'goldSpent': 10700,
#    'holdPings': 0,
#    'individualPosition': 'Invalid',
#    'inhibitorKills': 0,
#    'inhibitorTakedowns': 2,
#    'inhibitorsLost': 2,
#    'item0': 2065,
#    'item1': 3504,
#    'item2': 3107,
#    'item3': 3040,
#    'item4': 3158,
#    'item5': 0,
#    'item6': 2052,
#    'itemsPurchased': 20,
#    'killingSprees': 0,
#    'kills': 2,
#    'lane': 'MIDDLE',
#    'largestCriticalStrike': 0,
#    'largestKillingSpree': 0,
#    'largestMultiKill': 1,
#    'longestTimeSpentLiving': 274,
#    'magicDamageDealt': 12608,
#    'magicDamageDealtToChampions': 6748,
#    'magicDamageTaken': 6851,
#    'missions': {'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore10': 0,
#     'playerScore11': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0},
#    'needVisionPings': 0,
#    'neutralMinionsKilled': 0,
#    'nexusKills': 0,
#    'nexusLost': 1,
#    'nexusTakedowns': 0,
#    'objectivesStolen': 0,
#    'objectivesStolenAssists': 0,
#    'onMyWayPings': 0,
#    'participantId': 5,
#    'pentaKills': 0,
#    'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5008},
#     'styles': [{'description': 'primaryStyle',
#       'selections': [{'perk': 8214, 'var1': 808, 'var2': 2142, 'var3': 0},
#        {'perk': 8226, 'var1': 250, 'var2': 110, 'var3': 0},
#        {'perk': 8210, 'var1': 22, 'var2': 0, 'var3': 0},
#        {'perk': 8237, 'var1': 408, 'var2': 0, 'var3': 0}],
#       'style': 8200},
#      {'description': 'subStyle',
#       'selections': [{'perk': 8014, 'var1': 218, 'var2': 0, 'var3': 0},
#        {'perk': 8009, 'var1': 3180, 'var2': 0, 'var3': 0}],
#       'style': 8000}]},
#    'physicalDamageDealt': 1692,
#    'physicalDamageDealtToChampions': 648,
#    'physicalDamageTaken': 5887,
#    'placement': 0,
#    'playerAugment1': 0,
#    'playerAugment2': 0,
#    'playerAugment3': 0,
#    'playerAugment4': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore10': 0,
#    'playerScore11': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'playerSubteamId': 0,
#    'profileIcon': 3840,
#    'pushPings': 0,
#    'puuid': 'irrXKT8sisjBaCIrOaOknaSu_-HRyw61szxGL15iQqu8YpFDYJw9W7aePeadvQziclqsb8XBXmKWPg',
#    'quadraKills': 0,
#    'riotIdGameName': '고담시티',
#    'riotIdTagline': 'KR1',
#    'role': 'SUPPORT',
#    'sightWardsBoughtInGame': 0,
#    'spell1Casts': 35,
#    'spell2Casts': 60,
#    'spell3Casts': 80,
#    'spell4Casts': 9,
#    'subteamPlacement': 0,
#    'summoner1Casts': 6,
#    'summoner1Id': 3,
#    'summoner2Casts': 2,
#    'summoner2Id': 4,
#    'summonerId': 'AdeiByTXXA0zhYGSvozbL_MwtppEDuprESPwc7wl1FEMww',
#    'summonerLevel': 208,
#    'summonerName': '고담시티',
#    'teamEarlySurrendered': False,
#    'teamId': 100,
#    'teamPosition': '',
#    'timeCCingOthers': 37,
#    'timePlayed': 1278,
#    'totalAllyJungleMinionsKilled': 0,
#    'totalDamageDealt': 14522,
#    'totalDamageDealtToChampions': 7619,
#    'totalDamageShieldedOnTeammates': 14756,
#    'totalDamageTaken': 13199,
#    'totalEnemyJungleMinionsKilled': 0,
#    'totalHeal': 3417,
#    'totalHealsOnTeammates': 1594,
#    'totalMinionsKilled': 1,
#    'totalTimeCCDealt': 219,
#    'totalTimeSpentDead': 126,
#    'totalUnitsHealed': 6,
#    'tripleKills': 0,
#    'trueDamageDealt': 222,
#    'trueDamageDealtToChampions': 222,
#    'trueDamageTaken': 461,
#    'turretKills': 1,
#    'turretTakedowns': 2,
#    'turretsLost': 4,
#    'unrealKills': 0,
#    'visionClearedPings': 0,
#    'visionScore': 0,
#    'visionWardsBoughtInGame': 0,
#    'wardsKilled': 0,
#    'wardsPlaced': 0,
#    'win': False},
#   {'allInPings': 0,
#    'assistMePings': 0,
#    'assists': 24,
#    'baitPings': 0,
#    'baronKills': 0,
#    'basicPings': 0,
#    'bountyLevel': 0,
#    'challenges': {'12AssistStreakCount': 0,
#     'abilityUses': 109,
#     'acesBefore15Minutes': 1,
#     'alliedJungleMonsterKills': 0,
#     'baronTakedowns': 0,
#     'blastConeOppositeOpponentCount': 0,
#     'bountyGold': 150,
#     'buffsStolen': 0,
#     'completeSupportQuestInTime': 0,
#     'controlWardsPlaced': 0,
#     'damagePerMinute': 926.8378695273941,
#     'damageTakenOnTeamPercentage': 0.3099636864461753,
#     'dancedWithRiftHerald': 0,
#     'deathsByEnemyChamps': 10,
#     'dodgeSkillShotsSmallWindow': 26,
#     'doubleAces': 0,
#     'dragonTakedowns': 0,
#     'effectiveHealAndShielding': 0,
#     'elderDragonKillsWithOpposingSoul': 0,
#     'elderDragonMultikills': 0,
#     'enemyChampionImmobilizations': 28,
#     'enemyJungleMonsterKills': 0,
#     'epicMonsterKillsNearEnemyJungler': 0,
#     'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#     'epicMonsterSteals': 0,
#     'epicMonsterStolenWithoutSmite': 0,
#     'firstTurretKilled': 0,
#     'flawlessAces': 0,
#     'fullTeamTakedown': 12,
#     'gameLength': 1278.1046818,
#     'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#     'goldPerMinute': 631.7268823398656,
#     'hadOpenNexus': 0,
#     'immobilizeAndKillWithAlly': 11,
#     'initialBuffCount': 0,
#     'initialCrabCount': 0,
#     'jungleCsBefore10Minutes': 0,
#     'junglerTakedownsNearDamagedEpicMonster': 0,
#     'kTurretsDestroyedBeforePlatesFall': 1,
#     'kda': 3.1,
#     'killAfterHiddenWithAlly': 9,
#     'killParticipation': 0.62,
#     'killedChampTookFullTeamDamageSurvived': 0,
#     'killingSprees': 0,
#     'killsNearEnemyTurret': 3,
#     'killsOnOtherLanesEarlyJungleAsLaner': 0,
#     'killsOnRecentlyHealedByAramPack': 0,
#     'killsUnderOwnTurret': 0,
#     'killsWithHelpFromEpicMonster': 0,
#     'knockEnemyIntoTeamAndKill': 11,
#     'landSkillShotsEarlyGame': 0,
#     'laneMinionsFirst10Minutes': 9,
#     'legendaryCount': 0,
#     'lostAnInhibitor': 1,
#     'maxKillDeficit': 3,
#     'mejaisFullStackInTime': 0,
#     'moreEnemyJungleThanOpponent': 0,
#     'multiKillOneSpell': 0,
#     'multiTurretRiftHeraldCount': 0,
#     'multikills': 0,
#     'multikillsAfterAggressiveFlash': 0,
#     'mythicItemUsed': 6630,
#     'outerTurretExecutesBefore10Minutes': 0,
#     'outnumberedKills': 3,
#     'outnumberedNexusKill': 0,
#     'perfectDragonSoulsTaken': 0,
#     'perfectGame': 0,
#     'pickKillWithAlly': 18,
#     'poroExplosions': 0,
#     'quickCleanse': 0,
#     'quickFirstTurret': 0,
#     'quickSoloKills': 0,
#     'riftHeraldTakedowns': 0,
#     'saveAllyFromDeath': 0,
#     'scuttleCrabKills': 0,
#     'skillshotsDodged': 190,
#     'skillshotsHit': 0,
#     'snowballsHit': 13,
#     'soloBaronKills': 0,
#     'soloKills': 0,
#     'stealthWardsPlaced': 0,
#     'survivedSingleDigitHpCount': 0,
#     'survivedThreeImmobilizesInFight': 12,
#     'takedownOnFirstTurret': 1,
#     'takedowns': 31,
#     'takedownsAfterGainingLevelAdvantage': 0,
#     'takedownsBeforeJungleMinionSpawn': 0,
#     'takedownsFirstXMinutes': 19,
#     'takedownsInAlcove': 0,
#     'takedownsInEnemyFountain': 0,
#     'teamBaronKills': 0,
#     'teamDamagePercentage': 0.13755954793984235,
#     'teamElderDragonKills': 0,
#     'teamRiftHeraldKills': 0,
#     'tookLargeDamageSurvived': 2,
#     'turretPlatesTaken': 0,
#     'turretTakedowns': 4,
#     'turretsTakenWithRiftHerald': 0,
#     'twentyMinionsIn3SecondsCount': 0,
#     'twoWardsOneSweeperCount': 0,
#     'unseenRecalls': 0,
#     'visionScorePerMinute': 0,
#     'wardTakedowns': 0,
#     'wardTakedownsBefore20M': 0,
#     'wardsGuarded': 0},
#    'champExperience': 19846,
#    'champLevel': 18,
#    'championId': 122,
#    'championName': 'Darius',
#    'championTransform': 0,
#    'commandPings': 0,
#    'consumablesPurchased': 0,
#    'damageDealtToBuildings': 1678,
#    'damageDealtToObjectives': 1678,
#    'damageDealtToTurrets': 1678,
#    'damageSelfMitigated': 56382,
#    'dangerPings': 0,
#    'deaths': 10,
#    'detectorWardsPlaced': 0,
#    'doubleKills': 0,
#    'dragonKills': 0,
#    'eligibleForProgression': True,
#    'enemyMissingPings': 0,
#    'enemyVisionPings': 0,
#    'firstBloodAssist': False,
#    'firstBloodKill': False,
#    'firstTowerAssist': False,
#    'firstTowerKill': False,
#    'gameEndedInEarlySurrender': False,
#    'gameEndedInSurrender': False,
#    'getBackPings': 0,
#    'goldEarned': 13456,
#    'goldSpent': 12500,
#    'holdPings': 0,
#    'individualPosition': 'Invalid',
#    'inhibitorKills': 0,
#    'inhibitorTakedowns': 0,
#    'inhibitorsLost': 2,
#    'item0': 2051,
#    'item1': 6333,
#    'item2': 6630,
#    'item3': 3111,
#    'item4': 3742,
#    'item5': 1057,
#    'item6': 2052,
#    'itemsPurchased': 21,
#    'killingSprees': 1,
#    'kills': 7,
#    'lane': 'MIDDLE',
#    'largestCriticalStrike': 0,
#    'largestKillingSpree': 2,
#    'largestMultiKill': 1,
#    'longestTimeSpentLiving': 151,
#    'magicDamageDealt': 0,
#    'magicDamageDealtToChampions': 0,
#    'magicDamageTaken': 13421,
#    'missions': {'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore10': 0,
#     'playerScore11': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0},
#    'needVisionPings': 0,
#    'neutralMinionsKilled': 0,
#    'nexusKills': 0,
#    'nexusLost': 0,
#    'nexusTakedowns': 0,
#    'objectivesStolen': 0,
#    'objectivesStolenAssists': 0,
#    'onMyWayPings': 0,
#    'participantId': 6,
#    'pentaKills': 0,
#    'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#     'styles': [{'description': 'primaryStyle',
#       'selections': [{'perk': 8010, 'var1': 271, 'var2': 0, 'var3': 0},
#        {'perk': 9111, 'var1': 1734, 'var2': 310, 'var3': 0},
#        {'perk': 9105, 'var1': 8, 'var2': 10, 'var3': 0},
#        {'perk': 8299, 'var1': 821, 'var2': 0, 'var3': 0}],
#       'style': 8000},
#      {'description': 'subStyle',
#       'selections': [{'perk': 8242, 'var1': 132, 'var2': 0, 'var3': 0},
#        {'perk': 8473, 'var1': 594, 'var2': 0, 'var3': 0}],
#       'style': 8400}]},
#    'physicalDamageDealt': 45694,
#    'physicalDamageDealtToChampions': 15406,
#    'physicalDamageTaken': 21754,
#    'placement': 0,
#    'playerAugment1': 0,
#    'playerAugment2': 0,
#    'playerAugment3': 0,
#    'playerAugment4': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore10': 0,
#    'playerScore11': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'playerSubteamId': 0,
#    'profileIcon': 3546,
#    'pushPings': 0,
#    'puuid': 'OqdtNC3ZJI-FMI020F35pjg5RkdJblHdUzzIt56sbDJ0koO8uWoHaRvQm_twPcT95rR2xWStzR0DNw',
#    'quadraKills': 0,
#    'riotIdGameName': '보삐바뽀',
#    'riotIdTagline': 'KR1',
#    'role': 'SUPPORT',
#    'sightWardsBoughtInGame': 0,
#    'spell1Casts': 51,
#    'spell2Casts': 27,
#    'spell3Casts': 25,
#    'spell4Casts': 6,
#    'subteamPlacement': 0,
#    'summoner1Casts': 26,
#    'summoner1Id': 32,
#    'summoner2Casts': 5,
#    'summoner2Id': 4,
#    'summonerId': 'bS0GcGrrjnGKwwx5RZTUGyMA8Ep9GMA2u_VHFkCbWUnrYZTe',
#    'summonerLevel': 83,
#    'summonerName': '보삐바뽀',
#    'teamEarlySurrendered': False,
#    'teamId': 200,
#    'teamPosition': '',
#    'timeCCingOthers': 35,
#    'timePlayed': 1278,
#    'totalAllyJungleMinionsKilled': 0,
# ...
#     'enemyJungleMonsterKills': 0,
#     'epicMonsterKillsNearEnemyJungler': 0,
#     'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#     'epicMonsterSteals': 0,
#     'epicMonsterStolenWithoutSmite': 0,
#     'firstTurretKilled': 0,
#     'flawlessAces': 0,
#     'fullTeamTakedown': 12,
#     'gameLength': 1278.1046818,
#     'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#     'goldPerMinute': 739.7914516963707,
#     'hadOpenNexus': 0,
#     'immobilizeAndKillWithAlly': 14,
#     'initialBuffCount': 0,
#     'initialCrabCount': 0,
#     'jungleCsBefore10Minutes': 0,
#     'junglerTakedownsNearDamagedEpicMonster': 0,
#     'kTurretsDestroyedBeforePlatesFall': 1,
#     'kda': 6.833333333333333,
#     'killAfterHiddenWithAlly': 9,
#     'killParticipation': 0.82,
#     'killedChampTookFullTeamDamageSurvived': 0,
#     'killingSprees': 1,
#     'killsNearEnemyTurret': 3,
#     'killsOnOtherLanesEarlyJungleAsLaner': 0,
#     'killsOnRecentlyHealedByAramPack': 0,
#     'killsUnderOwnTurret': 4,
#     'killsWithHelpFromEpicMonster': 0,
#     'knockEnemyIntoTeamAndKill': 15,
#     'landSkillShotsEarlyGame': 23,
#     'laneMinionsFirst10Minutes': 14,
#     'legendaryCount': 0,
#     'lostAnInhibitor': 1,
#     'maxKillDeficit': 3,
#     'mejaisFullStackInTime': 0,
#     'moreEnemyJungleThanOpponent': 0,
#     'multiKillOneSpell': 0,
#     'multiTurretRiftHeraldCount': 0,
#     'multikills': 3,
#     'multikillsAfterAggressiveFlash': 0,
#     'mythicItemUsed': 6653,
#     'outerTurretExecutesBefore10Minutes': 0,
#     'outnumberedKills': 4,
#     'outnumberedNexusKill': 0,
#     'perfectDragonSoulsTaken': 0,
#     'perfectGame': 0,
#     'pickKillWithAlly': 25,
#     'poroExplosions': 0,
#     'quickCleanse': 0,
#     'quickFirstTurret': 0,
#     'quickSoloKills': 0,
#     'riftHeraldTakedowns': 0,
#     'saveAllyFromDeath': 0,
#     'scuttleCrabKills': 0,
#     'shortestTimeToAceFromFirstTakedown': 14.948755399999982,
#     'skillshotsDodged': 47,
#     'skillshotsHit': 60,
#     'snowballsHit': 0,
#     'soloBaronKills': 0,
#     'soloKills': 2,
#     'stealthWardsPlaced': 0,
#     'survivedSingleDigitHpCount': 0,
#     'survivedThreeImmobilizesInFight': 2,
#     'takedownOnFirstTurret': 1,
#     'takedowns': 41,
#     'takedownsAfterGainingLevelAdvantage': 0,
#     'takedownsBeforeJungleMinionSpawn': 1,
#     'takedownsFirstXMinutes': 27,
#     'takedownsInAlcove': 0,
#     'takedownsInEnemyFountain': 0,
#     'teamBaronKills': 0,
#     'teamDamagePercentage': 0.270747912734737,
#     'teamElderDragonKills': 0,
#     'teamRiftHeraldKills': 0,
#     'tookLargeDamageSurvived': 0,
#     'turretPlatesTaken': 0,
#     'turretTakedowns': 4,
#     'turretsTakenWithRiftHerald': 0,
#     'twentyMinionsIn3SecondsCount': 0,
#     'twoWardsOneSweeperCount': 0,
#     'unseenRecalls': 0,
#     'visionScorePerMinute': 0,
#     'wardTakedowns': 0,
#     'wardTakedownsBefore20M': 0,
#     'wardsGuarded': 0},
#    'champExperience': 21214,
#    'champLevel': 18,
#    'championId': 61,
#    'championName': 'Orianna',
#    'championTransform': 0,
#    'commandPings': 0,
#    'consumablesPurchased': 0,
#    'damageDealtToBuildings': 2517,
#    'damageDealtToObjectives': 2517,
#    'damageDealtToTurrets': 2517,
#    'damageSelfMitigated': 14140,
#    'dangerPings': 0,
#    'deaths': 6,
#    'detectorWardsPlaced': 0,
#    'doubleKills': 2,
#    'dragonKills': 0,
#    'eligibleForProgression': True,
#    'enemyMissingPings': 0,
#    'enemyVisionPings': 0,
#    'firstBloodAssist': False,
#    'firstBloodKill': True,
#    'firstTowerAssist': False,
#    'firstTowerKill': False,
#    'gameEndedInEarlySurrender': False,
#    'gameEndedInSurrender': False,
#    'getBackPings': 1,
#    'goldEarned': 15758,
#    'goldSpent': 14335,
#    'holdPings': 0,
#    'individualPosition': 'Invalid',
#    'inhibitorKills': 0,
#    'inhibitorTakedowns': 2,
#    'inhibitorsLost': 2,
#    'item0': 6653,
#    'item1': 3157,
#    'item2': 4645,
#    'item3': 3020,
#    'item4': 3089,
#    'item5': 1052,
#    'item6': 2052,
#    'itemsPurchased': 15,
#    'killingSprees': 3,
#    'kills': 13,
#    'lane': 'MIDDLE',
#    'largestCriticalStrike': 0,
#    'largestKillingSpree': 5,
#    'largestMultiKill': 3,
#    'longestTimeSpentLiving': 268,
#    'magicDamageDealt': 74348,
#    'magicDamageDealtToChampions': 36489,
#    'magicDamageTaken': 6302,
#    'missions': {'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore10': 0,
#     'playerScore11': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0},
#    'needVisionPings': 0,
#    'neutralMinionsKilled': 0,
#    'nexusKills': 1,
#    'nexusLost': 0,
#    'nexusTakedowns': 1,
#    'objectivesStolen': 0,
#    'objectivesStolenAssists': 0,
#    'onMyWayPings': 0,
#    'participantId': 9,
#    'pentaKills': 0,
#    'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5008},
#     'styles': [{'description': 'primaryStyle',
#       'selections': [{'perk': 8128, 'var1': 1789, 'var2': 32, 'var3': 0},
#        {'perk': 8126, 'var1': 1075, 'var2': 0, 'var3': 0},
#        {'perk': 8138, 'var1': 30, 'var2': 0, 'var3': 0},
#        {'perk': 8106, 'var1': 5, 'var2': 0, 'var3': 0}],
#       'style': 8100},
#      {'description': 'subStyle',
#       'selections': [{'perk': 8009, 'var1': 6024, 'var2': 0, 'var3': 0},
#        {'perk': 8014, 'var1': 1227, 'var2': 0, 'var3': 0}],
#       'style': 8000}]},
#    'physicalDamageDealt': 3827,
#    'physicalDamageDealtToChampions': 470,
#    'physicalDamageTaken': 8877,
#    'placement': 0,
#    'playerAugment1': 0,
#    'playerAugment2': 0,
#    'playerAugment3': 0,
#    'playerAugment4': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore10': 0,
#    'playerScore11': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'playerSubteamId': 0,
#    'profileIcon': 6298,
#    'pushPings': 0,
#    'puuid': 'MOfhL8HochDiWU_6VQEVNgS30UDCEgidn3xDlEtVyJThxWQgA4PKEOT8ZM3yPMUI6RIh296Exg8vyw',
#    'quadraKills': 0,
#    'riotIdGameName': '5dx',
#    'riotIdTagline': 'KR1',
#    'role': 'SUPPORT',
#    'sightWardsBoughtInGame': 0,
#    'spell1Casts': 160,
#    'spell2Casts': 74,
#    'spell3Casts': 65,
#    'spell4Casts': 11,
#    'subteamPlacement': 0,
#    'summoner1Casts': 7,
#    'summoner1Id': 6,
#    'summoner2Casts': 4,
#    'summoner2Id': 4,
#    'summonerId': 'QdAohNwGgb6Bt03Hti0YDOlm6Mk_EPe3_uNFQl2iijUCbw',
#    'summonerLevel': 1051,
#    'summonerName': '5dx',
#    'teamEarlySurrendered': False,
#    'teamId': 200,
#    'teamPosition': '',
#    'timeCCingOthers': 46,
#    'timePlayed': 1278,
#    'totalAllyJungleMinionsKilled': 0,
#    'totalDamageDealt': 80074,
#    'totalDamageDealtToChampions': 38859,
#    'totalDamageShieldedOnTeammates': 2690,
#    'totalDamageTaken': 15392,
#    'totalEnemyJungleMinionsKilled': 0,
#    'totalHeal': 2187,
#    'totalHealsOnTeammates': 0,
#    'totalMinionsKilled': 46,
#    'totalTimeCCDealt': 344,
#    'totalTimeSpentDead': 166,
#    'totalUnitsHealed': 1,
#    'tripleKills': 1,
#    'trueDamageDealt': 1899,
#    'trueDamageDealtToChampions': 1899,
#    'trueDamageTaken': 212,
#    'turretKills': 1,
#    'turretTakedowns': 4,
#    'turretsLost': 2,
#    'unrealKills': 0,
#    'visionClearedPings': 0,
#    'visionScore': 0,
#    'visionWardsBoughtInGame': 0,
#    'wardsKilled': 0,
#    'wardsPlaced': 0,
#    'win': True},
#   {'allInPings': 0,
#    'assistMePings': 0,
#    'assists': 29,
#    'baitPings': 0,
#    'baronKills': 0,
#    'basicPings': 0,
#    'bountyLevel': 1,
#    'challenges': {'12AssistStreakCount': 0,
#     'abilityUses': 291,
#     'acesBefore15Minutes': 1,
#     'alliedJungleMonsterKills': 0,
#     'baronTakedowns': 0,
#     'blastConeOppositeOpponentCount': 0,
#     'bountyGold': 375,
#     'buffsStolen': 0,
#     'completeSupportQuestInTime': 0,
#     'controlWardsPlaced': 0,
#     'damagePerMinute': 1009.6148883577307,
#     'damageTakenOnTeamPercentage': 0.2679448633580565,
#     'dancedWithRiftHerald': 0,
#     'deathsByEnemyChamps': 9,
#     'dodgeSkillShotsSmallWindow': 13,
#     'doubleAces': 0,
#     'dragonTakedowns': 0,
#     'effectiveHealAndShielding': 0,
#     'elderDragonKillsWithOpposingSoul': 0,
#     'elderDragonMultikills': 0,
#     'enemyChampionImmobilizations': 57,
#     'enemyJungleMonsterKills': 0,
#     'epicMonsterKillsNearEnemyJungler': 0,
#     'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#     'epicMonsterSteals': 0,
#     'epicMonsterStolenWithoutSmite': 0,
#     'firstTurretKilled': 0,
#     'flawlessAces': 0,
#     'fullTeamTakedown': 12,
#     'gameLength': 1278.1046818,
#     'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#     'goldPerMinute': 722.4239995689452,
#     'hadOpenNexus': 0,
#     'immobilizeAndKillWithAlly': 18,
#     'initialBuffCount': 0,
#     'initialCrabCount': 0,
#     'jungleCsBefore10Minutes': 0,
#     'junglerTakedownsNearDamagedEpicMonster': 0,
#     'kTurretsDestroyedBeforePlatesFall': 0,
#     'kda': 4.222222222222222,
#     'killAfterHiddenWithAlly': 10,
#     'killParticipation': 0.76,
#     'killedChampTookFullTeamDamageSurvived': 0,
#     'killingSprees': 0,
#     'killsNearEnemyTurret': 3,
#     'killsOnOtherLanesEarlyJungleAsLaner': 0,
#     'killsOnRecentlyHealedByAramPack': 0,
#     'killsUnderOwnTurret': 0,
#     'killsWithHelpFromEpicMonster': 0,
#     'knockEnemyIntoTeamAndKill': 9,
#     'landSkillShotsEarlyGame': 4,
#     'laneMinionsFirst10Minutes': 13,
#     'legendaryCount': 0,
#     'lostAnInhibitor': 1,
#     'maxKillDeficit': 3,
#     'mejaisFullStackInTime': 0,
#     'moreEnemyJungleThanOpponent': 0,
#     'multiKillOneSpell': 0,
#     'multiTurretRiftHeraldCount': 0,
#     'multikills': 1,
#     'multikillsAfterAggressiveFlash': 0,
#     'mythicItemUsed': 6630,
#     'outerTurretExecutesBefore10Minutes': 0,
#     'outnumberedKills': 1,
#     'outnumberedNexusKill': 0,
#     'perfectDragonSoulsTaken': 0,
#     'perfectGame': 0,
#     'pickKillWithAlly': 20,
#     'poroExplosions': 0,
#     'quickCleanse': 0,
#     'quickFirstTurret': 0,
#     'quickSoloKills': 0,
#     'riftHeraldTakedowns': 0,
#     'saveAllyFromDeath': 0,
#     'scuttleCrabKills': 0,
#     'skillshotsDodged': 114,
#     'skillshotsHit': 14,
#     'snowballsHit': 10,
#     'soloBaronKills': 0,
#     'soloKills': 3,
#     'stealthWardsPlaced': 0,
#     'survivedSingleDigitHpCount': 0,
#     'survivedThreeImmobilizesInFight': 8,
#     'takedownOnFirstTurret': 0,
#     'takedowns': 38,
#     'takedownsAfterGainingLevelAdvantage': 0,
#     'takedownsBeforeJungleMinionSpawn': 0,
#     'takedownsFirstXMinutes': 25,
#     'takedownsInAlcove': 0,
#     'takedownsInEnemyFountain': 0,
#     'teamBaronKills': 0,
#     'teamDamagePercentage': 0.14984515868632076,
#     'teamElderDragonKills': 0,
#     'teamRiftHeraldKills': 0,
#     'tookLargeDamageSurvived': 1,
#     'turretPlatesTaken': 0,
#     'turretTakedowns': 2,
#     'turretsTakenWithRiftHerald': 0,
#     'twentyMinionsIn3SecondsCount': 0,
#     'twoWardsOneSweeperCount': 0,
#     'unseenRecalls': 0,
#     'visionScorePerMinute': 0,
#     'wardTakedowns': 0,
#     'wardTakedownsBefore20M': 0,
#     'wardsGuarded': 0},
#    'champExperience': 21521,
#    'champLevel': 18,
#    'championId': 92,
#    'championName': 'Riven',
#    'championTransform': 0,
#    'commandPings': 1,
#    'consumablesPurchased': 0,
#    'damageDealtToBuildings': 1205,
#    'damageDealtToObjectives': 1205,
#    'damageDealtToTurrets': 1205,
#    'damageSelfMitigated': 48348,
#    'dangerPings': 0,
#    'deaths': 9,
#    'detectorWardsPlaced': 0,
#    'doubleKills': 1,
#    'dragonKills': 0,
#    'eligibleForProgression': True,
#    'enemyMissingPings': 0,
#    'enemyVisionPings': 0,
#    'firstBloodAssist': False,
#    'firstBloodKill': False,
#    'firstTowerAssist': False,
#    'firstTowerKill': False,
#    'gameEndedInEarlySurrender': False,
#    'gameEndedInSurrender': False,
#    'getBackPings': 1,
#    'goldEarned': 15388,
#    'goldSpent': 13700,
#    'holdPings': 0,
#    'individualPosition': 'Invalid',
#    'inhibitorKills': 0,
#    'inhibitorTakedowns': 1,
#    'inhibitorsLost': 2,
#    'item0': 6630,
#    'item1': 3158,
#    'item2': 3071,
#    'item3': 3161,
#    'item4': 3156,
#    'item5': 1036,
#    'item6': 2052,
#    'itemsPurchased': 22,
#    'killingSprees': 3,
#    'kills': 9,
#    'lane': 'TOP',
#    'largestCriticalStrike': 0,
#    'largestKillingSpree': 2,
#    'largestMultiKill': 2,
#    'longestTimeSpentLiving': 195,
#    'magicDamageDealt': 0,
#    'magicDamageDealtToChampions': 0,
#    'magicDamageTaken': 15873,
#    'missions': {'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore10': 0,
#     'playerScore11': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0},
#    'needVisionPings': 0,
#    'neutralMinionsKilled': 0,
#    'nexusKills': 0,
#    'nexusLost': 0,
#    'nexusTakedowns': 0,
#    'objectivesStolen': 0,
#    'objectivesStolenAssists': 0,
#    'onMyWayPings': 0,
#    'participantId': 10,
#    'pentaKills': 0,
#    'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5008},
#     'styles': [{'description': 'primaryStyle',
#       'selections': [{'perk': 8010, 'var1': 255, 'var2': 0, 'var3': 0},
#        {'perk': 9111, 'var1': 2412, 'var2': 380, 'var3': 0},
#        {'perk': 9105, 'var1': 6, 'var2': 50, 'var3': 0},
#        {'perk': 8299, 'var1': 1128, 'var2': 0, 'var3': 0}],
#       'style': 8000},
#      {'description': 'subStyle',
#       'selections': [{'perk': 8139, 'var1': 1021, 'var2': 0, 'var3': 0},
#        {'perk': 8135, 'var1': 450, 'var2': 5, 'var3': 0}],
#       'style': 8100}]},
#    'physicalDamageDealt': 62214,
#    'physicalDamageDealtToChampions': 20598,
#    'physicalDamageTaken': 17996,
#    'placement': 0,
#    'playerAugment1': 0,
#    'playerAugment2': 0,
#    'playerAugment3': 0,
#    'playerAugment4': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore10': 0,
#    'playerScore11': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'playerSubteamId': 0,
#    'profileIcon': 4895,
#    'pushPings': 0,
#    'puuid': 'J4A8TTqRd2oQn2GWiJiMYiqLTV6z-lt1D1T3uOo4JNRWV2qlBdy1fJOQ3qK3fdLPktX4fMRmD3-3rQ',
#    'quadraKills': 0,
#    'riotIdGameName': '김도사입니다',
#    'riotIdTagline': 'KR1',
#    'role': 'SUPPORT',
#    'sightWardsBoughtInGame': 0,
#    'spell1Casts': 142,
#    'spell2Casts': 41,
#    'spell3Casts': 91,
#    'spell4Casts': 17,
#    'subteamPlacement': 0,
#    'summoner1Casts': 3,
#    'summoner1Id': 4,
#    'summoner2Casts': 25,
#    'summoner2Id': 32,
#    'summonerId': 'FUWBRx0c4qtHSBKRSj6gryZ5UDMNVZRMmiPNp45jqXKxIA',
#    'summonerLevel': 422,
#    'summonerName': '김도사입니다',
#    'teamEarlySurrendered': False,
#    'teamId': 200,
#    'teamPosition': '',
#    'timeCCingOthers': 36,
#    'timePlayed': 1278,
#    'totalAllyJungleMinionsKilled': 0,
#    'totalDamageDealt': 65552,
#    'totalDamageDealtToChampions': 21506,
#    'totalDamageShieldedOnTeammates': 0,
#    'totalDamageTaken': 34402,
#    'totalEnemyJungleMinionsKilled': 0,
#    'totalHeal': 9524,
#    'totalHealsOnTeammates': 0,
#    'totalMinionsKilled': 47,
#    'totalTimeCCDealt': 61,
#    'totalTimeSpentDead': 224,
#    'totalUnitsHealed': 1,
#    'tripleKills': 0,
#    'trueDamageDealt': 3338,
#    'trueDamageDealtToChampions': 908,
#    'trueDamageTaken': 532,
#    'turretKills': 0,
#    'turretTakedowns': 2,
#    'turretsLost': 2,
#    'unrealKills': 0,
#    'visionClearedPings': 0,
#    'visionScore': 0,
#    'visionWardsBoughtInGame': 0,
#    'wardsKilled': 0,
#    'wardsPlaced': 0,
#    'win': True}],
#  'platformId': 'KR',
#  'queueId': 450,
#  'teams': [{'bans': [],
#    'objectives': {'baron': {'first': False, 'kills': 0},
#     'champion': {'first': False, 'kills': 42},
#     'dragon': {'first': False, 'kills': 0},
#     'horde': {'first': False, 'kills': 0},
#     'inhibitor': {'first': True, 'kills': 2},
#     'riftHerald': {'first': False, 'kills': 0},
#     'tower': {'first': True, 'kills': 2}},
#    'teamId': 100,
#    'win': False},
#   {'bans': [],
#    'objectives': {'baron': {'first': False, 'kills': 0},
#     'champion': {'first': True, 'kills': 51},
#     'dragon': {'first': False, 'kills': 0},
#     'horde': {'first': False, 'kills': 0},
#     'inhibitor': {'first': False, 'kills': 2},
#     'riftHerald': {'first': False, 'kills': 0},
#     'tower': {'first': False, 'kills': 4}},
#    'teamId': 200,
#    'win': True}],
#  'tournamentCode': ''}

# %%
df.iloc[0].matches['info']['participants'][0]
# Out:
# {'allInPings': 0,
#  'assistMePings': 0,
#  'assists': 14,
#  'baitPings': 0,
#  'baronKills': 0,
#  'basicPings': 0,
#  'bountyLevel': 0,
#  'challenges': {'12AssistStreakCount': 0,
#   'abilityUses': 230,
#   'acesBefore15Minutes': 2,
#   'alliedJungleMonsterKills': 0,
#   'baronTakedowns': 0,
#   'blastConeOppositeOpponentCount': 0,
#   'bountyGold': 900,
#   'buffsStolen': 0,
#   'completeSupportQuestInTime': 0,
#   'controlWardsPlaced': 0,
#   'damagePerMinute': 1157.8695984458288,
#   'damageTakenOnTeamPercentage': 0.1795998404272442,
#   'dancedWithRiftHerald': 0,
#   'deathsByEnemyChamps': 11,
#   'dodgeSkillShotsSmallWindow': 0,
#   'doubleAces': 0,
#   'dragonTakedowns': 0,
#   'effectiveHealAndShielding': 0,
#   'elderDragonKillsWithOpposingSoul': 0,
#   'elderDragonMultikills': 0,
#   'enemyChampionImmobilizations': 37,
#   'enemyJungleMonsterKills': 0,
#   'epicMonsterKillsNearEnemyJungler': 0,
#   'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#   'epicMonsterSteals': 0,
#   'epicMonsterStolenWithoutSmite': 0,
#   'firstTurretKilled': 1,
#   'firstTurretKilledTime': 555.5397561,
#   'flawlessAces': 2,
#   'fullTeamTakedown': 5,
#   'gameLength': 1278.1046818,
#   'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#   'goldPerMinute': 708.2313534122522,
#   'hadOpenNexus': 0,
#   'immobilizeAndKillWithAlly': 12,
#   'initialBuffCount': 0,
#   'initialCrabCount': 0,
#   'jungleCsBefore10Minutes': 0,
#   'junglerTakedownsNearDamagedEpicMonster': 0,
#   'kTurretsDestroyedBeforePlatesFall': 2,
#   'kda': 2.0833333333333335,
#   'killAfterHiddenWithAlly': 10,
#   'killParticipation': 0.5952380952380952,
#   'killedChampTookFullTeamDamageSurvived': 0,
#   'killingSprees': 2,
#   'killsNearEnemyTurret': 0,
#   'killsOnOtherLanesEarlyJungleAsLaner': 0,
#   'killsOnRecentlyHealedByAramPack': 0,
#   'killsUnderOwnTurret': 4,
#   'killsWithHelpFromEpicMonster': 0,
#   'knockEnemyIntoTeamAndKill': 0,
#   'landSkillShotsEarlyGame': 9,
#   'laneMinionsFirst10Minutes': 38,
#   'legendaryCount': 0,
#   'lostAnInhibitor': 0,
#   'maxKillDeficit': 0,
#   'mejaisFullStackInTime': 0,
#   'moreEnemyJungleThanOpponent': 0,
#   'multiKillOneSpell': 0,
#   'multiTurretRiftHeraldCount': 0,
#   'multikills': 4,
#   'multikillsAfterAggressiveFlash': 2,
#   'mythicItemUsed': 3031,
#   'outerTurretExecutesBefore10Minutes': 0,
#   'outnumberedKills': 3,
#   'outnumberedNexusKill': 0,
#   'perfectDragonSoulsTaken': 0,
#   'perfectGame': 0,
#   'pickKillWithAlly': 17,
#   'poroExplosions': 0,
#   'quickCleanse': 0,
#   'quickFirstTurret': 1,
#   'quickSoloKills': 0,
#   'riftHeraldTakedowns': 0,
#   'saveAllyFromDeath': 0,
#   'scuttleCrabKills': 0,
#   'shortestTimeToAceFromFirstTakedown': 8.026302200000032,
#   'skillshotsDodged': 15,
#   'skillshotsHit': 21,
#   'snowballsHit': 9,
#   'soloBaronKills': 0,
#   'soloKills': 1,
#   'stealthWardsPlaced': 0,
#   'survivedSingleDigitHpCount': 0,
#   'survivedThreeImmobilizesInFight': 0,
#   'takedownOnFirstTurret': 0,
#   'takedowns': 25,
#   'takedownsAfterGainingLevelAdvantage': 0,
#   'takedownsBeforeJungleMinionSpawn': 0,
#   'takedownsFirstXMinutes': 21,
#   'takedownsInAlcove': 0,
#   'takedownsInEnemyFountain': 0,
#   'teamBaronKills': 0,
#   'teamDamagePercentage': 0.2049339270981659,
#   'teamElderDragonKills': 0,
#   'teamRiftHeraldKills': 0,
#   'tookLargeDamageSurvived': 0,
#   'turretPlatesTaken': 0,
#   'turretTakedowns': 2,
#   'turretsTakenWithRiftHerald': 0,
#   'twentyMinionsIn3SecondsCount': 0,
#   'twoWardsOneSweeperCount': 0,
#   'unseenRecalls': 0,
#   'visionScorePerMinute': 0,
#   'wardTakedowns': 0,
#   'wardTakedownsBefore20M': 0,
#   'wardsGuarded': 0},
#  'champExperience': 17301,
#  'champLevel': 17,
#  'championId': 157,
#  'championName': 'Yasuo',
#  'championTransform': 0,
#  'commandPings': 8,
#  'consumablesPurchased': 2,
#  'damageDealtToBuildings': 2502,
#  'damageDealtToObjectives': 2502,
#  'damageDealtToTurrets': 2502,
#  'damageSelfMitigated': 38323,
#  'dangerPings': 0,
#  'deaths': 12,
#  'detectorWardsPlaced': 0,
#  'doubleKills': 2,
#  'dragonKills': 0,
#  'eligibleForProgression': True,
#  'enemyMissingPings': 0,
#  'enemyVisionPings': 0,
#  'firstBloodAssist': False,
#  'firstBloodKill': False,
#  'firstTowerAssist': True,
#  'firstTowerKill': False,
#  'gameEndedInEarlySurrender': False,
#  'gameEndedInSurrender': False,
#  'getBackPings': 1,
#  'goldEarned': 15086,
#  'goldSpent': 14900,
#  'holdPings': 0,
#  'individualPosition': 'Invalid',
#  'inhibitorKills': 1,
#  'inhibitorTakedowns': 1,
#  'inhibitorsLost': 2,
#  'item0': 6672,
#  'item1': 3006,
#  'item2': 6333,
#  'item3': 3031,
#  'item4': 3156,
#  'item5': 1053,
#  'item6': 0,
#  'itemsPurchased': 19,
#  'killingSprees': 2,
#  'kills': 11,
#  'lane': 'TOP',
#  'largestCriticalStrike': 746,
#  'largestKillingSpree': 4,
#  'largestMultiKill': 4,
#  'longestTimeSpentLiving': 136,
#  'magicDamageDealt': 5078,
#  'magicDamageDealtToChampions': 830,
#  'magicDamageTaken': 10062,
#  'missions': {'playerScore0': 0,
#   'playerScore1': 0,
#   'playerScore10': 0,
#   'playerScore11': 0,
#   'playerScore2': 0,
#   'playerScore3': 0,
#   'playerScore4': 0,
#   'playerScore5': 0,
#   'playerScore6': 0,
#   'playerScore7': 0,
#   'playerScore8': 0,
#   'playerScore9': 0},
#  'needVisionPings': 0,
#  'neutralMinionsKilled': 0,
#  'nexusKills': 0,
#  'nexusLost': 1,
#  'nexusTakedowns': 0,
#  'objectivesStolen': 0,
#  'objectivesStolenAssists': 0,
#  'onMyWayPings': 1,
#  'participantId': 1,
#  'pentaKills': 0,
#  'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#   'styles': [{'description': 'primaryStyle',
#     'selections': [{'perk': 8008, 'var1': 23, 'var2': 1, 'var3': 0},
#      {'perk': 9111, 'var1': 1001, 'var2': 250, 'var3': 0},
#      {'perk': 9104, 'var1': 7, 'var2': 0, 'var3': 0},
#      {'perk': 8014, 'var1': 908, 'var2': 0, 'var3': 0}],
#     'style': 8000},
#    {'description': 'subStyle',
#     'selections': [{'perk': 8139, 'var1': 815, 'var2': 0, 'var3': 0},
#      {'perk': 8134, 'var1': 4, 'var2': 5, 'var3': 0}],
#     'style': 8100}]},
#  'physicalDamageDealt': 77126,
#  'physicalDamageDealtToChampions': 22729,
#  'physicalDamageTaken': 12974,
#  'placement': 0,
#  'playerAugment1': 0,
#  'playerAugment2': 0,
#  'playerAugment3': 0,
#  'playerAugment4': 0,
#  'playerScore0': 0,
#  'playerScore1': 0,
#  'playerScore10': 0,
#  'playerScore11': 0,
#  'playerScore2': 0,
#  'playerScore3': 0,
#  'playerScore4': 0,
#  'playerScore5': 0,
#  'playerScore6': 0,
#  'playerScore7': 0,
#  'playerScore8': 0,
#  'playerScore9': 0,
#  'playerSubteamId': 0,
#  'profileIcon': 5410,
#  'pushPings': 0,
#  'puuid': 'bjJDDKsW5VHeRhyJBXWUGpdGAilokAL9ejp63Epj-ihXTyUCBctLsf0Ly_84aAqTdhW-k8lDfwjKjg',
#  'quadraKills': 1,
#  'riotIdGameName': '무악동불지옥',
#  'riotIdTagline': 'KR1',
#  'role': 'SUPPORT',
#  'sightWardsBoughtInGame': 0,
#  'spell1Casts': 151,
#  'spell2Casts': 17,
#  'spell3Casts': 55,
#  'spell4Casts': 7,
#  'subteamPlacement': 0,
#  'summoner1Casts': 17,
#  'summoner1Id': 32,
#  'summoner2Casts': 4,
#  'summoner2Id': 4,
#  'summonerId': 'DSAJu7ujwROCeqC6l52f1um-ZCn6CZwtgMXTEBgY7S4B5hQ',
#  'summonerLevel': 298,
#  'summonerName': '무악동불지옥',
#  'teamEarlySurrendered': False,
#  'teamId': 100,
#  'teamPosition': '',
#  'timeCCingOthers': 34,
#  'timePlayed': 1278,
#  'totalAllyJungleMinionsKilled': 0,
#  'totalDamageDealt': 83309,
#  'totalDamageDealtToChampions': 24664,
#  'totalDamageShieldedOnTeammates': 0,
#  'totalDamageTaken': 26915,
#  'totalEnemyJungleMinionsKilled': 0,
#  'totalHeal': 2476,
#  'totalHealsOnTeammates': 0,
#  'totalMinionsKilled': 74,
#  'totalTimeCCDealt': 114,
#  'totalTimeSpentDead': 286,
#  'totalUnitsHealed': 1,
#  'tripleKills': 1,
#  'trueDamageDealt': 1104,
#  'trueDamageDealtToChampions': 1104,
#  'trueDamageTaken': 3878,
#  'turretKills': 0,
#  'turretTakedowns': 2,
#  'turretsLost': 4,
#  'unrealKills': 0,
#  'visionClearedPings': 0,
#  'visionScore': 0,
#  'visionWardsBoughtInGame': 0,
#  'wardsKilled': 0,
#  'wardsPlaced': 0,
#  'win': False}

# %%
df.iloc[0]
# Out:
# match_id                                         KR_6817651119
# matches      {'metadata': {'dataVersion': '2', 'matchId': '...
# timelines    {'metadata': {'dataVersion': '2', 'matchId': '...
# Name: 0, dtype: object

# %%
df.iloc[0].timelines['info']['frames'][3]['participantFrames']['10']['totalGold']
# Out:
# 2565

# %% [markdown]
# # matchid , participantsid, g5~g15분 데이터프레임 만들기

# %%
columns = ['matchId','participantId','g5','g6','g7','g8','g9']

# %%
lst = []
for i in range(len(df)):
    timeline = df.iloc[i].timelines['info']['frames'][0]['participantFrames']
    for j in range(len(timeline)):
        tmp = []
        match_id = df.iloc[i].match_id
        tmp.append(match_id)
        participant_id = df.iloc[i].timelines['info']['participants'][j]['participantId']
        tmp.append(participant_id)
        for k in range(5,10):
            tmp.append(df.iloc[i].timelines['info']['frames'][k]['participantFrames'][str(j+1)]['totalGold'])
        lst.append(tmp)
df3 = pd.DataFrame(lst,columns =columns)

# %%
df2.matchId
# Out:
# 0      KR_6817651119
# 1      KR_6817651119
# 2      KR_6817651119
# 3      KR_6817651119
# 4      KR_6817651119
#            ...
# 349    KR_6859088545
# 350    KR_6859088545
# 351    KR_6859088545
# 352    KR_6859088545
# 353    KR_6859088545
# Name: matchId, Length: 354, dtype: object

# %%
df3
# Out:
#            matchId  participantId    g5    g6    g7    g8    g9
# 0    KR_6817651119              1  3842  4281  5122  6141  6841
# 1    KR_6817651119              2  3395  3845  4305  4863  5520
# 2    KR_6817651119              3  4826  5375  5894  6375  7005
# 3    KR_6817651119              4  3751  4276  4736  5299  6974
# 4    KR_6817651119              5  3426  3876  4336  4848  5373
# ..             ...            ...   ...   ...   ...   ...   ...
# 349  KR_6859088545              4  2760  5535  6185  6535  6885
# 350  KR_6859088545              5  2355  5105  5705  5705  6055
# 351  KR_6859088545              6  2350  5100  5700  5700  6050
# 352  KR_6859088545              7  2715  5465  6075  6450  6450
# 353  KR_6859088545              8  2705  5455  6055  6415  6415
#
# [354 rows x 7 columns]

# %%
pd.merge(df2,df3,on = ['matchId','participantId'])
# Out:
#            matchId  gameDuration     gameVersion riotIdGameName riotIdTagline  \
# 0    KR_6817651119          1278  13.23.544.5515         무악동불지옥           KR1
# 1    KR_6817651119          1278  13.23.544.5515          탑1452           KR1
# 2    KR_6817651119          1278  13.23.544.5515        Dante J           KR1
# 3    KR_6817651119          1278  13.23.544.5515            알민강           KR1
# 4    KR_6817651119          1278  13.23.544.5515           고담시티           KR1
# ..             ...           ...             ...            ...           ...
# 349  KR_6859088545          1272  13.24.547.9214       도둑고양이성지훈           KR1
# 350  KR_6859088545          1272  13.24.547.9214        멋지다 에스파           KR1
# 351  KR_6859088545          1272  13.24.547.9214          난허선도임           KR1
# 352  KR_6859088545          1272  13.24.547.9214          Lee하루           KR1
# 353  KR_6859088545          1272  13.24.547.9214            이대영          5900
#
#      summonerLevel  participantId championName  champExperience teamPosition  \
# 0              298              1        Yasuo            17301
# 1              476              2          Zac            19000
# 2              550              3     Aphelios            18088
# 3              249              4    Lissandra            19582
# 4              208              5         Lulu            20702
# ..             ...            ...          ...              ...          ...
# 349             91              4       Illaoi            17000
# 350            424              5        Teemo            12546
# 351            144              6        Shaco            12500
# 352            429              7         Ornn            17000
# 353            329              8        Briar            17000
#
#      ...  kills  deaths  assists  totalDamageDealtToChampions  \
# 0    ...     11      12       14                        24664
# 1    ...      3      12       25                        18848
# 2    ...     14      10       14                        39687
# 3    ...     12      12       20                        29534
# 4    ...      2       5       31                         7619
# ..   ...    ...     ...      ...                          ...
# 349  ...      8       9       12                        54749
# 350  ...      4       7        4                        33018
# 351  ...      4       7        4                        17967
# 352  ...      8       5        9                        46420
# 353  ...      8      13        4                        47126
#
#      totalDamageTaken    g5    g6    g7    g8    g9
# 0               26915  3842  4281  5122  6141  6841
# 1               53985  3395  3845  4305  4863  5520
# 2               25271  4826  5375  5894  6375  7005
# 3               30490  3751  4276  4736  5299  6974
# 4               13199  3426  3876  4336  4848  5373
# ..                ...   ...   ...   ...   ...   ...
# 349             90925  2760  5535  6185  6535  6885
# 350             18172  2355  5105  5705  5705  6055
# 351             14457  2350  5100  5700  5700  6050
# 352             75473  2715  5465  6075  6450  6450
# 353             38180  2705  5455  6055  6415  6415
#
# [354 rows x 22 columns]

# %%
tmp = df[:5]

# %%
tmp
# Out:
#         match_id                                            matches  \
# 0  KR_6851524682  {'metadata': {'dataVersion': '2', 'matchId': '...
# 1  KR_6851451412  {'metadata': {'dataVersion': '2', 'matchId': '...
# 2  KR_6851341004  {'metadata': {'dataVersion': '2', 'matchId': '...
# 3  KR_6853023010  {'metadata': {'dataVersion': '2', 'matchId': '...
# 4  KR_6852954512  {'metadata': {'dataVersion': '2', 'matchId': '...
#
#                                            timelines
# 0  {'metadata': {'dataVersion': '2', 'matchId': '...
# 1  {'metadata': {'dataVersion': '2', 'matchId': '...
# 2  {'metadata': {'dataVersion': '2', 'matchId': '...
# 3  {'metadata': {'dataVersion': '2', 'matchId': '...
# 4  {'metadata': {'dataVersion': '2', 'matchId': '...

# %%
tmp.iloc[0].matches['info']['teams'][0]['bans']
# Out:
# [{'championId': 134, 'pickTurn': 1},
#  {'championId': 25, 'pickTurn': 2},
#  {'championId': 7, 'pickTurn': 3},
#  {'championId': 910, 'pickTurn': 4},
#  {'championId': 34, 'pickTurn': 5}]

# %% [markdown]
# # lambda를 활용해서 blue_ban 리스트 생성
#
# # lambda를 활용해서 red_ban 리스트 생성
#
# # blue_ban + red_ban
#
# # 합친 리스트의 중복을 제거

# %%
blue_ban = list(map(lambda x :str(x['championId']) ,df.iloc[6].matches['info']['teams'][0]['bans']))

red_ban = list(map(lambda x :str(x['championId']) ,df.iloc[6].matches['info']['teams'][1]['bans']))

# %%
blue_ban
# Out:
# ['84', '7', '48', '122', '777']

# %%
red_ban
# Out:
# ['233', '122', '53', '166', '25']

# %%
ban_list = blue_ban + red_ban

# %%
ban_list = list(set(ban_list))

# %%
ban_list
# Out:
# ['777', '122', '48', '7', '53', '166', '25', '233', '84']

# %%
ban_list_str = '|'.join(ban_list)

# %%
ban_list_str.split('|')
# Out:
# ['777', '122', '48', '7', '53', '166', '25', '233', '84']

# %%
tmp.iloc[0].timelines['info']['frames'][16]
# Out:
# {'events': [{'itemId': 3067,
#    'participantId': 3,
#    'timestamp': 903524,
#    'type': 'ITEM_DESTROYED'},
#   {'itemId': 4642,
#    'participantId': 3,
#    'timestamp': 903524,
#    'type': 'ITEM_DESTROYED'},
#   {'itemId': 2065,
#    'participantId': 3,
#    'timestamp': 903524,
#    'type': 'ITEM_PURCHASED'},
#   {'itemId': 1058,
#    'participantId': 7,
#    'timestamp': 905027,
#    'type': 'ITEM_PURCHASED'},
#   {'killerId': 10,
#    'timestamp': 905462,
#    'type': 'WARD_KILL',
#    'wardType': 'CONTROL_WARD'},
#   {'level': 10, 'participantId': 9, 'timestamp': 906030, 'type': 'LEVEL_UP'},
#   {'levelUpType': 'NORMAL',
#    'participantId': 9,
#    'skillSlot': 1,
#    'timestamp': 906970,
#    'type': 'SKILL_LEVEL_UP'},
#   {'itemId': 2055,
#    'participantId': 10,
#    'timestamp': 907870,
#    'type': 'ITEM_DESTROYED'},
#   {'creatorId': 10,
#    'timestamp': 907870,
#    'type': 'WARD_PLACED',
#    'wardType': 'CONTROL_WARD'},
#   {'itemId': 3133,
#    'participantId': 6,
#    'timestamp': 908269,
#    'type': 'ITEM_DESTROYED'},
#   {'itemId': 3057,
#    'participantId': 6,
#    'timestamp': 908269,
#    'type': 'ITEM_DESTROYED'},
#   {'itemId': 3067,
#    'participantId': 6,
#    'timestamp': 908269,
#    'type': 'ITEM_DESTROYED'},
#   {'itemId': 6632,
#    'participantId': 6,
#    'timestamp': 908269,
#    'type': 'ITEM_PURCHASED'},
#   {'killerId': 10,
#    'timestamp': 912270,
#    'type': 'WARD_KILL',
#    'wardType': 'SIGHT_WARD'},
#   {'assistingParticipantIds': [10],
#    'bounty': 300,
#    'killStreakLength': 1,
#    'killerId': 9,
#    'position': {'x': 10453, 'y': 1196},
#    'shutdownBounty': 0,
#    'timestamp': 918832,
#    'type': 'CHAMPION_KILL',
#    'victimDamageDealt': [{'basic': False,
#      'magicDamage': 0,
#      'name': 'JarvanIV',
#      'participantId': 9,
#      'physicalDamage': 0,
#      'spellName': '6630active',
#      'spellSlot': 6,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'JarvanIV',
#      'participantId': 9,
#      'physicalDamage': 19,
#      'spellName': 'jarvanivmartialcadence',
#      'spellSlot': 63,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'JarvanIV',
#      'participantId': 9,
#      'physicalDamage': 108,
#      'spellName': 'jarvanivmartialcadence',
#      'spellSlot': 63,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'JarvanIV',
#      'participantId': 9,
#      'physicalDamage': 202,
#      'spellName': 'jarvanivcataclysm',
#      'spellSlot': 3,
#      'trueDamage': 0,
#      'type': 'OTHER'}],
#    'victimDamageReceived': [{'basic': False,
#      'magicDamage': 0,
#      'name': 'Vayne',
#      'participantId': 9,
#      'physicalDamage': 464,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Vayne',
#      'participantId': 9,
#      'physicalDamage': 178,
#      'spellName': 'vaynebasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Vayne',
#      'participantId': 9,
#      'physicalDamage': 312,
#      'spellName': 'vaynecritattack',
#      'spellSlot': 73,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Vayne',
#      'participantId': 9,
#      'physicalDamage': 85,
#      'spellName': 'vaynebasicattack3',
#      'spellSlot': 66,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Vayne',
#      'participantId': 9,
#      'physicalDamage': 0,
#      'spellName': 'vaynesilveredbolts',
#      'spellSlot': 1,
#      'trueDamage': 581,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Vayne',
#      'participantId': 9,
#      'physicalDamage': 0,
#      'spellName': 'vaynecondemn',
#      'spellSlot': 2,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Vayne',
#      'participantId': 9,
#      'physicalDamage': 85,
#      'spellName': 'vaynebasicattack2',
#      'spellSlot': 65,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Vayne',
#      'participantId': 9,
#      'physicalDamage': 173,
#      'spellName': 'vaynetumble',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Vayne',
#      'participantId': 9,
#      'physicalDamage': 92,
#      'spellName': 'vaynebasicattack4',
#      'spellSlot': 67,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'SRU_ChaosMinionMelee',
#      'participantId': 0,
#      'physicalDamage': 44,
#      'spellName': 'sru_chaosminionrangedbasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'MINION'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'SRU_ChaosMinionMelee',
#      'participantId': 0,
#      'physicalDamage': 32,
#      'spellName': 'sru_chaosminionmeleebasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'MINION'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'SRU_ChaosMinionMelee',
#      'participantId': 0,
#      'physicalDamage': 14,
#      'spellName': 'sru_chaosminionrangedbasicattack2',
#      'spellSlot': 65,
#      'trueDamage': 0,
#      'type': 'MINION'},
#     {'basic': False,
#      'magicDamage': 156,
#      'name': 'Lulu',
#      'participantId': 10,
#      'physicalDamage': 0,
#      'spellName': 'lulue',
#      'spellSlot': 2,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 78,
#      'name': 'Lulu',
#      'participantId': 10,
#      'physicalDamage': 0,
#      'spellName': 'luluq',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 38,
#      'name': 'Lulu',
#      'participantId': 10,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'}],
#    'victimId': 4},
#   {'bounty': 300,
#    'killStreakLength': 2,
#    'killerId': 8,
#    'position': {'x': 9591, 'y': 6226},
#    'shutdownBounty': 0,
#    'timestamp': 926203,
#    'type': 'CHAMPION_KILL',
#    'victimDamageDealt': [{'basic': False,
#      'magicDamage': 0,
#      'name': 'Kindred',
#      'participantId': 8,
#      'physicalDamage': 0,
#      'spellName': 'burning',
#      'spellSlot': -1,
#      'trueDamage': 40,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 184,
#      'name': 'Kindred',
#      'participantId': 8,
#      'physicalDamage': 0,
#      'spellName': 'kindredw',
#      'spellSlot': 1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Kindred',
#      'participantId': 8,
#      'physicalDamage': 94,
#      'spellName': 'kindredq',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Kindred',
#      'participantId': 8,
#      'physicalDamage': 0,
#      'spellName': 's5_summonersmiteplayerganker',
#      'spellSlot': 5,
#      'trueDamage': 40,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Kindred',
#      'participantId': 8,
#      'physicalDamage': 0,
#      'spellName': 'kindredewrapper',
#      'spellSlot': 2,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Kindred',
#      'participantId': 8,
#      'physicalDamage': 247,
#      'spellName': 'kindredpassivemanager',
#      'spellSlot': 63,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Kindred',
#      'participantId': 8,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Kindred',
#      'participantId': 8,
#      'physicalDamage': 57,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'}],
#    'victimDamageReceived': [{'basic': True,
#      'magicDamage': 0,
#      'name': 'Naafiri',
#      'participantId': 8,
#      'physicalDamage': 127,
#      'spellName': 'naafiriw',
#      'spellSlot': 1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Naafiri',
#      'participantId': 8,
#      'physicalDamage': 133,
#      'spellName': 'naafiriw',
#      'spellSlot': 1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Naafiri',
#      'participantId': 8,
#      'physicalDamage': 160,
#      'spellName': '',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Naafiri',
#      'participantId': 8,
#      'physicalDamage': 379,
#      'spellName': 'naafirip',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Naafiri',
#      'participantId': 8,
#      'physicalDamage': 50,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Naafiri',
#      'participantId': 8,
#      'physicalDamage': 254,
#      'spellName': 'naafiribasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Naafiri',
#      'participantId': 8,
#      'physicalDamage': 222,
#      'spellName': 'naafirie',
#      'spellSlot': 2,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Naafiri',
#      'participantId': 8,
#      'physicalDamage': 0,
#      'spellName': 'summonerdot',
#      'spellSlot': 4,
#      'trueDamage': 54,
#      'type': 'OTHER'}],
#    'victimId': 1},
#   {'assistingParticipantIds': [7],
#    'bounty': 274,
#    'killStreakLength': 3,
#    'killerId': 8,
#    'position': {'x': 8937, 'y': 6221},
#    'shutdownBounty': 0,
#    'timestamp': 931644,
#    'type': 'CHAMPION_KILL',
#    'victimDamageDealt': [{'basic': False,
#      'magicDamage': 0,
#      'name': 'Sylas',
#      'participantId': 8,
#      'physicalDamage': 0,
#      'spellName': '6656cast',
#      'spellSlot': 7,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 55,
#      'name': 'Sylas',
#      'participantId': 8,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 138,
#      'name': 'Sylas',
#      'participantId': 8,
#      'physicalDamage': 0,
#      'spellName': 'sylase2',
#      'spellSlot': 2,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 236,
#      'name': 'Sylas',
#      'participantId': 8,
#      'physicalDamage': 0,
#      'spellName': 'sylaspassive',
#      'spellSlot': 63,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 196,
#      'name': 'Sylas',
#      'participantId': 8,
#      'physicalDamage': 0,
#      'spellName': 'sylasw',
#      'spellSlot': 1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 103,
#      'name': 'Sylas',
#      'participantId': 8,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Sylas',
#      'participantId': 8,
#      'physicalDamage': 0,
#      'spellName': 'sylasq',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'}],
#    'victimDamageReceived': [{'basic': False,
#      'magicDamage': 0,
#      'name': 'Naafiri',
#      'participantId': 8,
#      'physicalDamage': 75,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Naafiri',
#      'participantId': 8,
#      'physicalDamage': 284,
#      'spellName': 'naafirip',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Naafiri',
#      'participantId': 8,
#      'physicalDamage': 664,
#      'spellName': '',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Naafiri',
#      'participantId': 8,
#      'physicalDamage': 0,
#      'spellName': 'burning',
#      'spellSlot': -1,
#      'trueDamage': 40,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Naafiri',
#      'participantId': 8,
#      'physicalDamage': 122,
#      'spellName': 'naafiribasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 84,
#      'name': 'Taliyah',
#      'participantId': 7,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 24,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 542,
#      'name': 'Taliyah',
#      'participantId': 7,
#      'physicalDamage': 0,
#      'spellName': 'taliyahq',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 91,
#      'name': 'Taliyah',
#      'participantId': 7,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 159,
#      'name': 'Taliyah',
#      'participantId': 7,
#      'physicalDamage': 0,
#      'spellName': 'taliyahe',
#      'spellSlot': 2,
#      'trueDamage': 0,
#      'type': 'OTHER'}],
#    'victimId': 5},
#   {'killType': 'KILL_MULTI',
#    'killerId': 8,
#    'multiKillLength': 2,
#    'position': {'x': 8454, 'y': 6350},
#    'timestamp': 931644,
#    'type': 'CHAMPION_SPECIAL_KILL'},
#   {'level': 9, 'participantId': 7, 'timestamp': 931644, 'type': 'LEVEL_UP'},
#   {'levelUpType': 'NORMAL',
#    'participantId': 7,
#    'skillSlot': 1,
#    'timestamp': 934916,
#    'type': 'SKILL_LEVEL_UP'},
#   {'assistingParticipantIds': [2],
#    'bounty': 300,
#    'killStreakLength': 0,
#    'killerId': 3,
#    'position': {'x': 12844, 'y': 2607},
#    'shutdownBounty': 150,
#    'timestamp': 943254,
#    'type': 'CHAMPION_KILL',
#    'victimDamageDealt': [{'basic': False,
#      'magicDamage': 0,
#      'name': 'Vayne',
#      'participantId': 2,
#      'physicalDamage': 138,
#      'spellName': 'vaynecondemn',
#      'spellSlot': 2,
#      'trueDamage': 0,
#      'type': 'OTHER'}],
#    'victimDamageReceived': [{'basic': False,
#      'magicDamage': 214,
#      'name': 'Blitzcrank',
#      'participantId': 3,
#      'physicalDamage': 0,
#      'spellName': 'staticfield',
#      'spellSlot': 3,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'SRU_OrderMinionSiege',
#      'participantId': 0,
#      'physicalDamage': 0,
#      'spellName': 'sru_orderminionrangedbasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'MINION'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'SRU_OrderMinionSiege',
#      'participantId': 0,
#      'physicalDamage': 31,
#      'spellName': 'sru_orderminionsiegebasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'MINION'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'SRU_OrderMinionSiege',
#      'participantId': 0,
#      'physicalDamage': 30,
#      'spellName': 'sru_orderminionrangedbasicattack2',
#      'spellSlot': 65,
#      'trueDamage': 0,
#      'type': 'MINION'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Ashe',
#      'participantId': 2,
#      'physicalDamage': 0,
#      'spellName': 'enchantedcrystalarrow',
#      'spellSlot': 3,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Ashe',
#      'participantId': 2,
#      'physicalDamage': 124,
#      'spellName': 'volley',
#      'spellSlot': 1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Ashe',
#      'participantId': 2,
#      'physicalDamage': 252,
#      'spellName': 'ashebasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'OTHER'}],
#    'victimId': 9},
#   {'level': 8, 'participantId': 3, 'timestamp': 943254, 'type': 'LEVEL_UP'},
#   {'itemId': 1036,
#    'participantId': 8,
#    'timestamp': 944756,
#    'type': 'ITEM_DESTROYED'},
#   {'itemId': 1036,
#    'participantId': 8,
#    'timestamp': 944756,
#    'type': 'ITEM_DESTROYED'},
#   {'itemId': 3134,
#    'participantId': 8,
#    'timestamp': 944756,
#    'type': 'ITEM_PURCHASED'},
#   {'itemId': 1055,
#    'participantId': 9,
#    'timestamp': 947233,
#    'type': 'ITEM_SOLD'},
#   {'levelUpType': 'NORMAL',
#    'participantId': 3,
#    'skillSlot': 3,
#    'timestamp': 947332,
#    'type': 'SKILL_LEVEL_UP'},
#   {'itemId': 3057,
#    'participantId': 9,
#    'timestamp': 947799,
#    'type': 'ITEM_DESTROYED'},
#   {'itemId': 3051,
#    'participantId': 9,
#    'timestamp': 947799,
#    'type': 'ITEM_DESTROYED'},
#   {'itemId': 3078,
#    'participantId': 9,
#    'timestamp': 947799,
#    'type': 'ITEM_PURCHASED'},
#   {'itemId': 1018,
#    'participantId': 8,
#    'timestamp': 949336,
#    'type': 'ITEM_PURCHASED'},
#   {'itemId': 3051,
#    'participantId': 1,
#    'timestamp': 951642,
#    'type': 'ITEM_PURCHASED'},
#   {'itemId': 3057,
#    'participantId': 1,
#    'timestamp': 951907,
#    'type': 'ITEM_PURCHASED'},
#   {'assistingParticipantIds': [3],
#    'bounty': 300,
#    'killStreakLength': 0,
#    'killerId': 2,
#    'position': {'x': 13492, 'y': 3773},
#    'shutdownBounty': 0,
#    'timestamp': 951975,
#    'type': 'CHAMPION_KILL',
#    'victimDamageDealt': [{'basic': False,
#      'magicDamage': 84,
#      'name': 'Lulu',
#      'participantId': 2,
#      'physicalDamage': 0,
#      'spellName': 'luluq',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 41,
#      'name': 'Lulu',
#      'participantId': 2,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Lulu',
#      'participantId': 3,
#      'physicalDamage': 0,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Lulu',
#      'participantId': 3,
#      'physicalDamage': 35,
#      'spellName': 'lulubasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'OTHER'}],
#    'victimDamageReceived': [{'basic': False,
#      'magicDamage': 72,
#      'name': 'Ashe',
#      'participantId': 2,
#      'physicalDamage': 0,
#      'spellName': 'enchantedcrystalarrow',
#      'spellSlot': 3,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Ashe',
#      'participantId': 2,
#      'physicalDamage': 530,
#      'spellName': 'asheq',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Ashe',
#      'participantId': 2,
#      'physicalDamage': 78,
#      'spellName': 'volley',
#      'spellSlot': 1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Ashe',
#      'participantId': 2,
#      'physicalDamage': 293,
#      'spellName': '',
#      'spellSlot': -1,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Ashe',
#      'participantId': 2,
#      'physicalDamage': 155,
#      'spellName': 'ashebasicattack',
#      'spellSlot': 64,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Blitzcrank',
#      'participantId': 3,
#      'physicalDamage': 105,
#      'spellName': 'powerfist',
#      'spellSlot': 2,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 232,
#      'name': 'Blitzcrank',
#      'participantId': 3,
#      'physicalDamage': 0,
#      'spellName': 'staticfield',
#      'spellSlot': 3,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': False,
#      'magicDamage': 0,
#      'name': 'Blitzcrank',
#      'participantId': 3,
#      'physicalDamage': 0,
#      'spellName': 'rocketgrab',
#      'spellSlot': 0,
#      'trueDamage': 0,
#      'type': 'OTHER'},
#     {'basic': True,
#      'magicDamage': 0,
#      'name': 'Blitzcrank',
#      'participantId': 3,
#      'physicalDamage': 49,
#      'spellName': 'blitzcrankbasicattack2',
#      'spellSlot': 65,
#      'trueDamage': 0,
#      'type': 'OTHER'}],
#    'victimId': 10},
#   {'level': 9, 'participantId': 2, 'timestamp': 951975, 'type': 'LEVEL_UP'},
#   {'itemId': 2055,
#    'participantId': 1,
#    'timestamp': 953776,
#    'type': 'ITEM_PURCHASED'},
#   {'levelUpType': 'NORMAL',
#    'participantId': 2,
#    'skillSlot': 2,
#    'timestamp': 954975,
#    'type': 'SKILL_LEVEL_UP'},
#   {'bounty': 0,
#    'buildingType': 'TOWER_BUILDING',
#    'killerId': 6,
#    'laneType': 'MID_LANE',
#    'position': {'x': 5846, 'y': 6396},
#    'teamId': 100,
#    'timestamp': 955008,
#    'towerType': 'OUTER_TURRET',
#    'type': 'BUILDING_KILL'},
#   {'creatorId': 3,
#    'timestamp': 957179,
#    'type': 'WARD_PLACED',
#    'wardType': 'SIGHT_WARD'},
#   {'itemId': 1001,
#    'participantId': 5,
#    'timestamp': 958746,
#    'type': 'ITEM_DESTROYED'},
#   {'itemId': 3020,
#    'participantId': 5,
#    'timestamp': 958746,
#    'type': 'ITEM_PURCHASED'}],
#  'participantFrames': {'1': {'championStats': {'abilityHaste': 0,
#     'abilityPower': 0,
#     'armor': 66,
#     'armorPen': 0,
#     'armorPenPercent': 0,
#     'attackDamage': 152,
#     'attackSpeed': 291,
#     'bonusArmorPenPercent': 0,
#     'bonusMagicPenPercent': 0,
#     'ccReduction': 0,
#     'cooldownReduction': 0,
#     'health': 1310,
#     'healthMax': 1310,
#     'healthRegen': 21,
#     'lifesteal': 0,
#     'magicPen': 0,
#     'magicPenPercent': 0,
#     'magicResist': 38,
#     'movementSpeed': 413,
#     'omnivamp': 0,
#     'physicalVamp': 0,
#     'power': 509,
#     'powerMax': 535,
#     'powerRegen': 19,
#     'spellVamp': 0},
#    'currentGold': 156,
#    'damageStats': {'magicDamageDone': 13532,
#     'magicDamageDoneToChampions': 1163,
#     'magicDamageTaken': 2751,
#     'physicalDamageDone': 55259,
#     'physicalDamageDoneToChampions': 5133,
#     'physicalDamageTaken': 10599,
#     'totalDamageDone': 84979,
#     'totalDamageDoneToChampions': 6573,
#     'totalDamageTaken': 13737,
#     'trueDamageDone': 16187,
#     'trueDamageDoneToChampions': 276,
#     'trueDamageTaken': 386},
#    'goldPerSecond': 0,
#    'jungleMinionsKilled': 72,
#    'level': 9,
#    'minionsKilled': 16,
#    'participantId': 1,
#    'position': {'x': 3397, 'y': 2571},
#    'timeEnemySpentControlled': 210043,
#    'totalGold': 6766,
#    'xp': 5620},
#   '2': {'championStats': {'abilityHaste': 0,
#     'abilityPower': 0,
#     'armor': 63,
#     'armorPen': 0,
#     'armorPenPercent': 0,
#     'attackDamage': 154,
#     'attackSpeed': 218,
#     'bonusArmorPenPercent': 0,
#     'bonusMagicPenPercent': 0,
#     'ccReduction': 0,
#     'cooldownReduction': 0,
#     'health': 1116,
#     'healthMax': 1420,
#     'healthRegen': 14,
#     'lifesteal': 3,
#     'magicPen': 0,
#     'magicPenPercent': 0,
#     'magicResist': 38,
#     'movementSpeed': 370,
#     'omnivamp': 2,
#     'physicalVamp': 0,
#     'power': 635,
#     'powerMax': 635,
#     'powerRegen': 22,
#     'spellVamp': 0},
#    'currentGold': 1267,
#    'damageStats': {'magicDamageDone': 2899,
#     'magicDamageDoneToChampions': 654,
#     'magicDamageTaken': 2261,
#     'physicalDamageDone': 42715,
#     'physicalDamageDoneToChampions': 10778,
#     'physicalDamageTaken': 5373,
#     'totalDamageDone': 48454,
#     'totalDamageDoneToChampions': 11432,
#     'totalDamageTaken': 7839,
#     'trueDamageDone': 2840,
#     'trueDamageDoneToChampions': 0,
#     'trueDamageTaken': 205},
#    'goldPerSecond': 0,
#    'jungleMinionsKilled': 0,
#    'level': 9,
#    'minionsKilled': 94,
#    'participantId': 2,
#    'position': {'x': 12525, 'y': 2571},
#    'timeEnemySpentControlled': 487699,
#    'totalGold': 7047,
#    'xp': 5270},
#   '3': {'championStats': {'abilityHaste': 0,
#     'abilityPower': 45,
#     'armor': 79,
#     'armorPen': 0,
#     'armorPenPercent': 0,
#     'attackDamage': 82,
#     'attackSpeed': 106,
#     'bonusArmorPenPercent': 0,
#     'bonusMagicPenPercent': 0,
#     'ccReduction': 5,
#     'cooldownReduction': 0,
#     'health': 1579,
#     'healthMax': 1579,
#     'healthRegen': 41,
#     'lifesteal': 0,
#     'magicPen': 0,
#     'magicPenPercent': 0,
#     'magicResist': 43,
#     'movementSpeed': 350,
#     'omnivamp': 0,
#     'physicalVamp': 0,
#     'power': 514,
#     'powerMax': 618,
#     'powerRegen': 164,
#     'spellVamp': 0},
#    'currentGold': 809,
#    'damageStats': {'magicDamageDone': 3075,
#     'magicDamageDoneToChampions': 1568,
#     'magicDamageTaken': 1455,
#     'physicalDamageDone': 3674,
#     'physicalDamageDoneToChampions': 978,
#     'physicalDamageTaken': 6057,
#     'totalDamageDone': 10375,
#     'totalDamageDoneToChampions': 2873,
#     'totalDamageTaken': 8663,
#     'trueDamageDone': 3624,
#     'trueDamageDoneToChampions': 326,
#     'trueDamageTaken': 1150},
#    'goldPerSecond': 30,
#    'jungleMinionsKilled': 0,
#    'level': 8,
#    'minionsKilled': 23,
#    'participantId': 3,
#    'position': {'x': 11916, 'y': 3772},
#    'timeEnemySpentControlled': 74759,
#    'totalGold': 4263,
#    'xp': 4645},
#   '4': {'championStats': {'abilityHaste': 0,
#     'abilityPower': 0,
#     'armor': 79,
#     'armorPen': 0,
#     'armorPenPercent': 0,
#     'attackDamage': 172,
#     'attackSpeed': 164,
#     'bonusArmorPenPercent': 0,
#     'bonusMagicPenPercent': 0,
#     'ccReduction': 0,
#     'cooldownReduction': 0,
#     'health': 1954,
#     'healthMax': 1954,
#     'healthRegen': 34,
#     'lifesteal': 0,
#     'magicPen': 0,
#     'magicPenPercent': 0,
#     'magicResist': 47,
#     'movementSpeed': 503,
#     'omnivamp': 8,
#     'physicalVamp': 0,
#     'power': 725,
#     'powerMax': 725,
#     'powerRegen': 19,
#     'spellVamp': 0},
#    'currentGold': 274,
#    'damageStats': {'magicDamageDone': 2254,
#     'magicDamageDoneToChampions': 334,
#     'magicDamageTaken': 1280,
#     'physicalDamageDone': 47984,
#     'physicalDamageDoneToChampions': 5001,
#     'physicalDamageTaken': 9193,
#     'totalDamageDone': 51838,
#     'totalDamageDoneToChampions': 5336,
#     'totalDamageTaken': 12545,
#     'trueDamageDone': 1600,
#     'trueDamageDoneToChampions': 0,
#     'trueDamageTaken': 2071},
#    'goldPerSecond': 0,
#    'jungleMinionsKilled': 0,
#    'level': 10,
#    'minionsKilled': 108,
#    'participantId': 4,
#    'position': {'x': 6277, 'y': 6687},
#    'timeEnemySpentControlled': 142790,
#    'totalGold': 5499,
#    'xp': 7021},
#   '5': {'championStats': {'abilityHaste': 0,
#     'abilityPower': 145,
#     'armor': 73,
#     'armorPen': 0,
#     'armorPenPercent': 0,
#     'attackDamage': 84,
#     'attackSpeed': 127,
#     'bonusArmorPenPercent': 0,
#     'bonusMagicPenPercent': 0,
#     'ccReduction': 0,
#     'cooldownReduction': 0,
#     'health': 0,
#     'healthMax': 2063,
#     'healthRegen': 31,
#     'lifesteal': 0,
#     'magicPen': 18,
#     'magicPenPercent': 0,
#     'magicResist': 51,
#     'movementSpeed': 420,
#     'omnivamp': 0,
#     'physicalVamp': 0,
#     'power': 905,
#     'powerMax': 1541,
#     'powerRegen': 28,
#     'spellVamp': 0},
#    'currentGold': 15,
#    'damageStats': {'magicDamageDone': 42064,
#     'magicDamageDoneToChampions': 8946,
#     'magicDamageTaken': 2676,
#     'physicalDamageDone': 4217,
#     'physicalDamageDoneToChampions': 0,
#     'physicalDamageTaken': 10899,
#     'totalDamageDone': 46282,
#     'totalDamageDoneToChampions': 8946,
#     'totalDamageTaken': 14516,
#     'trueDamageDone': 1,
#     'trueDamageDoneToChampions': 0,
#     'trueDamageTaken': 940},
#    'goldPerSecond': 0,
#    'jungleMinionsKilled': 0,
#    'level': 10,
#    'minionsKilled': 83,
#    'participantId': 5,
#    'position': {'x': 8937, 'y': 6221},
#    'timeEnemySpentControlled': 225801,
#    'totalGold': 5745,
#    'xp': 6774},
#   '6': {'championStats': {'abilityHaste': 0,
#     'abilityPower': 0,
#     'armor': 79,
#     'armorPen': 0,
#     'armorPenPercent': 0,
#     'attackDamage': 142,
#     'attackSpeed': 129,
#     'bonusArmorPenPercent': 0,
#     'bonusMagicPenPercent': 0,
#     'ccReduction': 11,
#     'cooldownReduction': 0,
#     'health': 1948,
#     'healthMax': 1976,
#     'healthRegen': 37,
#     'lifesteal': 0,
#     'magicPen': 0,
#     'magicPenPercent': 0,
#     'magicResist': 47,
#     'movementSpeed': 375,
#     'omnivamp': 0,
#     'physicalVamp': 0,
#     'power': 667,
#     'powerMax': 861,
#     'powerRegen': 27,
#     'spellVamp': 0},
#    'currentGold': 806,
#    'damageStats': {'magicDamageDone': 895,
#     'magicDamageDoneToChampions': 895,
#     'magicDamageTaken': 1086,
#     'physicalDamageDone': 30885,
#     'physicalDamageDoneToChampions': 7855,
#     'physicalDamageTaken': 8066,
#     'totalDamageDone': 36146,
#     'totalDamageDoneToChampions': 10335,
#     'totalDamageTaken': 9229,
#     'trueDamageDone': 4365,
#     'trueDamageDoneToChampions': 1584,
#     'trueDamageTaken': 76},
#    'goldPerSecond': 0,
#    'jungleMinionsKilled': 0,
#    'level': 10,
#    'minionsKilled': 82,
#    'participantId': 6,
#    'position': {'x': 6491, 'y': 8311},
#    'timeEnemySpentControlled': 113706,
#    'totalGold': 4906,
#    'xp': 6939},
#   '7': {'championStats': {'abilityHaste': 0,
#     'abilityPower': 167,
#     'armor': 55,
#     'armorPen': 0,
#     'armorPenPercent': 0,
#     'attackDamage': 80,
#     'attackSpeed': 119,
#     'bonusArmorPenPercent': 0,
#     'bonusMagicPenPercent': 0,
#     'ccReduction': 6,
#     'cooldownReduction': 0,
#     'health': 1250,
#     'healthMax': 1250,
#     'healthRegen': 21,
#     'lifesteal': 0,
#     'magicPen': 24,
#     'magicPenPercent': 0,
#     'magicResist': 38,
#     'movementSpeed': 375,
#     'omnivamp': 0,
#     'physicalVamp': 0,
#     'power': 777,
#     'powerMax': 1272,
#     'powerRegen': 93,
#     'spellVamp': 0},
#    'currentGold': 504,
#    'damageStats': {'magicDamageDone': 67890,
#     'magicDamageDoneToChampions': 5156,
#     'magicDamageTaken': 2373,
#     'physicalDamageDone': 11965,
#     'physicalDamageDoneToChampions': 719,
#     'physicalDamageTaken': 9071,
#     'totalDamageDone': 94878,
#     'totalDamageDoneToChampions': 6246,
#     'totalDamageTaken': 11513,
#     'trueDamageDone': 15022,
#     'trueDamageDoneToChampions': 370,
#     'trueDamageTaken': 68},
#    'goldPerSecond': 0,
#    'jungleMinionsKilled': 73,
#    'level': 9,
#    'minionsKilled': 16,
#    'participantId': 7,
#    'position': {'x': 8910, 'y': 2215},
#    'timeEnemySpentControlled': 458850,
#    'totalGold': 6554,
#    'xp': 5669},
#   '8': {'championStats': {'abilityHaste': 0,
#     'abilityPower': 0,
#     'armor': 91,
#     'armorPen': 0,
#     'armorPenPercent': 0,
#     'attackDamage': 179,
#     'attackSpeed': 118,
#     'bonusArmorPenPercent': 0,
#     'bonusMagicPenPercent': 0,
#     'ccReduction': 6,
#     'cooldownReduction': 0,
#     'health': 1688,
#     'healthMax': 1688,
#     'healthRegen': 202,
#     'lifesteal': 0,
#     'magicPen': 0,
#     'magicPenPercent': 0,
#     'magicResist': 82,
#     'movementSpeed': 390,
#     'omnivamp': 0,
#     'physicalVamp': 0,
#     'power': 1002,
#     'powerMax': 1002,
#     'powerRegen': 32,
#     'spellVamp': 0},
#    'currentGold': 276,
#    'damageStats': {'magicDamageDone': 0,
#     'magicDamageDoneToChampions': 0,
#     'magicDamageTaken': 6488,
#     'physicalDamageDone': 40173,
#     'physicalDamageDoneToChampions': 7639,
#     'physicalDamageTaken': 2086,
#     'totalDamageDone': 41739,
#     'totalDamageDoneToChampions': 8257,
#     'totalDamageTaken': 8707,
#     'trueDamageDone': 1566,
#     'trueDamageDoneToChampions': 617,
#     'trueDamageTaken': 131},
#    'goldPerSecond': 0,
#    'jungleMinionsKilled': 0,
#    'level': 11,
#    'minionsKilled': 98,
#    'participantId': 8,
#    'position': {'x': 10927, 'y': 10435},
#    'timeEnemySpentControlled': 4408,
#    'totalGold': 6476,
#    'xp': 8376},
#   '9': {'championStats': {'abilityHaste': 0,
#     'abilityPower': 0,
#     'armor': 74,
#     'armorPen': 0,
#     'armorPenPercent': 0,
#     'attackDamage': 166,
#     'attackSpeed': 251,
#     'bonusArmorPenPercent': 0,
#     'bonusMagicPenPercent': 0,
#     'ccReduction': 6,
#     'cooldownReduction': 0,
#     'health': 0,
#     'healthMax': 1763,
#     'healthRegen': 15,
#     'lifesteal': 0,
#     'magicPen': 0,
#     'magicPenPercent': 0,
#     'magicResist': 49,
#     'movementSpeed': 421,
#     'omnivamp': 0,
#     'physicalVamp': 0,
#     'power': 373,
#     'powerMax': 502,
#     'powerRegen': 20,
#     'spellVamp': 0},
#    'currentGold': 152,
#    'damageStats': {'magicDamageDone': 1255,
#     'magicDamageDoneToChampions': 351,
#     'magicDamageTaken': 2136,
#     'physicalDamageDone': 50338,
#     'physicalDamageDoneToChampions': 10750,
#     'physicalDamageTaken': 8035,
#     'totalDamageDone': 55745,
#     'totalDamageDoneToChampions': 13283,
#     'totalDamageTaken': 10429,
#     'trueDamageDone': 4151,
#     'trueDamageDoneToChampions': 2181,
#     'trueDamageTaken': 258},
#    'goldPerSecond': 0,
#    'jungleMinionsKilled': 0,
#    'level': 10,
#    'minionsKilled': 118,
#    'participantId': 9,
#    'position': {'x': 12844, 'y': 2607},
#    'timeEnemySpentControlled': 7903,
#    'totalGold': 8140,
#    'xp': 6706},
#   '10': {'championStats': {'abilityHaste': 0,
#     'abilityPower': 45,
#     'armor': 66,
#     'armorPen': 0,
#     'armorPenPercent': 0,
#     'attackDamage': 62,
#     'attackSpeed': 112,
#     'bonusArmorPenPercent': 0,
#     'bonusMagicPenPercent': 0,
#     'ccReduction': 6,
#     'cooldownReduction': 0,
#     'health': 0,
#     'healthMax': 1426,
#     'healthRegen': 33,
#     'lifesteal': 0,
#     'magicPen': 0,
#     'magicPenPercent': 0,
#     'magicResist': 37,
#     'movementSpeed': 355,
#     'omnivamp': 0,
#     'physicalVamp': 0,
#     'power': 462,
#     'powerMax': 917,
#     'powerRegen': 57,
#     'spellVamp': 0},
#    'currentGold': 770,
#    'damageStats': {'magicDamageDone': 8520,
#     'magicDamageDoneToChampions': 3284,
#     'magicDamageTaken': 1167,
#     'physicalDamageDone': 2902,
#     'physicalDamageDoneToChampions': 1173,
#     'physicalDamageTaken': 4972,
#     'totalDamageDone': 12944,
#     'totalDamageDoneToChampions': 4458,
#     'totalDamageTaken': 6207,
#     'trueDamageDone': 1522,
#     'trueDamageDoneToChampions': 0,
#     'trueDamageTaken': 68},
#    'goldPerSecond': 30,
#    'jungleMinionsKilled': 0,
#    'level': 8,
#    'minionsKilled': 15,
#    'participantId': 10,
#    'position': {'x': 13492, 'y': 3773},
#    'timeEnemySpentControlled': 185566,
#    'totalGold': 4390,
#    'xp': 5031}},
#  'timestamp': 960247}

# %%
killerId = 9|7|9

# %%
victmId = 2|2|4

# %%
assistsId = 7|9,10|10

# %%
킬     죽은사람       어시스트

# %%
tmp.iloc[0].timelines['info']['frames'][2]['events']
# Out:
# [{'creatorId': 3,
#   'timestamp': 74331,
#   'type': 'WARD_PLACED',
#   'wardType': 'YELLOW_TRINKET'},
#  {'creatorId': 5,
#   'timestamp': 85251,
#   'type': 'WARD_PLACED',
#   'wardType': 'YELLOW_TRINKET'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 1,
#   'skillSlot': 2,
#   'timestamp': 86117,
#   'type': 'SKILL_LEVEL_UP'},
#  {'creatorId': 10,
#   'timestamp': 86584,
#   'type': 'WARD_PLACED',
#   'wardType': 'YELLOW_TRINKET'},
#  {'level': 2, 'participantId': 1, 'timestamp': 101116, 'type': 'LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 1,
#   'skillSlot': 1,
#   'timestamp': 102985,
#   'type': 'SKILL_LEVEL_UP'},
#  {'level': 2, 'participantId': 7, 'timestamp': 107028, 'type': 'LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 7,
#   'skillSlot': 3,
#   'timestamp': 108434,
#   'type': 'SKILL_LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 6,
#   'skillSlot': 2,
#   'timestamp': 109536,
#   'type': 'SKILL_LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 4,
#   'skillSlot': 1,
#   'timestamp': 109970,
#   'type': 'SKILL_LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 10,
#   'skillSlot': 3,
#   'timestamp': 111940,
#   'type': 'SKILL_LEVEL_UP'},
#  {'itemId': 2003,
#   'participantId': 9,
#   'timestamp': 118187,
#   'type': 'ITEM_DESTROYED'}]

# %%
tmp_map = list(map(lambda x : x['events'],tmp.iloc[0].timelines['info']['frames']))

# %%
tmp_map[2]
# Out:
# [{'creatorId': 3,
#   'timestamp': 74331,
#   'type': 'WARD_PLACED',
#   'wardType': 'YELLOW_TRINKET'},
#  {'creatorId': 5,
#   'timestamp': 85251,
#   'type': 'WARD_PLACED',
#   'wardType': 'YELLOW_TRINKET'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 1,
#   'skillSlot': 2,
#   'timestamp': 86117,
#   'type': 'SKILL_LEVEL_UP'},
#  {'creatorId': 10,
#   'timestamp': 86584,
#   'type': 'WARD_PLACED',
#   'wardType': 'YELLOW_TRINKET'},
#  {'level': 2, 'participantId': 1, 'timestamp': 101116, 'type': 'LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 1,
#   'skillSlot': 1,
#   'timestamp': 102985,
#   'type': 'SKILL_LEVEL_UP'},
#  {'level': 2, 'participantId': 7, 'timestamp': 107028, 'type': 'LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 7,
#   'skillSlot': 3,
#   'timestamp': 108434,
#   'type': 'SKILL_LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 6,
#   'skillSlot': 2,
#   'timestamp': 109536,
#   'type': 'SKILL_LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 4,
#   'skillSlot': 1,
#   'timestamp': 109970,
#   'type': 'SKILL_LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 10,
#   'skillSlot': 3,
#   'timestamp': 111940,
#   'type': 'SKILL_LEVEL_UP'},
#  {'itemId': 2003,
#   'participantId': 9,
#   'timestamp': 118187,
#   'type': 'ITEM_DESTROYED'}]

# %%
tmp_map = [element for array in tmp_map for element in array]

# %%
tmp_list = []
for array in tmp_map:
    for element in array:
        tmp_list.append(element)

# %% [markdown]
# # tmp_map 리스트에서  type이 'CHAMPION_KILL' 인 애들만 뽑아보기

# %%
kill_log = list(filter(lambda x:x['type']=='CHAMPION_KILL' ,tmp_map))

# %%
k -> killerId
v -> victimId
a -> assistingParticipantIds

# %%
kill_log
# Out:
# [{'assistingParticipantIds': [10],
#   'bounty': 400,
#   'killStreakLength': 0,
#   'killerId': 9,
#   'position': {'x': 11750, 'y': 1145},
#   'shutdownBounty': 0,
#   'timestamp': 136002,
#   'type': 'CHAMPION_KILL',
#   'victimDamageDealt': [{'basic': False,
#     'magicDamage': 87,
#     'name': 'Blitzcrank',
#     'participantId': 9,
#     'physicalDamage': 0,
#     'spellName': 'rocketgrab',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Blitzcrank',
#     'participantId': 9,
#     'physicalDamage': 48,
#     'spellName': 'blitzcrankbasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Blitzcrank',
#     'participantId': 10,
#     'physicalDamage': 44,
#     'spellName': 'blitzcrankbasicattack2',
#     'spellSlot': 65,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimDamageReceived': [{'basic': True,
#     'magicDamage': 0,
#     'name': 'Vayne',
#     'participantId': 9,
#     'physicalDamage': 99,
#     'spellName': 'vaynebasicattack3',
#     'spellSlot': 66,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Vayne',
#     'participantId': 9,
#     'physicalDamage': 103,
#     'spellName': 'vaynebasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Vayne',
#     'participantId': 9,
#     'physicalDamage': 176,
#     'spellName': 'vaynebasicattack2',
#     'spellSlot': 65,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Vayne',
#     'participantId': 9,
#     'physicalDamage': 49,
#     'spellName': 'vaynetumble',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 46,
#     'name': 'Lulu',
#     'participantId': 10,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Lulu',
#     'participantId': 10,
#     'physicalDamage': 92,
#     'spellName': 'lulubasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 7,
#     'name': 'Lulu',
#     'participantId': 10,
#     'physicalDamage': 0,
#     'spellName': 'lulupassive',
#     'spellSlot': 63,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 93,
#     'name': 'Lulu',
#     'participantId': 10,
#     'physicalDamage': 0,
#     'spellName': 'lulue',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Lulu',
#     'participantId': 10,
#     'physicalDamage': 107,
#     'spellName': 'lulubasicattack2',
#     'spellSlot': 65,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'SRU_ChaosMinionMelee',
#     'participantId': 0,
#     'physicalDamage': 31,
#     'spellName': 'sru_chaosminionrangedbasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'MINION'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'SRU_ChaosMinionMelee',
#     'participantId': 0,
#     'physicalDamage': 23,
#     'spellName': 'sru_chaosminionmeleebasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'MINION'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'SRU_ChaosMinionMelee',
#     'participantId': 0,
#     'physicalDamage': 31,
#     'spellName': 'sru_chaosminionrangedbasicattack2',
#     'spellSlot': 65,
#     'trueDamage': 0,
#     'type': 'MINION'}],
#   'victimId': 3},
#  {'assistingParticipantIds': [1, 3],
#   'bounty': 300,
#   'killStreakLength': 0,
#   'killerId': 2,
#   'position': {'x': 11079, 'y': 1795},
#   'shutdownBounty': 0,
#   'timestamp': 140442,
#   'type': 'CHAMPION_KILL',
#   'victimDamageDealt': [{'basic': False,
#     'magicDamage': 0,
#     'name': 'Vayne',
#     'participantId': 1,
#     'physicalDamage': 95,
#     'spellName': 'vaynetumble',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Vayne',
#     'participantId': 2,
#     'physicalDamage': 207,
#     'spellName': 'vaynetumble',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Vayne',
#     'participantId': 2,
#     'physicalDamage': 118,
#     'spellName': 'vaynebasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Vayne',
#     'participantId': 2,
#     'physicalDamage': 61,
#     'spellName': 'vaynebasicattack4',
#     'spellSlot': 67,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimDamageReceived': [{'basic': False,
#     'magicDamage': 87,
#     'name': 'Blitzcrank',
#     'participantId': 3,
#     'physicalDamage': 0,
#     'spellName': 'rocketgrab',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Blitzcrank',
#     'participantId': 3,
#     'physicalDamage': 48,
#     'spellName': 'blitzcrankbasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'SRU_OrderMinionRanged',
#     'participantId': 0,
#     'physicalDamage': 18,
#     'spellName': 'sru_orderminionrangedbasicattack2',
#     'spellSlot': 65,
#     'trueDamage': 0,
#     'type': 'MINION'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'SRU_OrderMinionRanged',
#     'participantId': 0,
#     'physicalDamage': 9,
#     'spellName': 'sru_orderminionrangedbasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'MINION'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Kindred',
#     'participantId': 1,
#     'physicalDamage': 38,
#     'spellName': 'kindredq',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Kindred',
#     'participantId': 1,
#     'physicalDamage': 63,
#     'spellName': 'kindredpassivemanager',
#     'spellSlot': 63,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Ashe',
#     'participantId': 2,
#     'physicalDamage': 27,
#     'spellName': 'ashebasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimId': 9},
#  {'bounty': 300,
#   'killStreakLength': 0,
#   'killerId': 1,
#   'position': {'x': 14020, 'y': 4591},
#   'shutdownBounty': 0,
#   'timestamp': 152375,
#   'type': 'CHAMPION_KILL',
#   'victimDamageDealt': [{'basic': True,
#     'magicDamage': 0,
#     'name': 'Lulu',
#     'participantId': 1,
#     'physicalDamage': 33,
#     'spellName': 'lulubasicattack2',
#     'spellSlot': 65,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 7,
#     'name': 'Lulu',
#     'participantId': 1,
#     'physicalDamage': 0,
#     'spellName': 'lulupassive',
#     'spellSlot': 63,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Lulu',
#     'participantId': 1,
#     'physicalDamage': 33,
#     'spellName': 'lulubasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 7,
#     'name': 'Lulu',
#     'participantId': 1,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimDamageReceived': [{'basic': False,
#     'magicDamage': 0,
#     'name': 'Ashe',
#     'participantId': 2,
#     'physicalDamage': 136,
#     'spellName': 'volley',
#     'spellSlot': 1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Ashe',
#     'participantId': 2,
#     'physicalDamage': 142,
#     'spellName': 'ashebasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'SRU_OrderMinionMelee',
#     'participantId': 0,
#     'physicalDamage': 4,
#     'spellName': 'sru_orderminionmeleebasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'MINION'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Blitzcrank',
#     'participantId': 3,
#     'physicalDamage': 44,
#     'spellName': 'blitzcrankbasicattack2',
#     'spellSlot': 65,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Kindred',
#     'participantId': 1,
#     'physicalDamage': 103,
#     'spellName': 'kindredq',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Kindred',
#     'participantId': 1,
#     'physicalDamage': 354,
#     'spellName': 'kindredpassivemanager',
#     'spellSlot': 63,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Kindred',
#     'participantId': 1,
#     'physicalDamage': 39,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimId': 10},
#  {'assistingParticipantIds': [9],
#   'bounty': 300,
#   'killStreakLength': 0,
#   'killerId': 10,
#   'position': {'x': 13792, 'y': 4148},
#   'shutdownBounty': 0,
#   'timestamp': 152909,
#   'type': 'CHAMPION_KILL',
#   'victimDamageReceived': [{'basic': True,
#     'magicDamage': 0,
#     'name': 'Lulu',
#     'participantId': 10,
#     'physicalDamage': 33,
#     'spellName': 'lulubasicattack2',
#     'spellSlot': 65,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 7,
#     'name': 'Lulu',
#     'participantId': 10,
#     'physicalDamage': 0,
#     'spellName': 'lulupassive',
#     'spellSlot': 63,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Lulu',
#     'participantId': 10,
#     'physicalDamage': 67,
#     'spellName': 'lulubasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 7,
#     'name': 'Lulu',
#     'participantId': 10,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Vayne',
#     'participantId': 9,
#     'physicalDamage': 95,
#     'spellName': 'vaynetumble',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'SRU_ChaosMinionMelee',
#     'participantId': 0,
#     'physicalDamage': 29,
#     'spellName': 'sru_chaosminionsiegebasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'MINION'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'SRU_ChaosMinionMelee',
#     'participantId': 0,
#     'physicalDamage': 34,
#     'spellName': 'sru_chaosminionrangedbasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'MINION'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'SRU_ChaosMinionMelee',
#     'participantId': 0,
#     'physicalDamage': 56,
#     'spellName': 'sru_chaosminionmeleebasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'MINION'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'SRU_ChaosMinionMelee',
#     'participantId': 0,
#     'physicalDamage': 78,
#     'spellName': 'sru_chaosminionrangedbasicattack2',
#     'spellSlot': 65,
#     'trueDamage': 0,
#     'type': 'MINION'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Turret',
#     'participantId': 0,
#     'physicalDamage': 389,
#     'spellName': 'turretbasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'TOWER'}],
#   'victimId': 1},
#  {'assistingParticipantIds': [7],
#   'bounty': 300,
#   'killStreakLength': 0,
#   'killerId': 6,
#   'position': {'x': 3715, 'y': 13473},
#   'shutdownBounty': 0,
#   'timestamp': 167869,
#   'type': 'CHAMPION_KILL',
#   'victimDamageDealt': [{'basic': False,
#     'magicDamage': 0,
#     'name': 'JarvanIV',
#     'participantId': 6,
#     'physicalDamage': 140,
#     'spellName': 'jarvanivdragonstrike',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'JarvanIV',
#     'participantId': 6,
#     'physicalDamage': 87,
#     'spellName': 'jarvanivmartialcadence',
#     'spellSlot': 63,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'JarvanIV',
#     'participantId': 6,
#     'physicalDamage': 209,
#     'spellName': 'jarvanivmartialcadence',
#     'spellSlot': 63,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 124,
#     'name': 'JarvanIV',
#     'participantId': 6,
#     'physicalDamage': 0,
#     'spellName': 'jarvanivdemacianstandard',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'JarvanIV',
#     'participantId': 6,
#     'physicalDamage': 182,
#     'spellName': 'jarvanivbasicattack3',
#     'spellSlot': 66,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'JarvanIV',
#     'participantId': 6,
#     'physicalDamage': 164,
#     'spellName': 'jarvanivbasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'JarvanIV',
#     'participantId': 6,
#     'physicalDamage': 59,
#     'spellName': 'jarvanivbasicattack2',
#     'spellSlot': 65,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimDamageReceived': [{'basic': True,
#     'magicDamage': 0,
#     'name': 'SRU_ChaosMinionRanged',
#     'participantId': 0,
#     'physicalDamage': 12,
#     'spellName': 'sru_chaosminionmeleebasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'MINION'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'SRU_ChaosMinionRanged',
#     'participantId': 0,
#     'physicalDamage': 99,
#     'spellName': 'sru_chaosminionrangedbasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'MINION'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'SRU_ChaosMinionRanged',
#     'participantId': 0,
#     'physicalDamage': 99,
#     'spellName': 'sru_chaosminionrangedbasicattack2',
#     'spellSlot': 65,
#     'trueDamage': 0,
#     'type': 'MINION'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Camille',
#     'participantId': 6,
#     'physicalDamage': 207,
#     'spellName': 'camillew',
#     'spellSlot': 1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Camille',
#     'participantId': 6,
#     'physicalDamage': 78,
#     'spellName': 'camillebasicattack3',
#     'spellSlot': 66,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Camille',
#     'participantId': 6,
#     'physicalDamage': 154,
#     'spellName': 'camillebasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 65,
#     'name': 'Camille',
#     'participantId': 6,
#     'physicalDamage': 31,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Camille',
#     'participantId': 6,
#     'physicalDamage': 115,
#     'spellName': 'camilleedash2',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Camille',
#     'participantId': 6,
#     'physicalDamage': 104,
#     'spellName': 'camillebasicattack2',
#     'spellSlot': 65,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Camille',
#     'participantId': 6,
#     'physicalDamage': 51,
#     'spellName': 'camillebasicattack4',
#     'spellSlot': 67,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 99,
#     'name': 'Taliyah',
#     'participantId': 7,
#     'physicalDamage': 0,
#     'spellName': 'taliyahe',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Taliyah',
#     'participantId': 7,
#     'physicalDamage': 42,
#     'spellName': 'taliyahbasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 20,
#     'name': 'Taliyah',
#     'participantId': 7,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 14,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Taliyah',
#     'participantId': 7,
#     'physicalDamage': 0,
#     'spellName': 'burning',
#     'spellSlot': -1,
#     'trueDamage': 10,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 72,
#     'name': 'Taliyah',
#     'participantId': 7,
#     'physicalDamage': 0,
#     'spellName': 'taliyahq',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimId': 4},
#  {'assistingParticipantIds': [5],
#   'bounty': 300,
#   'killStreakLength': 0,
#   'killerId': 1,
#   'position': {'x': 8707, 'y': 7916},
#   'shutdownBounty': 0,
#   'timestamp': 215899,
#   'type': 'CHAMPION_KILL',
#   'victimDamageDealt': [{'basic': False,
#     'magicDamage': 0,
#     'name': 'Taliyah',
#     'participantId': 1,
#     'physicalDamage': 0,
#     'spellName': 'burning',
#     'spellSlot': -1,
#     'trueDamage': 6,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Taliyah',
#     'participantId': 1,
#     'physicalDamage': 44,
#     'spellName': 'taliyahbasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 46,
#     'name': 'Taliyah',
#     'participantId': 5,
#     'physicalDamage': 0,
#     'spellName': 'taliyahe',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 23,
#     'name': 'Taliyah',
#     'participantId': 5,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 14,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 104,
#     'name': 'Taliyah',
#     'participantId': 5,
#     'physicalDamage': 0,
#     'spellName': 'taliyahq',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimDamageReceived': [{'basic': False,
#     'magicDamage': 92,
#     'name': 'Sylas',
#     'participantId': 5,
#     'physicalDamage': 0,
#     'spellName': 'sylase2',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 43,
#     'name': 'Sylas',
#     'participantId': 5,
#     'physicalDamage': 0,
#     'spellName': 'sylasq',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 48,
#     'name': 'Kindred',
#     'participantId': 1,
#     'physicalDamage': 0,
#     'spellName': 'kindredw',
#     'spellSlot': 1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 36,
#     'name': 'Kindred',
#     'participantId': 1,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Kindred',
#     'participantId': 1,
#     'physicalDamage': 107,
#     'spellName': 'kindredewrapper',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Kindred',
#     'participantId': 1,
#     'physicalDamage': 182,
#     'spellName': 'kindredpassivemanager',
#     'spellSlot': 63,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Kindred',
#     'participantId': 1,
#     'physicalDamage': 48,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimId': 7},
#  {'bounty': 300,
#   'killStreakLength': 0,
#   'killerId': 5,
#   'position': {'x': 8336, 'y': 8673},
#   'shutdownBounty': 0,
#   'timestamp': 288723,
#   'type': 'CHAMPION_KILL',
#   'victimDamageReceived': [{'basic': False,
#     'magicDamage': 130,
#     'name': 'Sylas',
#     'participantId': 5,
#     'physicalDamage': 0,
#     'spellName': 'sylasw',
#     'spellSlot': 1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 151,
#     'name': 'Sylas',
#     'participantId': 5,
#     'physicalDamage': 0,
#     'spellName': 'sylaspassive',
#     'spellSlot': 63,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 73,
#     'name': 'Sylas',
#     'participantId': 5,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 45,
#     'name': 'Sylas',
#     'participantId': 5,
#     'physicalDamage': 0,
#     'spellName': 'sylasq',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimId': 8},
#  {'assistingParticipantIds': [7, 10],
#   'bounty': 300,
#   'killStreakLength': 0,
#   'killerId': 9,
#   'position': {'x': 10808, 'y': 907},
#   'shutdownBounty': 0,
#   'timestamp': 298837,
#   'type': 'CHAMPION_KILL',
#   'victimDamageDealt': [{'basic': False,
#     'magicDamage': 0,
#     'name': 'Blitzcrank',
#     'participantId': 9,
#     'physicalDamage': 0,
#     'spellName': 'summonerdot',
#     'spellSlot': 4,
#     'trueDamage': 88,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Blitzcrank',
#     'participantId': 9,
#     'physicalDamage': 97,
#     'spellName': 'powerfist',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimDamageReceived': [{'basic': True,
#     'magicDamage': 0,
#     'name': 'Vayne',
#     'participantId': 9,
#     'physicalDamage': 101,
#     'spellName': 'vaynebasicattack2',
#     'spellSlot': 65,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Vayne',
#     'participantId': 9,
#     'physicalDamage': 95,
#     'spellName': 'vaynebasicattack4',
#     'spellSlot': 67,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Vayne',
#     'participantId': 9,
#     'physicalDamage': 54,
#     'spellName': 'vaynebasicattack3',
#     'spellSlot': 66,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Vayne',
#     'participantId': 9,
#     'physicalDamage': 0,
#     'spellName': 'vaynesilveredbolts',
#     'spellSlot': 1,
#     'trueDamage': 130,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Vayne',
#     'participantId': 9,
#     'physicalDamage': 105,
#     'spellName': 'vaynebasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Vayne',
#     'participantId': 9,
#     'physicalDamage': 54,
#     'spellName': 'vaynetumble',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 61,
#     'name': 'Lulu',
#     'participantId': 10,
#     'physicalDamage': 0,
#     'spellName': 'luluq',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Lulu',
#     'participantId': 10,
#     'physicalDamage': 63,
#     'spellName': 'lulubasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 40,
#     'name': 'Lulu',
#     'participantId': 10,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 55,
#     'name': 'Lulu',
#     'participantId': 10,
#     'physicalDamage': 0,
#     'spellName': 'lulue',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Lulu',
#     'participantId': 10,
#     'physicalDamage': 0,
#     'spellName': 'lulubasicattack2',
#     'spellSlot': 65,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'SRU_ChaosMinionRanged',
#     'participantId': 0,
#     'physicalDamage': 8,
#     'spellName': 'sru_chaosminionrangedbasicattack2',
#     'spellSlot': 65,
#     'trueDamage': 0,
#     'type': 'MINION'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Taliyah',
#     'participantId': 7,
#     'physicalDamage': 39,
#     'spellName': 'taliyahbasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 28,
#     'name': 'Taliyah',
#     'participantId': 7,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 14,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 58,
#     'name': 'Taliyah',
#     'participantId': 7,
#     'physicalDamage': 0,
#     'spellName': 'taliyahe',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 19,
#     'name': 'Taliyah',
#     'participantId': 7,
#     'physicalDamage': 0,
#     'spellName': 'taliyahq',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimId': 3},
#  {'assistingParticipantIds': [10],
#   'bounty': 300,
#   'killStreakLength': 0,
#   'killerId': 7,
#   'position': {'x': 9924, 'y': 1696},
#   'shutdownBounty': 0,
#   'timestamp': 321109,
#   'type': 'CHAMPION_KILL',
#   'victimDamageDealt': [{'basic': True,
#     'magicDamage': 0,
#     'name': 'Ashe',
#     'participantId': 10,
#     'physicalDamage': 111,
#     'spellName': 'ashebasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Ashe',
#     'participantId': 10,
#     'physicalDamage': 126,
#     'spellName': 'asheq',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Ashe',
#     'participantId': 10,
#     'physicalDamage': 159,
#     'spellName': 'volley',
#     'spellSlot': 1,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimDamageReceived': [{'basic': False,
#     'magicDamage': 78,
#     'name': 'Lulu',
#     'participantId': 10,
#     'physicalDamage': 0,
#     'spellName': 'luluq',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 40,
#     'name': 'Lulu',
#     'participantId': 10,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 70,
#     'name': 'Lulu',
#     'participantId': 10,
#     'physicalDamage': 0,
#     'spellName': 'lulue',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 56,
#     'name': 'Lulu',
#     'participantId': 10,
#     'physicalDamage': 0,
#     'spellName': 'lulupassive',
#     'spellSlot': 63,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Lulu',
#     'participantId': 10,
#     'physicalDamage': 107,
#     'spellName': 'lulubasicattack2',
#     'spellSlot': 65,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 32,
#     'name': 'Taliyah',
#     'participantId': 7,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 14,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Taliyah',
#     'participantId': 7,
#     'physicalDamage': 44,
#     'spellName': 'taliyahbasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 110,
#     'name': 'Taliyah',
#     'participantId': 7,
#     'physicalDamage': 0,
#     'spellName': 'taliyahq',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 45,
#     'name': 'Taliyah',
#     'participantId': 7,
#     'physicalDamage': 0,
#     'spellName': 'taliyahe',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimId': 2},
#  {'assistingParticipantIds': [1],
#   'bounty': 274,
#   'killStreakLength': 1,
#   'killerId': 5,
#   'position': {'x': 8751, 'y': 9136},
#   'shutdownBounty': 0,
#   'timestamp': 383451,
#   'type': 'CHAMPION_KILL',
#   'victimDamageDealt': [{'basic': False,
#     'magicDamage': 0,
#     'name': 'Naafiri',
#     'participantId': 5,
#     'physicalDamage': 132,
#     'spellName': '',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Naafiri',
#     'participantId': 5,
#     'physicalDamage': 175,
#     'spellName': 'naafirip',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Naafiri',
#     'participantId': 5,
#     'physicalDamage': 0,
#     'spellName': 'summonerdot',
#     'spellSlot': 4,
#     'trueDamage': 185,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Naafiri',
#     'participantId': 5,
#     'physicalDamage': 76,
#     'spellName': 'naafiriw',
#     'spellSlot': 1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Naafiri',
#     'participantId': 5,
#     'physicalDamage': 66,
#     'spellName': 'naafiriw',
#     'spellSlot': 1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Naafiri',
#     'participantId': 5,
#     'physicalDamage': 76,
#     'spellName': 'naafiribasicattack2',
#     'spellSlot': 65,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimDamageReceived': [{'basic': False,
#     'magicDamage': 288,
#     'name': 'Sylas',
#     'participantId': 5,
#     'physicalDamage': 0,
#     'spellName': 'sylasq',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 98,
#     'name': 'Sylas',
#     'participantId': 5,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 243,
#     'name': 'Sylas',
#     'participantId': 5,
#     'physicalDamage': 0,
#     'spellName': 'sylaspassive',
#     'spellSlot': 63,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 282,
#     'name': 'Sylas',
#     'participantId': 5,
#     'physicalDamage': 0,
#     'spellName': 'sylasw',
#     'spellSlot': 1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 226,
#     'name': 'Sylas',
#     'participantId': 5,
#     'physicalDamage': 0,
#     'spellName': 'sylase2',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 22,
#     'name': 'Kindred',
#     'participantId': 1,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Kindred',
#     'participantId': 1,
#     'physicalDamage': 117,
#     'spellName': 'kindredpassivemanager',
#     'spellSlot': 63,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Kindred',
#     'participantId': 7,
#     'physicalDamage': 0,
#     'spellName': 'burning',
#     'spellSlot': -1,
#     'trueDamage': 3,
#     'type': 'OTHER'}],
#   'victimId': 8},
#  {'bounty': 300,
#   'killStreakLength': 0,
#   'killerId': 0,
#   'position': {'x': 7669, 'y': 8256},
#   'shutdownBounty': 100,
#   'timestamp': 385482,
#   'type': 'CHAMPION_KILL',
#   'victimDamageReceived': [{'basic': True,
#     'magicDamage': 0,
#     'name': 'Turret',
#     'participantId': 0,
#     'physicalDamage': 808,
#     'spellName': 'turretbasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'TOWER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'SRU_ChaosMinionMelee',
#     'participantId': 0,
#     'physicalDamage': 19,
#     'spellName': 'sru_chaosminionrangedbasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'MINION'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'SRU_ChaosMinionMelee',
#     'participantId': 0,
#     'physicalDamage': 8,
#     'spellName': 'sru_chaosminionmeleebasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'MINION'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'SRU_ChaosMinionMelee',
#     'participantId': 0,
#     'physicalDamage': 19,
#     'spellName': 'sru_chaosminionrangedbasicattack2',
#     'spellSlot': 65,
#     'trueDamage': 0,
#     'type': 'MINION'}],
#   'victimId': 1},
#  {'assistingParticipantIds': [10],
#   'bounty': 274,
#   'killStreakLength': 1,
#   'killerId': 9,
#   'position': {'x': 12546, 'y': 2555},
#   'shutdownBounty': 0,
#   'timestamp': 423519,
#   'type': 'CHAMPION_KILL',
#   'victimDamageReceived': [{'basic': True,
#     'magicDamage': 0,
#     'name': 'Vayne',
#     'participantId': 9,
#     'physicalDamage': 50,
#     'spellName': 'vaynebasicattack4',
#     'spellSlot': 67,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 79,
#     'name': 'Vayne',
#     'participantId': 9,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Vayne',
#     'participantId': 9,
#     'physicalDamage': 50,
#     'spellName': 'vaynebasicattack3',
#     'spellSlot': 66,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Vayne',
#     'participantId': 9,
#     'physicalDamage': 0,
#     'spellName': 'vaynesilveredbolts',
#     'spellSlot': 1,
#     'trueDamage': 263,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Vayne',
#     'participantId': 9,
#     'physicalDamage': 105,
#     'spellName': 'vaynebasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Vayne',
#     'participantId': 9,
#     'physicalDamage': 105,
#     'spellName': 'vaynebasicattack2',
#     'spellSlot': 65,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Vayne',
#     'participantId': 9,
#     'physicalDamage': 35,
#     'spellName': 'vaynecondemn',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Vayne',
#     'participantId': 9,
#     'physicalDamage': 0,
#     'spellName': 'vaynetumble',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 45,
#     'name': 'Lulu',
#     'participantId': 10,
#     'physicalDamage': 0,
#     'spellName': 'lulupassive',
#     'spellSlot': 63,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 150,
#     'name': 'Lulu',
#     'participantId': 10,
#     'physicalDamage': 0,
#     'spellName': 'lulue',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Lulu',
#     'participantId': 10,
#     'physicalDamage': 32,
#     'spellName': 'lulubasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 44,
#     'name': 'Lulu',
#     'participantId': 10,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Lulu',
#     'participantId': 10,
#     'physicalDamage': 32,
#     'spellName': 'lulubasicattack2',
#     'spellSlot': 65,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 61,
#     'name': 'Lulu',
#     'participantId': 10,
#     'physicalDamage': 0,
#     'spellName': 'luluq',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'SRU_ChaosMinionRanged',
#     'participantId': 0,
#     'physicalDamage': 14,
#     'spellName': 'sru_chaosminionsiegebasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'MINION'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'SRU_ChaosMinionRanged',
#     'participantId': 0,
#     'physicalDamage': 11,
#     'spellName': 'sru_chaosminionmeleebasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'MINION'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'SRU_ChaosMinionRanged',
#     'participantId': 0,
#     'physicalDamage': 26,
#     'spellName': 'sru_chaosminionrangedbasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'MINION'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'SRU_ChaosMinionRanged',
#     'participantId': 0,
#     'physicalDamage': 17,
#     'spellName': 'sru_chaosminionrangedbasicattack2',
#     'spellSlot': 65,
#     'trueDamage': 0,
#     'type': 'MINION'}],
#   'victimId': 3},
#  {'assistingParticipantIds': [2],
#   'bounty': 300,
#   'killStreakLength': 2,
#   'killerId': 5,
#   'position': {'x': 13303, 'y': 3953},
#   'shutdownBounty': 150,
#   'timestamp': 428244,
#   'type': 'CHAMPION_KILL',
#   'victimDamageDealt': [{'basic': False,
#     'magicDamage': 33,
#     'name': 'Vayne',
#     'participantId': 2,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Vayne',
#     'participantId': 2,
#     'physicalDamage': 98,
#     'spellName': 'vaynetumble',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Vayne',
#     'participantId': 2,
#     'physicalDamage': 56,
#     'spellName': 'vaynebasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Vayne',
#     'participantId': 2,
#     'physicalDamage': 56,
#     'spellName': 'vaynebasicattack2',
#     'spellSlot': 65,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Vayne',
#     'participantId': 5,
#     'physicalDamage': 52,
#     'spellName': 'vaynebasicattack4',
#     'spellSlot': 67,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 20,
#     'name': 'Vayne',
#     'participantId': 5,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Vayne',
#     'participantId': 5,
#     'physicalDamage': 56,
#     'spellName': 'vaynebasicattack3',
#     'spellSlot': 66,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimDamageReceived': [{'basic': False,
#     'magicDamage': 0,
#     'name': 'Ashe',
#     'participantId': 2,
#     'physicalDamage': 226,
#     'spellName': 'asheq',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Ashe',
#     'participantId': 2,
#     'physicalDamage': 93,
#     'spellName': 'volley',
#     'spellSlot': 1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Ashe',
#     'participantId': 2,
#     'physicalDamage': 139,
#     'spellName': 'ashebasicattack2',
#     'spellSlot': 65,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Ashe',
#     'participantId': 2,
#     'physicalDamage': 139,
#     'spellName': 'ashebasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 185,
#     'name': 'Sylas',
#     'participantId': 5,
#     'physicalDamage': 0,
#     'spellName': 'sylasw',
#     'spellSlot': 1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 93,
#     'name': 'Sylas',
#     'participantId': 5,
#     'physicalDamage': 0,
#     'spellName': 'sylaspassive',
#     'spellSlot': 63,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 82,
#     'name': 'Sylas',
#     'participantId': 5,
#     'physicalDamage': 0,
#     'spellName': 'sylase2',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 51,
#     'name': 'Sylas',
#     'participantId': 5,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimId': 9},
#  {'assistingParticipantIds': [2],
#   'bounty': 300,
#   'killStreakLength': 3,
#   'killerId': 5,
#   'position': {'x': 13550, 'y': 2573},
#   'shutdownBounty': 0,
#   'timestamp': 455735,
#   'type': 'CHAMPION_KILL',
#   'victimDamageDealt': [{'basic': True,
#     'magicDamage': 0,
#     'name': 'Taliyah',
#     'participantId': 2,
#     'physicalDamage': 46,
#     'spellName': 'taliyahbasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 218,
#     'name': 'Taliyah',
#     'participantId': 5,
#     'physicalDamage': 0,
#     'spellName': 'taliyahq',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 42,
#     'name': 'Taliyah',
#     'participantId': 5,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimDamageReceived': [{'basic': False,
#     'magicDamage': 0,
#     'name': 'Ashe',
#     'participantId': 2,
#     'physicalDamage': 82,
#     'spellName': 'asheq',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Ashe',
#     'participantId': 2,
#     'physicalDamage': 200,
#     'spellName': 'volley',
#     'spellSlot': 1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Ashe',
#     'participantId': 2,
#     'physicalDamage': 60,
#     'spellName': 'ashebasicattack2',
#     'spellSlot': 65,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Ashe',
#     'participantId': 2,
#     'physicalDamage': 150,
#     'spellName': 'ashebasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 182,
#     'name': 'Sylas',
#     'participantId': 5,
#     'physicalDamage': 0,
#     'spellName': 'sylaspassive',
#     'spellSlot': 63,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 363,
#     'name': 'Sylas',
#     'participantId': 5,
#     'physicalDamage': 0,
#     'spellName': 'sylasw',
#     'spellSlot': 1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 21,
#     'name': 'Sylas',
#     'participantId': 5,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimId': 7},
#  {'bounty': 300,
#   'killStreakLength': 0,
#   'killerId': 9,
#   'position': {'x': 13059, 'y': 3935},
#   'shutdownBounty': 150,
#   'timestamp': 483015,
#   'type': 'CHAMPION_KILL',
#   'victimDamageDealt': [{'basic': False,
#     'magicDamage': 11,
#     'name': 'Kindred',
#     'participantId': 9,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Kindred',
#     'participantId': 9,
#     'physicalDamage': 63,
#     'spellName': 'kindredpassivemanager',
#     'spellSlot': 63,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 121,
#     'name': 'Kindred',
#     'participantId': 9,
#     'physicalDamage': 0,
#     'spellName': 'kindredw',
#     'spellSlot': 1,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimDamageReceived': [{'basic': True,
#     'magicDamage': 0,
#     'name': 'SRU_ChaosMinionMelee',
#     'participantId': 0,
#     'physicalDamage': 40,
#     'spellName': 'sru_chaosminionrangedbasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'MINION'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'SRU_ChaosMinionMelee',
#     'participantId': 0,
#     'physicalDamage': 32,
#     'spellName': 'sru_chaosminionmeleebasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'MINION'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Vayne',
#     'participantId': 9,
#     'physicalDamage': 96,
#     'spellName': 'vaynecondemn',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 33,
#     'name': 'Vayne',
#     'participantId': 9,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Vayne',
#     'participantId': 9,
#     'physicalDamage': 59,
#     'spellName': 'vaynebasicattack3',
#     'spellSlot': 66,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Vayne',
#     'participantId': 9,
#     'physicalDamage': 0,
#     'spellName': 'vaynesilveredbolts',
#     'spellSlot': 1,
#     'trueDamage': 80,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Vayne',
#     'participantId': 9,
#     'physicalDamage': 55,
#     'spellName': 'vaynebasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Vayne',
#     'participantId': 9,
#     'physicalDamage': 55,
#     'spellName': 'vaynebasicattack2',
#     'spellSlot': 65,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Turret',
#     'participantId': 0,
#     'physicalDamage': 495,
#     'spellName': 'turretbasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'TOWER'}],
#   'victimId': 1},
#  {'bounty': 300,
#   'killStreakLength': 1,
#   'killerId': 9,
#   'position': {'x': 12643, 'y': 2765},
#   'shutdownBounty': 0,
#   'timestamp': 487457,
#   'type': 'CHAMPION_KILL',
#   'victimDamageDealt': [{'basic': False,
#     'magicDamage': 0,
#     'name': 'Ashe',
#     'participantId': 9,
#     'physicalDamage': 140,
#     'spellName': 'asheq',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Ashe',
#     'participantId': 9,
#     'physicalDamage': 186,
#     'spellName': 'volley',
#     'spellSlot': 1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Ashe',
#     'participantId': 9,
#     'physicalDamage': 174,
#     'spellName': 'ashebasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimDamageReceived': [{'basic': True,
#     'magicDamage': 0,
#     'name': 'SRU_ChaosMinionMelee',
#     'participantId': 0,
#     'physicalDamage': 10,
#     'spellName': 'sru_chaosminionrangedbasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'MINION'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'SRU_ChaosMinionMelee',
#     'participantId': 0,
#     'physicalDamage': 4,
#     'spellName': 'sru_chaosminionmeleebasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'MINION'},
#    {'basic': False,
#     'magicDamage': 47,
#     'name': 'Vayne',
#     'participantId': 9,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Vayne',
#     'participantId': 9,
#     'physicalDamage': 303,
#     'spellName': 'vaynetumble',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Vayne',
#     'participantId': 9,
#     'physicalDamage': 131,
#     'spellName': 'vaynetumble',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Vayne',
#     'participantId': 9,
#     'physicalDamage': 0,
#     'spellName': 'vaynesilveredbolts',
#     'spellSlot': 1,
#     'trueDamage': 84,
#     'type': 'OTHER'}],
#   'victimId': 2},
#  {'bounty': 219,
#   'killStreakLength': 2,
#   'killerId': 9,
#   'position': {'x': 11090, 'y': 1066},
#   'shutdownBounty': 0,
#   'timestamp': 499161,
#   'type': 'CHAMPION_KILL',
#   'victimDamageDealt': [{'basic': False,
#     'magicDamage': 0,
#     'name': 'Blitzcrank',
#     'participantId': 9,
#     'physicalDamage': 96,
#     'spellName': 'powerfist',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimDamageReceived': [{'basic': True,
#     'magicDamage': 0,
#     'name': 'Vayne',
#     'participantId': 9,
#     'physicalDamage': 56,
#     'spellName': 'vaynebasicattack4',
#     'spellSlot': 67,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 113,
#     'name': 'Vayne',
#     'participantId': 9,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Vayne',
#     'participantId': 9,
#     'physicalDamage': 216,
#     'spellName': 'vaynetumble',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Vayne',
#     'participantId': 9,
#     'physicalDamage': 369,
#     'spellName': 'vaynetumble',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Vayne',
#     'participantId': 9,
#     'physicalDamage': 56,
#     'spellName': 'vaynebasicattack3',
#     'spellSlot': 66,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Vayne',
#     'participantId': 9,
#     'physicalDamage': 98,
#     'spellName': 'vaynecritattack',
#     'spellSlot': 73,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Vayne',
#     'participantId': 9,
# ...
#     'physicalDamage': 0,
#     'spellName': 'taliyahe',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Camille',
#     'participantId': 6,
#     'physicalDamage': 5,
#     'spellName': 'camilleq2',
#     'spellSlot': 0,
#     'trueDamage': 440,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Camille',
#     'participantId': 6,
#     'physicalDamage': 0,
#     'spellName': 'camiller',
#     'spellSlot': 3,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Camille',
#     'participantId': 6,
#     'physicalDamage': 4,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 81,
#     'type': 'OTHER'}],
#   'victimId': 3},
#  {'assistingParticipantIds': [4],
#   'bounty': 300,
#   'killStreakLength': 0,
#   'killerId': 5,
#   'position': {'x': 1561, 'y': 723},
#   'shutdownBounty': 150,
#   'timestamp': 1884932,
#   'type': 'CHAMPION_KILL',
#   'victimDamageDealt': [{'basic': False,
#     'magicDamage': 0,
#     'name': 'Naafiri',
#     'participantId': 5,
#     'physicalDamage': 0,
#     'spellName': 'summonerdot',
#     'spellSlot': 4,
#     'trueDamage': 234,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Naafiri',
#     'participantId': 5,
#     'physicalDamage': 714,
#     'spellName': '',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Naafiri',
#     'participantId': 5,
#     'physicalDamage': 289,
#     'spellName': 'naafirip',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Naafiri',
#     'participantId': 5,
#     'physicalDamage': 102,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Naafiri',
#     'participantId': 5,
#     'physicalDamage': 277,
#     'spellName': 'naafiriw',
#     'spellSlot': 1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Naafiri',
#     'participantId': 5,
#     'physicalDamage': 204,
#     'spellName': 'naafiribasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Naafiri',
#     'participantId': 5,
#     'physicalDamage': 428,
#     'spellName': 'naafirie',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimDamageReceived': [{'basic': False,
#     'magicDamage': 135,
#     'name': 'Sylas',
#     'participantId': 5,
#     'physicalDamage': 0,
#     'spellName': '6656cast',
#     'spellSlot': 7,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 185,
#     'name': 'Sylas',
#     'participantId': 5,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 253,
#     'name': 'Sylas',
#     'participantId': 5,
#     'physicalDamage': 0,
#     'spellName': 'sylasq',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 168,
#     'name': 'Sylas',
#     'participantId': 5,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 196,
#     'name': 'Sylas',
#     'participantId': 5,
#     'physicalDamage': 0,
#     'spellName': 'sylaspassive',
#     'spellSlot': 63,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 672,
#     'name': 'Sylas',
#     'participantId': 5,
#     'physicalDamage': 0,
#     'spellName': 'sylasw',
#     'spellSlot': 1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Turret',
#     'participantId': 0,
#     'physicalDamage': 390,
#     'spellName': 'turretbasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'TOWER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'JarvanIV',
#     'participantId': 4,
#     'physicalDamage': 278,
#     'spellName': 'jarvanivdragonstrike',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'JarvanIV',
#     'participantId': 4,
#     'physicalDamage': 0,
#     'spellName': 'jarvanivmartialcadence',
#     'spellSlot': 63,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'JarvanIV',
#     'participantId': 4,
#     'physicalDamage': 0,
#     'spellName': 'jarvanivmartialcadence',
#     'spellSlot': 63,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimId': 8},
#  {'assistingParticipantIds': [6, 7, 8, 10],
#   'bounty': 300,
#   'killStreakLength': 1,
#   'killerId': 9,
#   'position': {'x': 1537, 'y': 1054},
#   'shutdownBounty': 0,
#   'timestamp': 1893874,
#   'type': 'CHAMPION_KILL',
#   'victimDamageDealt': [{'basic': False,
#     'magicDamage': 160,
#     'name': 'Sylas',
#     'participantId': 7,
#     'physicalDamage': 0,
#     'spellName': '6656cast',
#     'spellSlot': 7,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 111,
#     'name': 'Sylas',
#     'participantId': 7,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 599,
#     'name': 'Sylas',
#     'participantId': 7,
#     'physicalDamage': 0,
#     'spellName': 'sylasq',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 148,
#     'name': 'Sylas',
#     'participantId': 9,
#     'physicalDamage': 0,
#     'spellName': '6656cast',
#     'spellSlot': 7,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 77,
#     'name': 'Sylas',
#     'participantId': 9,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 439,
#     'name': 'Sylas',
#     'participantId': 9,
#     'physicalDamage': 0,
#     'spellName': 'sylasq',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 339,
#     'name': 'Sylas',
#     'participantId': 9,
#     'physicalDamage': 0,
#     'spellName': 'sylase2',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 160,
#     'name': 'Sylas',
#     'participantId': 9,
#     'physicalDamage': 0,
#     'spellName': 'sylaspassive',
#     'spellSlot': 63,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 26,
#     'name': 'Sylas',
#     'participantId': 9,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimDamageReceived': [{'basic': False,
#     'magicDamage': 34,
#     'name': 'Taliyah',
#     'participantId': 7,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 441,
#     'name': 'Taliyah',
#     'participantId': 7,
#     'physicalDamage': 0,
#     'spellName': 'taliyahq',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Taliyah',
#     'participantId': 7,
#     'physicalDamage': 0,
#     'spellName': 'burning',
#     'spellSlot': -1,
#     'trueDamage': 65,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Taliyah',
#     'participantId': 7,
#     'physicalDamage': 40,
#     'spellName': 'taliyahbasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 56,
#     'name': 'Taliyah',
#     'participantId': 10,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 60,
#     'name': 'Taliyah',
#     'participantId': 10,
#     'physicalDamage': 0,
#     'spellName': 'lulue',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 26,
#     'name': 'Taliyah',
#     'participantId': 10,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Naafiri',
#     'participantId': 8,
#     'physicalDamage': 0,
#     'spellName': 'summonerdot',
#     'spellSlot': 4,
#     'trueDamage': 234,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Naafiri',
#     'participantId': 8,
#     'physicalDamage': 714,
#     'spellName': '',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Naafiri',
#     'participantId': 8,
#     'physicalDamage': 289,
#     'spellName': 'naafirip',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Naafiri',
#     'participantId': 8,
#     'physicalDamage': 102,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Naafiri',
#     'participantId': 8,
#     'physicalDamage': 277,
#     'spellName': 'naafiriw',
#     'spellSlot': 1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Naafiri',
#     'participantId': 8,
#     'physicalDamage': 204,
#     'spellName': 'naafiribasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Naafiri',
#     'participantId': 8,
#     'physicalDamage': 428,
#     'spellName': 'naafirie',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Vayne',
#     'participantId': 9,
#     'physicalDamage': 460,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Vayne',
#     'participantId': 9,
#     'physicalDamage': 341,
#     'spellName': 'vaynetumble',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Vayne',
#     'participantId': 9,
#     'physicalDamage': 734,
#     'spellName': 'vaynetumble',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Vayne',
#     'participantId': 9,
#     'physicalDamage': 0,
#     'spellName': 'vaynesilveredbolts',
#     'spellSlot': 1,
#     'trueDamage': 289,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 57,
#     'name': 'Camille',
#     'participantId': 6,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Camille',
#     'participantId': 6,
#     'physicalDamage': 99,
#     'spellName': 'camillebasicattack4',
#     'spellSlot': 67,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimId': 5},
#  {'assistingParticipantIds': [6, 7, 10],
#   'bounty': 300,
#   'killStreakLength': 2,
#   'killerId': 9,
#   'position': {'x': 1757, 'y': 3382},
#   'shutdownBounty': 0,
#   'timestamp': 1897276,
#   'type': 'CHAMPION_KILL',
#   'victimDamageDealt': [{'basic': False,
#     'magicDamage': 0,
#     'name': 'JarvanIV',
#     'participantId': 9,
#     'physicalDamage': 348,
#     'spellName': 'jarvanivcataclysm',
#     'spellSlot': 3,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimDamageReceived': [{'basic': False,
#     'magicDamage': 592,
#     'name': 'Taliyah',
#     'participantId': 7,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 1077,
#     'name': 'Taliyah',
#     'participantId': 7,
#     'physicalDamage': 0,
#     'spellName': 'taliyahq',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Taliyah',
#     'participantId': 7,
#     'physicalDamage': 31,
#     'spellName': 'taliyahbasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 146,
#     'name': 'Taliyah',
#     'participantId': 7,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 40,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 791,
#     'name': 'Taliyah',
#     'participantId': 7,
#     'physicalDamage': 0,
#     'spellName': 'taliyahe',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Taliyah',
#     'participantId': 7,
#     'physicalDamage': 0,
#     'spellName': 'burning',
#     'spellSlot': -1,
#     'trueDamage': 43,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 56,
#     'name': 'Vayne',
#     'participantId': 9,
#     'physicalDamage': 439,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Vayne',
#     'participantId': 9,
#     'physicalDamage': 112,
#     'spellName': 'vaynebasicattack2',
#     'spellSlot': 65,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Vayne',
#     'participantId': 9,
#     'physicalDamage': 95,
#     'spellName': 'vaynecondemn',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Vayne',
#     'participantId': 9,
#     'physicalDamage': 0,
#     'spellName': 'vaynesilveredbolts',
#     'spellSlot': 1,
#     'trueDamage': 418,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Vayne',
#     'participantId': 9,
#     'physicalDamage': 486,
#     'spellName': 'vaynetumble',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Vayne',
#     'participantId': 9,
#     'physicalDamage': 568,
#     'spellName': 'vaynetumble',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 57,
#     'name': 'Camille',
#     'participantId': 6,
#     'physicalDamage': 30,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Camille',
#     'participantId': 6,
#     'physicalDamage': 4,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 332,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Camille',
#     'participantId': 6,
#     'physicalDamage': 5,
#     'spellName': 'camilleq2',
#     'spellSlot': 0,
#     'trueDamage': 388,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Camille',
#     'participantId': 6,
#     'physicalDamage': 109,
#     'spellName': 'camilleq',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'SRU_ChaosMinionSuper',
#     'participantId': 0,
#     'physicalDamage': 29,
#     'spellName': 'sru_chaosminionrangedbasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'MINION'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'SRU_ChaosMinionSuper',
#     'participantId': 0,
#     'physicalDamage': 195,
#     'spellName': 'sru_chaosminionsuperbasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'MINION'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'SRU_ChaosMinionSuper',
#     'participantId': 0,
#     'physicalDamage': 14,
#     'spellName': 'sru_chaosminionrangedbasicattack2',
#     'spellSlot': 65,
#     'trueDamage': 0,
#     'type': 'MINION'},
#    {'basic': False,
#     'magicDamage': 22,
#     'name': 'Taliyah',
#     'participantId': 10,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 81,
#     'name': 'Taliyah',
#     'participantId': 10,
#     'physicalDamage': 0,
#     'spellName': 'lulue',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 27,
#     'name': 'Taliyah',
#     'participantId': 10,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimId': 4}]

# %% [markdown]
# # kill_log에서 killerId의 값을 list로 묶기 -> k
#
# # kill_log에서 victimId의 값을 list로 묶기 - > v
#
# # kill_log에서 assistingParticipantIds의 값을 list로 묶기 - > a
#
# # 세개의 리스트를 각각 |로 묶기

# %%
k = list(map(lambda x: str(x['killerId']),kill_log))

# %%
v = list(map(lambda x: str(x['victimId']),kill_log))

# %%
def assi_cal(x):
    try:
        return ','.join(list(map(lambda y: str(y) ,x['assistingParticipantIds'])))
    except:
        return ''

# %%
a = list(map(lambda x : assi_cal(x) ,kill_log))

# %%
k[3]
# Out:
# '10'

# %%
a[3]
# Out:
# '9'

# %%
v[3]
# Out:
# '1'

# %%
k_str = '|'.join(k)

# %%
k_str
# Out:
# '9|2|1|10|6|1|5|9|7|5|0|9|5|5|9|9|9|1|1|8|2|9|7|8|10|2|7|1|2|9|6|9|8|8|3|2|7|4|2|9|9|9|4|7|6|1|3|8|9|9|8|2|9|2|9|5|4|6|4|8|5|2|7|7|5|9|4|4|1|5|7|9|8|6|8|5|9|9'

# %%
a_str = '|'.join(a)

# %%
a_str
# Out:
# '10|1,3||9|7|5||7,10|10|1||10|2|2|||||5||3||6|7,10|9|3|9,10|4,5|3|7|7,9,10|10||7|2|3|9,10|5|3,4|7,10|7,8,10|7,8||8,9|7,9,10|2,4,5|1,2,4|10|6,8,10|10|9,10|4|8,10|3|8,10|1,2,3|1,3,5|9,10|5|||1|9,10||2|7,10|3,5|3,5|2,3,4,5|1,2,3||6,10||8,10|6,7|4|6,7,8,10|6,7,10'

# %%
v_str = '|'.join(v)

# %%
v_str
# Out:
# '3|9|10|1|4|7|8|3|2|8|1|3|9|7|1|2|3|7|8|5|10|5|1|5|3|9|2|6|7|2|3|4|1|5|9|10|1|6|10|2|3|5|8|4|3|6|7|3|1|4|5|6|3|8|2|9|10|1|6|5|8|6|3|2|7|1|9|6|7|8|5|4|2|1|3|8|5|4'

# %% [markdown]
# # tmp.iloc[0].timelines['info']['frames']

# %%
tmp.iloc[4].timelines['info']['frames'][15]['events']
# Out:
# [{'itemId': 3076,
#   'participantId': 4,
#   'timestamp': 851333,
#   'type': 'ITEM_DESTROYED'},
#  {'itemId': 1011,
#   'participantId': 4,
#   'timestamp': 851333,
#   'type': 'ITEM_DESTROYED'},
#  {'itemId': 3075,
#   'participantId': 4,
#   'timestamp': 851333,
#   'type': 'ITEM_PURCHASED'},
#  {'assistingParticipantIds': [6, 7, 9, 10],
#   'bounty': 0,
#   'buildingType': 'TOWER_BUILDING',
#   'killerId': 8,
#   'laneType': 'MID_LANE',
#   'position': {'x': 4943, 'y': 4929},
#   'teamId': 100,
#   'timestamp': 851969,
#   'towerType': 'NEXUS_TURRET',
#   'type': 'BUILDING_KILL'},
#  {'assistingParticipantIds': [7, 8, 9, 10],
#   'bounty': 180,
#   'killStreakLength': 1,
#   'killerId': 6,
#   'position': {'x': 5261, 'y': 4555},
#   'shutdownBounty': 0,
#   'timestamp': 853102,
#   'type': 'CHAMPION_KILL',
#   'victimDamageDealt': [{'basic': False,
#     'magicDamage': 82,
#     'name': 'Sion',
#     'participantId': 6,
#     'physicalDamage': 0,
#     'spellName': 'sione',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Sion',
#     'participantId': 7,
#     'physicalDamage': 172,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Sion',
#     'participantId': 7,
#     'physicalDamage': 42,
#     'spellName': 'sionbasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 91,
#     'name': 'Sion',
#     'participantId': 9,
#     'physicalDamage': 0,
#     'spellName': 'sione',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimDamageReceived': [{'basic': False,
#     'magicDamage': 169,
#     'name': 'Kayle',
#     'participantId': 9,
#     'physicalDamage': 0,
#     'spellName': 'kaylepassive',
#     'spellSlot': 63,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Kayle',
#     'participantId': 9,
#     'physicalDamage': 0,
#     'spellName': 'kayleeattackupgrade',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 251,
#     'name': 'Kayle',
#     'participantId': 9,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Kayle',
#     'participantId': 9,
#     'physicalDamage': 223,
#     'spellName': 'kaylebasicattack4',
#     'spellSlot': 50,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 324,
#     'name': 'Kayle',
#     'participantId': 9,
#     'physicalDamage': 368,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Kayle',
#     'participantId': 9,
#     'physicalDamage': 211,
#     'spellName': 'kaylebasicattack3',
#     'spellSlot': 50,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 136,
#     'name': 'Kayle',
#     'participantId': 9,
#     'physicalDamage': 0,
#     'spellName': 'kayleq',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Kayle',
#     'participantId': 9,
#     'physicalDamage': 78,
#     'spellName': 'kaylebasicattack2',
#     'spellSlot': 50,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 250,
#     'name': 'Malzahar',
#     'participantId': 8,
#     'physicalDamage': 0,
#     'spellName': 'malzahare',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 183,
#     'name': 'Malzahar',
#     'participantId': 8,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 75,
#     'name': 'Malzahar',
#     'participantId': 8,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 38,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 192,
#     'name': 'Malzahar',
#     'participantId': 8,
#     'physicalDamage': 0,
#     'spellName': 'malzaharq',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 242,
#     'name': 'Malzahar',
#     'participantId': 8,
#     'physicalDamage': 0,
#     'spellName': 'malzaharw',
#     'spellSlot': 1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 37,
#     'name': 'Ashe',
#     'participantId': 6,
#     'physicalDamage': 1016,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Ashe',
#     'participantId': 6,
#     'physicalDamage': 262,
#     'spellName': 'ashebasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Ashe',
#     'participantId': 6,
#     'physicalDamage': 156,
#     'spellName': 'ashebasicattack2',
#     'spellSlot': 65,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Ashe',
#     'participantId': 6,
#     'physicalDamage': 188,
#     'spellName': 'volley',
#     'spellSlot': 1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 88,
#     'name': 'Brand',
#     'participantId': 10,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 68,
#     'name': 'Brand',
#     'participantId': 10,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 36,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 142,
#     'name': 'Brand',
#     'participantId': 10,
#     'physicalDamage': 0,
#     'spellName': 'brande',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'HA_ChaosMinionRanged',
#     'participantId': 0,
#     'physicalDamage': 10,
#     'spellName': 'ha_chaosminionrangedbasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'MINION'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'HA_ChaosMinionRanged',
#     'participantId': 0,
#     'physicalDamage': 23,
#     'spellName': 'ha_chaosminionrangedbasicattack2',
#     'spellSlot': 65,
#     'trueDamage': 0,
#     'type': 'MINION'},
#    {'basic': False,
#     'magicDamage': 216,
#     'name': 'Jax',
#     'participantId': 7,
#     'physicalDamage': 0,
#     'spellName': 'jaxe',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Jax',
#     'participantId': 7,
#     'physicalDamage': 184,
#     'spellName': 'jaxq',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 103,
#     'name': 'Jax',
#     'participantId': 7,
#     'physicalDamage': 0,
#     'spellName': 'jaxw',
#     'spellSlot': 1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Jax',
#     'participantId': 7,
#     'physicalDamage': 204,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Jax',
#     'participantId': 7,
#     'physicalDamage': 112,
#     'spellName': 'jaxbasicattack2',
#     'spellSlot': 65,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimId': 3},
#  {'level': 16, 'participantId': 8, 'timestamp': 853102, 'type': 'LEVEL_UP'},
#  {'level': 14, 'participantId': 1, 'timestamp': 853500, 'type': 'LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 8,
#   'skillSlot': 4,
#   'timestamp': 854435,
#   'type': 'SKILL_LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 1,
#   'skillSlot': 2,
#   'timestamp': 856888,
#   'type': 'SKILL_LEVEL_UP'},
#  {'itemId': 2052,
#   'participantId': 7,
#   'timestamp': 860111,
#   'type': 'ITEM_DESTROYED'},
#  {'itemId': 1057,
#   'participantId': 3,
#   'timestamp': 860278,
#   'type': 'ITEM_DESTROYED'},
#  {'itemId': 1028,
#   'participantId': 3,
#   'timestamp': 860278,
#   'type': 'ITEM_DESTROYED'},
#  {'itemId': 3066,
#   'participantId': 3,
#   'timestamp': 860278,
#   'type': 'ITEM_DESTROYED'},
#  {'itemId': 4401,
#   'participantId': 3,
#   'timestamp': 860278,
#   'type': 'ITEM_PURCHASED'},
#  {'level': 15, 'participantId': 10, 'timestamp': 861714, 'type': 'LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 10,
#   'skillSlot': 3,
#   'timestamp': 863242,
#   'type': 'SKILL_LEVEL_UP'},
#  {'level': 16, 'participantId': 3, 'timestamp': 867010, 'type': 'LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 3,
#   'skillSlot': 4,
#   'timestamp': 868343,
#   'type': 'SKILL_LEVEL_UP'},
#  {'level': 15, 'participantId': 5, 'timestamp': 872074, 'type': 'LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 5,
#   'skillSlot': 3,
#   'timestamp': 875544,
#   'type': 'SKILL_LEVEL_UP'},
#  {'itemId': 1028,
#   'participantId': 3,
#   'timestamp': 876758,
#   'type': 'ITEM_PURCHASED'},
#  {'itemId': 1029,
#   'participantId': 3,
#   'timestamp': 877556,
#   'type': 'ITEM_PURCHASED'},
#  {'assistingParticipantIds': [6, 8, 10],
#   'bounty': 180,
#   'killStreakLength': 1,
#   'killerId': 7,
#   'position': {'x': 4998, 'y': 5931},
#   'shutdownBounty': 0,
#   'timestamp': 878890,
#   'type': 'CHAMPION_KILL',
#   'victimDamageDealt': [{'basic': False,
#     'magicDamage': 171,
#     'name': 'Ahri',
#     'participantId': 7,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 178,
#     'name': 'Ahri',
#     'participantId': 7,
#     'physicalDamage': 0,
#     'spellName': 'ahrie',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 68,
#     'name': 'Ahri',
#     'participantId': 7,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 35,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 165,
#     'name': 'Ahri',
#     'participantId': 7,
#     'physicalDamage': 0,
#     'spellName': 'ahriq',
#     'spellSlot': 0,
#     'trueDamage': 287,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 380,
#     'name': 'Ahri',
#     'participantId': 7,
#     'physicalDamage': 0,
#     'spellName': 'ahriw',
#     'spellSlot': 1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 118,
#     'name': 'Ahri',
#     'participantId': 7,
#     'physicalDamage': 0,
#     'spellName': 'ahrir',
#     'spellSlot': 3,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 2,
#     'name': 'Ahri',
#     'participantId': 8,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 23,
#     'name': 'Ahri',
#     'participantId': 8,
#     'physicalDamage': 0,
#     'spellName': 'ahriq',
#     'spellSlot': 0,
#     'trueDamage': 326,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 211,
#     'name': 'Ahri',
#     'participantId': 10,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 475,
#     'name': 'Ahri',
#     'participantId': 10,
#     'physicalDamage': 0,
#     'spellName': 'ahriq',
#     'spellSlot': 0,
#     'trueDamage': 622,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 275,
#     'name': 'Ahri',
#     'participantId': 10,
#     'physicalDamage': 0,
#     'spellName': 'ahriw',
#     'spellSlot': 1,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimDamageReceived': [{'basic': False,
#     'magicDamage': 243,
#     'name': 'Malzahar',
#     'participantId': 8,
#     'physicalDamage': 0,
#     'spellName': 'malzaharq',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 149,
#     'name': 'Malzahar',
#     'participantId': 8,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 138,
#     'name': 'Malzahar',
#     'participantId': 8,
#     'physicalDamage': 0,
#     'spellName': 'malzahare',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Malzahar',
#     'participantId': 8,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 36,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Malzahar',
#     'participantId': 8,
#     'physicalDamage': 42,
#     'spellName': 'malzaharbasicattack2',
#     'spellSlot': 65,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Jax',
#     'participantId': 7,
#     'physicalDamage': 203,
#     'spellName': 'jaxq',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 189,
#     'name': 'Jax',
#     'participantId': 7,
#     'physicalDamage': 0,
#     'spellName': 'jaxe',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 87,
#     'name': 'Jax',
#     'participantId': 7,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': 3,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Jax',
#     'participantId': 7,
#     'physicalDamage': 140,
#     'spellName': 'jaxbasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Jax',
#     'participantId': 7,
#     'physicalDamage': 167,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Jax',
#     'participantId': 7,
#     'physicalDamage': 140,
#     'spellName': 'jaxbasicattack2',
#     'spellSlot': 65,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Brand',
#     'participantId': 10,
#     'physicalDamage': 46,
#     'spellName': 'brandbasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimId': 5},
#  {'assistingParticipantIds': [1, 5],
#   'bounty': 180,
#   'killStreakLength': 0,
#   'killerId': 4,
#   'position': {'x': 6214, 'y': 6279},
#   'shutdownBounty': 0,
#   'timestamp': 878924,
#   'type': 'CHAMPION_KILL',
#   'victimDamageDealt': [{'basic': False,
#     'magicDamage': 18,
#     'name': 'Brand',
#     'participantId': 1,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Brand',
#     'participantId': 1,
#     'physicalDamage': 44,
#     'spellName': 'brandbasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 164,
#     'name': 'Brand',
#     'participantId': 1,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 16,
#     'name': 'Brand',
#     'participantId': 1,
#     'physicalDamage': 0,
#     'spellName': 'brandpassive',
#     'spellSlot': 63,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 156,
#     'name': 'Brand',
#     'participantId': 1,
#     'physicalDamage': 0,
#     'spellName': 'brande',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 350,
#     'name': 'Brand',
#     'participantId': 4,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 120,
#     'name': 'Brand',
#     'participantId': 4,
#     'physicalDamage': 0,
#     'spellName': 'brandpassive',
#     'spellSlot': 63,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 140,
#     'name': 'Brand',
#     'participantId': 4,
#     'physicalDamage': 0,
#     'spellName': 'brande',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Brand',
#     'participantId': 4,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 66,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 184,
#     'name': 'Brand',
#     'participantId': 4,
#     'physicalDamage': 0,
#     'spellName': 'brandq',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimDamageReceived': [{'basic': True,
#     'magicDamage': 0,
#     'name': 'HA_OrderMinionRanged',
#     'participantId': 0,
#     'physicalDamage': 14,
#     'spellName': 'ha_orderminionrangedbasicattack2',
#     'spellSlot': 65,
#     'trueDamage': 0,
#     'type': 'MINION'},
#    {'basic': False,
#     'magicDamage': 211,
#     'name': 'Ahri',
#     'participantId': 5,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 475,
#     'name': 'Ahri',
#     'participantId': 5,
#     'physicalDamage': 0,
#     'spellName': 'ahriq',
#     'spellSlot': 0,
#     'trueDamage': 622,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 275,
#     'name': 'Ahri',
#     'participantId': 5,
#     'physicalDamage': 0,
#     'spellName': 'ahriw',
#     'spellSlot': 1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'MasterYi',
#     'participantId': 1,
#     'physicalDamage': 0,
#     'spellName': 'wujustyle',
#     'spellSlot': 2,
#     'trueDamage': 128,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'MasterYi',
#     'participantId': 1,
#     'physicalDamage': 256,
#     'spellName': 'alphastrike',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'MasterYi',
#     'participantId': 1,
#     'physicalDamage': 235,
#     'spellName': 'masteryibasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Fizz',
#     'participantId': 4,
#     'physicalDamage': 216,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 106,
#     'name': 'Fizz',
#     'participantId': 4,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimId': 10},
#  {'assistingParticipantIds': [6, 7, 8, 10],
#   'bounty': 180,
#   'killStreakLength': 0,
#   'killerId': 9,
#   'position': {'x': 6549, 'y': 6327},
#   'shutdownBounty': 0,
#   'timestamp': 879360,
#   'type': 'CHAMPION_KILL',
#   'victimDamageDealt': [{'basic': True,
#     'magicDamage': 0,
#     'name': 'Fizz',
#     'participantId': 6,
#     'physicalDamage': 210,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 254,
#     'name': 'Fizz',
#     'participantId': 6,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Fizz',
#     'participantId': 6,
#     'physicalDamage': 51,
#     'spellName': 'fizzw',
#     'spellSlot': 1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 141,
#     'name': 'Fizz',
#     'participantId': 6,
#     'physicalDamage': 0,
#     'spellName': 'fizzw',
#     'spellSlot': 1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Fizz',
#     'participantId': 7,
#     'physicalDamage': 155,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 167,
#     'name': 'Fizz',
#     'participantId': 7,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 90,
#     'name': 'Fizz',
#     'participantId': 7,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 35,
#     'name': 'Fizz',
#     'participantId': 7,
#     'physicalDamage': 0,
#     'spellName': 'fizzbasicattack2',
#     'spellSlot': 65,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Fizz',
#     'participantId': 7,
#     'physicalDamage': 36,
#     'spellName': 'fizzbasicattack2',
#     'spellSlot': 65,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 223,
#     'name': 'Fizz',
#     'participantId': 8,
#     'physicalDamage': 0,
#     'spellName': 'fizze',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 77,
#     'name': 'Fizz',
#     'participantId': 8,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 325,
#     'name': 'Fizz',
#     'participantId': 9,
#     'physicalDamage': 0,
#     'spellName': 'fizzr',
#     'spellSlot': 3,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 144,
#     'name': 'Fizz',
#     'participantId': 9,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimDamageReceived': [{'basic': False,
#     'magicDamage': 368,
#     'name': 'Brand',
#     'participantId': 10,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 120,
#     'name': 'Brand',
#     'participantId': 10,
#     'physicalDamage': 0,
#     'spellName': 'brandpassive',
#     'spellSlot': 63,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 140,
#     'name': 'Brand',
#     'participantId': 10,
#     'physicalDamage': 0,
#     'spellName': 'brande',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Brand',
#     'participantId': 10,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 66,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 184,
#     'name': 'Brand',
#     'participantId': 10,
#     'physicalDamage': 0,
#     'spellName': 'brandq',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'HA_ChaosMinionMelee',
#     'participantId': 0,
#     'physicalDamage': 8,
#     'spellName': 'ha_chaosminionrangedbasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'MINION'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'HA_ChaosMinionMelee',
#     'participantId': 0,
#     'physicalDamage': 6,
#     'spellName': 'ha_chaosminionmeleebasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'MINION'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Jax',
#     'participantId': 7,
#     'physicalDamage': 136,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Jax',
#     'participantId': 7,
#     'physicalDamage': 77,
#     'spellName': 'snowballfollowupcast',
#     'spellSlot': 4,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Jax',
#     'participantId': 7,
#     'physicalDamage': 0,
#     'spellName': 'snowballfollowupcast',
#     'spellSlot': 4,
#     'trueDamage': 85,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Jax',
#     'participantId': 7,
#     'physicalDamage': 0,
#     'spellName': 'summonersnowball',
#     'spellSlot': 4,
#     'trueDamage': 85,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Jax',
#     'participantId': 7,
#     'physicalDamage': 78,
#     'spellName': '',
#     'spellSlot': 3,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 57,
#     'name': 'Jax',
#     'participantId': 7,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': 3,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 100,
#     'name': 'Jax',
#     'participantId': 7,
#     'physicalDamage': 78,
#     'spellName': 'jaxw',
#     'spellSlot': 1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Jax',
#     'participantId': 7,
#     'physicalDamage': 78,
#     'spellName': 'jaxbasicattack2',
#     'spellSlot': 65,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Ashe',
#     'participantId': 6,
#     'physicalDamage': 999,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Ashe',
#     'participantId': 6,
#     'physicalDamage': 70,
#     'spellName': 'ashebasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Ashe',
#     'participantId': 6,
#     'physicalDamage': 98,
#     'spellName': 'ashebasicattack2',
#     'spellSlot': 65,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Ashe',
#     'participantId': 6,
#     'physicalDamage': 866,
#     'spellName': 'asheq',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 26,
#     'name': 'Kayle',
#     'participantId': 9,
#     'physicalDamage': 0,
#     'spellName': 'kaylepassive',
#     'spellSlot': 63,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 34,
#     'name': 'Kayle',
#     'participantId': 9,
#     'physicalDamage': 45,
#     'spellName': 'kayleeattackupgrade',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 129,
#     'name': 'Kayle',
#     'participantId': 9,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Kayle',
#     'participantId': 9,
#     'physicalDamage': 54,
#     'spellName': 'kaylebasicattack4',
#     'spellSlot': 50,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 185,
#     'name': 'Kayle',
#     'participantId': 9,
#     'physicalDamage': 204,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 131,
#     'name': 'Kayle',
#     'participantId': 9,
#     'physicalDamage': 0,
#     'spellName': 'kayleq',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Kayle',
#     'participantId': 9,
#     'physicalDamage': 54,
#     'spellName': 'kaylebasicattack',
#     'spellSlot': 50,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Kayle',
#     'participantId': 9,
#     'physicalDamage': 108,
#     'spellName': 'kaylebasicattack3',
#     'spellSlot': 50,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 63,
#     'name': 'Malzahar',
#     'participantId': 8,
#     'physicalDamage': 0,
#     'spellName': 'malzaharw',
#     'spellSlot': 1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Malzahar',
#     'participantId': 8,
#     'physicalDamage': 30,
#     'spellName': 'malzaharbasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 75,
#     'name': 'Malzahar',
#     'participantId': 8,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 99,
#     'name': 'Malzahar',
#     'participantId': 8,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimId': 4},
#  {'assistingParticipantIds': [2, 4, 5],
#   'bounty': 180,
#   'killStreakLength': 0,
#   'killerId': 1,
#   'position': {'x': 5045, 'y': 5685},
#   'shutdownBounty': 0,
#   'timestamp': 880169,
#   'type': 'CHAMPION_KILL',
#   'victimDamageDealt': [{'basic': False,
#     'magicDamage': 0,
#     'name': 'Jax',
#     'participantId': 1,
#     'physicalDamage': 158,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 123,
#     'name': 'Jax',
#     'participantId': 1,
#     'physicalDamage': 132,
#     'spellName': 'jaxw',
#     'spellSlot': 1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Jax',
#     'participantId': 2,
#     'physicalDamage': 143,
#     'spellName': '',
#     'spellSlot': 3,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 92,
#     'name': 'Jax',
#     'participantId': 2,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': 3,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 200,
#     'name': 'Jax',
#     'participantId': 2,
#     'physicalDamage': 0,
#     'spellName': 'jaxe',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 159,
#     'name': 'Jax',
#     'participantId': 2,
#     'physicalDamage': 143,
#     'spellName': 'jaxw',
#     'spellSlot': 1,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimDamageReceived': [{'basic': True,
#     'magicDamage': 0,
#     'name': 'Jinx',
#     'participantId': 2,
#     'physicalDamage': 140,
#     'spellName': 'jinxqcritattack',
#     'spellSlot': 74,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Jinx',
#     'participantId': 2,
#     'physicalDamage': 86,
#     'spellName': 'jinxqattack2',
#     'spellSlot': 70,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'HA_OrderMinionRanged',
#     'participantId': 0,
#     'physicalDamage': 5,
#     'spellName': 'ha_orderminionmeleebasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'MINION'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'HA_OrderMinionRanged',
#     'participantId': 0,
#     'physicalDamage': 21,
#     'spellName': 'ha_orderminionrangedbasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'MINION'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Sion',
#     'participantId': 3,
#     'physicalDamage': 172,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Sion',
#     'participantId': 3,
#     'physicalDamage': 84,
#     'spellName': 'sionbasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Sion',
#     'participantId': 3,
#     'physicalDamage': 106,
#     'spellName': 'sionpassive',
#     'spellSlot': 63,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 171,
#     'name': 'Ahri',
#     'participantId': 5,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 178,
#     'name': 'Ahri',
#     'participantId': 5,
#     'physicalDamage': 0,
#     'spellName': 'ahrie',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 68,
#     'name': 'Ahri',
#     'participantId': 5,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 35,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 165,
#     'name': 'Ahri',
#     'participantId': 5,
#     'physicalDamage': 0,
#     'spellName': 'ahriq',
#     'spellSlot': 0,
#     'trueDamage': 287,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 380,
#     'name': 'Ahri',
#     'participantId': 5,
#     'physicalDamage': 0,
#     'spellName': 'ahriw',
#     'spellSlot': 1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 118,
#     'name': 'Ahri',
#     'participantId': 5,
#     'physicalDamage': 0,
#     'spellName': 'ahrir',
#     'spellSlot': 3,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'MasterYi',
#     'participantId': 1,
#     'physicalDamage': 150,
#     'spellName': 'snowballfollowupcast',
#     'spellSlot': 4,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'MasterYi',
#     'participantId': 1,
#     'physicalDamage': 104,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 123,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'MasterYi',
#     'participantId': 1,
#     'physicalDamage': 0,
#     'spellName': 'snowballfollowupcast',
#     'spellSlot': 4,
#     'trueDamage': 80,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'MasterYi',
#     'participantId': 1,
#     'physicalDamage': 0,
#     'spellName': 'summonersnowball',
#     'spellSlot': 4,
#     'trueDamage': 80,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'MasterYi',
#     'participantId': 1,
#     'physicalDamage': 69,
#     'spellName': 'masteryipassive',
#     'spellSlot': 63,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'MasterYi',
#     'participantId': 1,
#     'physicalDamage': 139,
#     'spellName': 'meditate',
#     'spellSlot': 1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'MasterYi',
#     'participantId': 1,
#     'physicalDamage': 0,
#     'spellName': 'wujustyle',
#     'spellSlot': 2,
#     'trueDamage': 249,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Fizz',
#     'participantId': 4,
#     'physicalDamage': 155,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 167,
#     'name': 'Fizz',
#     'participantId': 4,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 90,
#     'name': 'Fizz',
#     'participantId': 4,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 35,
#     'name': 'Fizz',
#     'participantId': 4,
#     'physicalDamage': 0,
#     'spellName': 'fizzbasicattack2',
#     'spellSlot': 65,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Fizz',
#     'participantId': 4,
#     'physicalDamage': 36,
#     'spellName': 'fizzbasicattack2',
#     'spellSlot': 65,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimId': 7},
#  {'assistingParticipantIds': [7, 10],
#   'bounty': 180,
#   'killStreakLength': 1,
#   'killerId': 8,
#   'position': {'x': 4550, 'y': 5499},
#   'shutdownBounty': 0,
#   'timestamp': 880970,
#   'type': 'CHAMPION_KILL',
#   'victimDamageDealt': [{'basic': False,
#     'magicDamage': 40,
#     'name': 'Jinx',
#     'participantId': 8,
#     'physicalDamage': 112,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Jinx',
#     'participantId': 8,
#     'physicalDamage': 178,
#     'spellName': 'jinxqcritattack',
#     'spellSlot': 74,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimDamageReceived': [{'basic': True,
#     'magicDamage': 0,
#     'name': 'Jax',
#     'participantId': 7,
#     'physicalDamage': 143,
#     'spellName': '',
#     'spellSlot': 3,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 92,
#     'name': 'Jax',
#     'participantId': 7,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': 3,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 200,
#     'name': 'Jax',
#     'participantId': 7,
#     'physicalDamage': 0,
#     'spellName': 'jaxe',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 159,
#     'name': 'Jax',
#     'participantId': 7,
#     'physicalDamage': 143,
#     'spellName': 'jaxw',
#     'spellSlot': 1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 164,
#     'name': 'Malzahar',
#     'participantId': 8,
#     'physicalDamage': 0,
#     'spellName': 'malzahare',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 62,
#     'name': 'Malzahar',
#     'participantId': 8,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 94,
#     'name': 'Malzahar',
#     'participantId': 8,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimId': 2},
#  {'assistingParticipantIds': [4],
#   'bounty': 180,
#   'killStreakLength': 1,
#   'killerId': 1,
#   'position': {'x': 6382, 'y': 5608},
#   'shutdownBounty': 0,
#   'timestamp': 882774,
#   'type': 'CHAMPION_KILL',
#   'victimDamageDealt': [{'basic': False,
#     'magicDamage': 30,
#     'name': 'Kayle',
#     'participantId': 1,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 44,
#     'name': 'Kayle',
#     'participantId': 1,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Kayle',
#     'participantId': 1,
#     'physicalDamage': 78,
#     'spellName': 'kaylebasicattack3',
#     'spellSlot': 50,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimDamageReceived': [{'basic': False,
#     'magicDamage': 325,
#     'name': 'Fizz',
#     'participantId': 4,
#     'physicalDamage': 0,
#     'spellName': 'fizzr',
#     'spellSlot': 3,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 144,
#     'name': 'Fizz',
#     'participantId': 4,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'MasterYi',
#     'participantId': 1,
#     'physicalDamage': 12,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'MasterYi',
#     'participantId': 1,
#     'physicalDamage': 343,
#     'spellName': 'alphastrike',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'MasterYi',
#     'participantId': 1,
#     'physicalDamage': 237,
#     'spellName': 'masteryibasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimId': 9},
#  {'killType': 'KILL_MULTI',
#   'killerId': 1,
#   'multiKillLength': 2,
#   'position': {'x': 6233, 'y': 5729},
#   'timestamp': 882774,
#   'type': 'CHAMPION_SPECIAL_KILL'},
#  {'level': 15, 'participantId': 4, 'timestamp': 882774, 'type': 'LEVEL_UP'},
#  {'itemId': 3108,
#   'participantId': 7,
#   'timestamp': 884010,
#   'type': 'ITEM_PURCHASED'},
#  {'itemId': 1033,
#   'participantId': 4,
#   'timestamp': 884110,
#   'type': 'ITEM_PURCHASED'},
#  {'assistingParticipantIds': [7, 8, 9, 10],
#   'bounty': 180,
#   'killStreakLength': 2,
#   'killerId': 6,
#   'position': {'x': 5780, 'y': 5249},
#   'shutdownBounty': 0,
#   'timestamp': 884545,
#   'type': 'CHAMPION_KILL',
#   'victimDamageDealt': [{'basic': False,
#     'magicDamage': 0,
#     'name': 'MasterYi',
#     'participantId': 6,
#     'physicalDamage': 559,
#     'spellName': 'alphastrike',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'MasterYi',
#     'participantId': 8,
#     'physicalDamage': 275,
#     'spellName': 'alphastrike',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimDamageReceived': [{'basic': False,
#     'magicDamage': 51,
#     'name': 'Ashe',
#     'participantId': 6,
#     'physicalDamage': 573,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Ashe',
#     'participantId': 6,
#     'physicalDamage': 117,
#     'spellName': 'ashebasicattack2',
#     'spellSlot': 65,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Ashe',
#     'participantId': 6,
#     'physicalDamage': 136,
#     'spellName': 'ashecritattack',
#     'spellSlot': 73,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Ashe',
#     'participantId': 6,
#     'physicalDamage': 256,
#     'spellName': 'ashebasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 30,
#     'name': 'Kayle',
#     'participantId': 9,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 44,
#     'name': 'Kayle',
#     'participantId': 9,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Kayle',
#     'participantId': 9,
#     'physicalDamage': 78,
#     'spellName': 'kaylebasicattack3',
#     'spellSlot': 50,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Jax',
#     'participantId': 7,
#     'physicalDamage': 158,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 123,
#     'name': 'Jax',
#     'participantId': 7,
#     'physicalDamage': 132,
#     'spellName': 'jaxw',
#     'spellSlot': 1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 18,
#     'name': 'Brand',
#     'participantId': 10,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Brand',
#     'participantId': 10,
#     'physicalDamage': 44,
#     'spellName': 'brandbasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 200,
#     'name': 'Brand',
#     'participantId': 10,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 16,
#     'name': 'Brand',
#     'participantId': 10,
#     'physicalDamage': 0,
#     'spellName': 'brandpassive',
#     'spellSlot': 63,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 156,
#     'name': 'Brand',
#     'participantId': 10,
#     'physicalDamage': 0,
#     'spellName': 'brande',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'HA_ChaosMinionRanged',
#     'participantId': 0,
#     'physicalDamage': 30,
#     'spellName': 'ha_chaosminionrangedbasicattack2',
#     'spellSlot': 65,
#     'trueDamage': 0,
#     'type': 'MINION'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'HA_ChaosMinionRanged',
#     'participantId': 0,
#     'physicalDamage': 7,
#     'spellName': 'ha_chaosminionmeleebasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'MINION'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'HA_ChaosMinionRanged',
#     'participantId': 0,
#     'physicalDamage': 33,
#     'spellName': 'ha_chaosminionsiegebasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'MINION'},
#    {'basic': False,
#     'magicDamage': 94,
#     'name': 'Malzahar',
#     'participantId': 8,
#     'physicalDamage': 0,
#     'spellName': 'malzahare',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 81,
#     'name': 'Malzahar',
#     'participantId': 8,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 36,
#     'name': 'Malzahar',
#     'participantId': 8,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 73,
#     'name': 'Malzahar',
#     'participantId': 8,
#     'physicalDamage': 0,
#     'spellName': 'malzaharw',
#     'spellSlot': 1,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimId': 1},
#  {'killType': 'KILL_ACE',
#   'killerId': 6,
#   'position': {'x': 5803, 'y': 6145},
#   'timestamp': 884545,
#   'type': 'CHAMPION_SPECIAL_KILL'},
#  {'level': 16, 'participantId': 6, 'timestamp': 884545, 'type': 'LEVEL_UP'},
#  {'itemId': 3191,
#   'participantId': 7,
#   'timestamp': 884911,
#   'type': 'ITEM_PURCHASED'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 4,
#   'skillSlot': 1,
#   'timestamp': 885143,
#   'type': 'SKILL_LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 6,
#   'skillSlot': 4,
#   'timestamp': 885676,
#   'type': 'SKILL_LEVEL_UP'},
#  {'itemId': 1043,
#   'participantId': 9,
#   'timestamp': 886613,
#   'type': 'ITEM_DESTROYED'},
#  {'itemId': 3108,
#   'participantId': 9,
#   'timestamp': 886613,
#   'type': 'ITEM_DESTROYED'},
#  {'itemId': 3115,
#   'participantId': 9,
#   'timestamp': 886613,
#   'type': 'ITEM_PURCHASED'},
#  {'itemId': 3035,
#   'participantId': 2,
#   'timestamp': 887651,
#   'type': 'ITEM_DESTROYED'},
#  {'itemId': 1018,
#   'participantId': 2,
#   'timestamp': 887651,
#   'type': 'ITEM_DESTROYED'},
#  {'itemId': 3036,
#   'participantId': 2,
#   'timestamp': 887651,
#   'type': 'ITEM_PURCHASED'},
#  {'itemId': 1058,
#   'participantId': 5,
#   'timestamp': 887651,
#   'type': 'ITEM_DESTROYED'},
#  {'itemId': 1058,
#   'participantId': 5,
#   'timestamp': 887651,
#   'type': 'ITEM_DESTROYED'},
#  {'itemId': 3089,
#   'participantId': 5,
#   'timestamp': 887651,
#   'type': 'ITEM_PURCHASED'},
#  {'level': 16, 'participantId': 7, 'timestamp': 896030, 'type': 'LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 7,
#   'skillSlot': 4,
#   'timestamp': 897001,
#   'type': 'SKILL_LEVEL_UP'}]

# %%
tmp
# Out:
#           matchId  gameDuration    gameVersion  participantId championName  \
# 0   KR_6423842371          1899  13.6.499.7758              1         Kled
# 1   KR_6423842371          1899  13.6.499.7758              2        Sylas
# 2   KR_6423842371          1899  13.6.499.7758              3         Sett
# 3   KR_6423842371          1899  13.6.499.7758              4        Xayah
# 4   KR_6423842371          1899  13.6.499.7758              5     Nautilus
# 5   KR_6423823464           101  13.6.499.7758              1       Irelia
# 6   KR_6423823464           101  13.6.499.7758              2      Karthus
# 7   KR_6423823464           101  13.6.499.7758              3      Leblanc
# 8   KR_6423823464           101  13.6.499.7758              4     Aphelios
# 9   KR_6423823464           101  13.6.499.7758              5         Pyke
# 10  KR_6418892621          1300  13.6.499.7165              1         Sion
# 11  KR_6418892621          1300  13.6.499.7165              2      Sejuani
# 12  KR_6418892621          1300  13.6.499.7165              3        Yasuo
# 13  KR_6418892621          1300  13.6.499.7165              4         Jinx
# 14  KR_6418892621          1300  13.6.499.7165              5        Milio
# 15  KR_6416420210          2554   13.6.499.913              1       Irelia
# 16  KR_6416420210          2554   13.6.499.913              2   MonkeyKing
# 17  KR_6416420210          2554   13.6.499.913              3         Fizz
# 18  KR_6416420210          2554   13.6.499.913              4         Zeri
# 19  KR_6416420210          2554   13.6.499.913              5         Pyke
# 20  KR_6423900737          1531  13.6.499.7758              1         Jinx
# 21  KR_6423900737          1531  13.6.499.7758              2         Shen
# 22  KR_6423900737          1531  13.6.499.7758              3        Leona
# 23  KR_6423900737          1531  13.6.499.7758              4         Ahri
# 24  KR_6423900737          1531  13.6.499.7758              5       LeeSin
# 0   KR_6423842371          1899  13.6.499.7758              6          Jax
# 1   KR_6423842371          1899  13.6.499.7758              7       LeeSin
# 2   KR_6423842371          1899  13.6.499.7758              8         Yone
# 3   KR_6423842371          1899  13.6.499.7758              9        Ziggs
# 4   KR_6423842371          1899  13.6.499.7758             10        Rakan
# 5   KR_6423823464           101  13.6.499.7758              6         Ryze
# 6   KR_6423823464           101  13.6.499.7758              7         Nunu
# 7   KR_6423823464           101  13.6.499.7758              8        Yasuo
# 8   KR_6423823464           101  13.6.499.7758              9        Sivir
# 9   KR_6423823464           101  13.6.499.7758             10       Thresh
# 10  KR_6418892621          1300  13.6.499.7165              6     Renekton
# 11  KR_6418892621          1300  13.6.499.7165              7      Karthus
# 12  KR_6418892621          1300  13.6.499.7165              8     Pantheon
# 13  KR_6418892621          1300  13.6.499.7165              9        Xayah
# 14  KR_6418892621          1300  13.6.499.7165             10          Zoe
# 15  KR_6416420210          2554   13.6.499.913              6       Kennen
# 16  KR_6416420210          2554   13.6.499.913              7        Elise
# 17  KR_6416420210          2554   13.6.499.913              8     Nocturne
# 18  KR_6416420210          2554   13.6.499.913              9        Kaisa
# 19  KR_6416420210          2554   13.6.499.913             10     Pantheon
# 20  KR_6423900737          1531  13.6.499.7758              6       Maokai
# 21  KR_6423900737          1531  13.6.499.7758              7         Yone
# 22  KR_6423900737          1531  13.6.499.7758              8       KSante
# 23  KR_6423900737          1531  13.6.499.7758              9         Jhin
# 24  KR_6423900737          1531  13.6.499.7758             10     JarvanIV
#
#    teamPosition  teamId    win  kills  deaths  ...  firstDT  laneTower  \
# 0           TOP     100   True      2       5  ...        0          1
# 1        JUNGLE     100   True     22       4  ...        0          0
# 2        MIDDLE     100   True      7       4  ...        0          1
# 3        BOTTOM     100   True      2       1  ...        0          1
# 4       UTILITY     100   True      1       5  ...        0          0
# 5           TOP     100  False      0       0  ...        0          0
# 6        JUNGLE     100  False      0       1  ...        0          0
# 7        MIDDLE     100  False      0       0  ...        0          0
# 8        BOTTOM     100  False      0       0  ...        0          0
# 9       UTILITY     100  False      0       0  ...        0          0
# 10          TOP     100  False      4       9  ...        0          1
# 11       JUNGLE     100  False      6       9  ...        0          0
# 12       MIDDLE     100  False      3      10  ...        1          1
# 13       BOTTOM     100  False      9      10  ...        0          1
# 14      UTILITY     100  False      0       7  ...        0          0
# 15          TOP     100   True      8      12  ...        0          1
# 16       JUNGLE     100   True      9       8  ...        0          0
# 17       MIDDLE     100   True     12       8  ...        1          1
# 18       BOTTOM     100   True     18       8  ...        0          1
# 19      UTILITY     100   True      7       8  ...        0          0
# 20       BOTTOM     100  False      2      10  ...        0          1
# 21          TOP     100  False      1       8  ...        1          1
# 22      UTILITY     100  False      1       7  ...        0          0
# 23       MIDDLE     100  False      3       6  ...        0          1
# 24       JUNGLE     100  False      5       7  ...        0          0
# 0           TOP     200  False      3       6  ...        0          1
# 1        JUNGLE     200  False      6       8  ...        0          0
# 2        MIDDLE     200  False      5       9  ...        0          1
# 3        BOTTOM     200  False      4       5  ...        1          1
# 4       UTILITY     200  False      1       6  ...        0          0
# 5           TOP     200   True      0       0  ...        0          0
# 6        JUNGLE     200   True      1       0  ...        0          0
# 7        MIDDLE     200   True      0       0  ...        0          0
# 8        BOTTOM     200   True      0       0  ...        0          0
# 9       UTILITY     200   True      0       0  ...        0          0
# 10          TOP     200   True      7       6  ...        0          0
# 11       JUNGLE     200   True     13       6  ...        0          0
# 12       MIDDLE     200   True     10       4  ...        0          0
# 13       BOTTOM     200   True      8       5  ...        0          0
# 14      UTILITY     200   True      7       2  ...        0          0
# 15          TOP     200  False     10      11  ...        0          1
# 16       JUNGLE     200  False     19       9  ...        0          0
# 17       MIDDLE     200  False      7      10  ...        0          1
# 18       BOTTOM     200  False      4       8  ...        0          1
# 19      UTILITY     200  False      4      16  ...        0          0
# 20      UTILITY     200   True      0       4  ...        0          0
# 21       MIDDLE     200   True      9       4  ...        0          0
# 22          TOP     200   True     10       1  ...        0          0
# 23       BOTTOM     200   True     10       2  ...        0          0
# 24       JUNGLE     200   True      9       1  ...        0          0
#
#     LaneTowerTime                                bans  \
# 0         1093499  7|53|60|350|222|30|238|114|412|234
# 1               0  7|53|60|350|222|30|238|114|412|234
# 2          922816  7|53|60|350|222|30|238|114|412|234
# 3         1050013  7|53|60|350|222|30|238|114|412|234
# 4               0  7|53|60|350|222|30|238|114|412|234
# 5               0     41|91|53|25|38|119|45|76|24|902
# 6               0     41|91|53|25|38|119|45|76|24|902
# 7               0     41|91|53|25|38|119|45|76|24|902
# 8               0     41|91|53|25|38|119|45|76|24|902
# 9               0     41|91|53|25|38|119|45|76|24|902
# 10         722445       53|64|79|45|136|39|76|221|555
# 11              0       53|64|79|45|136|39|76|221|555
# 12         709728       53|64|79|45|136|39|76|221|555
# 13         723701       53|64|79|45|136|39|76|221|555
# 14              0       53|64|79|45|136|39|76|221|555
# 15         842159   7|126|360|64|350|45|136|76|24|498
# 16              0   7|126|360|64|350|45|136|76|24|498
# 17         739876   7|126|360|64|350|45|136|76|24|498
# 18        1045785   7|126|360|64|350|45|136|76|24|498
# 19              0   7|126|360|64|350|45|136|76|24|498
# 20         872346     111|62|517|45|238|114|79|81|902
# 21         771400     111|62|517|45|238|114|79|81|902
# 22              0     111|62|517|45|238|114|79|81|902
# 23         848103     111|62|517|45|238|114|79|81|902
# 24              0     111|62|517|45|238|114|79|81|902
# 0         1587983  7|53|60|350|222|30|238|114|412|234
# 1               0  7|53|60|350|222|30|238|114|412|234
# 2          878952  7|53|60|350|222|30|238|114|412|234
# 3          782291  7|53|60|350|222|30|238|114|412|234
# 4               0  7|53|60|350|222|30|238|114|412|234
# 5               0     41|91|53|25|38|119|45|76|24|902
# 6               0     41|91|53|25|38|119|45|76|24|902
# 7               0     41|91|53|25|38|119|45|76|24|902
# 8               0     41|91|53|25|38|119|45|76|24|902
# 9               0     41|91|53|25|38|119|45|76|24|902
# 10              0       53|64|79|45|136|39|76|221|555
# 11              0       53|64|79|45|136|39|76|221|555
# 12              0       53|64|79|45|136|39|76|221|555
# 13              0       53|64|79|45|136|39|76|221|555
# 14              0       53|64|79|45|136|39|76|221|555
# 15        1283740   7|126|360|64|350|45|136|76|24|498
# 16              0   7|126|360|64|350|45|136|76|24|498
# 17        1217621   7|126|360|64|350|45|136|76|24|498
# 18         952750   7|126|360|64|350|45|136|76|24|498
# 19              0   7|126|360|64|350|45|136|76|24|498
# 20              0     111|62|517|45|238|114|79|81|902
# 21              0     111|62|517|45|238|114|79|81|902
# 22              0     111|62|517|45|238|114|79|81|902
# 23              0     111|62|517|45|238|114|79|81|902
# 24              0     111|62|517|45|238|114|79|81|902
#
#                                              killerId  \
# 0   9|3|3|8|3|3|7|1|3|9|8|9|1|2|2|3|7|2|3|6|2|6|2|...
# 1   9|3|3|8|3|3|7|1|3|9|8|9|1|2|2|3|7|2|3|6|2|6|2|...
# 2   9|3|3|8|3|3|7|1|3|9|8|9|1|2|2|3|7|2|3|6|2|6|2|...
# 3   9|3|3|8|3|3|7|1|3|9|8|9|1|2|2|3|7|2|3|6|2|6|2|...
# 4   9|3|3|8|3|3|7|1|3|9|8|9|1|2|2|3|7|2|3|6|2|6|2|...
# 5                                                   7
# 6                                                   7
# 7                                                   7
# 8                                                   7
# 9                                                   7
# 10  9|2|7|8|9|10|10|10|9|6|0|10|9|4|7|6|2|10|2|6|1...
# 11  9|2|7|8|9|10|10|10|9|6|0|10|9|4|7|6|2|10|2|6|1...
# 12  9|2|7|8|9|10|10|10|9|6|0|10|9|4|7|6|2|10|2|6|1...
# 13  9|2|7|8|9|10|10|10|9|6|0|10|9|4|7|6|2|10|2|6|1...
# 14  9|2|7|8|9|10|10|10|9|6|0|10|9|4|7|6|2|10|2|6|1...
# 15  7|7|2|6|2|10|7|2|4|3|2|8|9|10|7|10|1|3|7|7|2|8...
# 16  7|7|2|6|2|10|7|2|4|3|2|8|9|10|7|10|1|3|7|7|2|8...
# 17  7|7|2|6|2|10|7|2|4|3|2|8|9|10|7|10|1|3|7|7|2|8...
# 18  7|7|2|6|2|10|7|2|4|3|2|8|9|10|7|10|1|3|7|7|2|8...
# 19  7|7|2|6|2|10|7|2|4|3|2|8|9|10|7|10|1|3|7|7|2|8...
# 20  1|10|10|10|10|9|8|4|9|5|10|9|9|7|8|8|9|5|4|7|7...
# 21  1|10|10|10|10|9|8|4|9|5|10|9|9|7|8|8|9|5|4|7|7...
# 22  1|10|10|10|10|9|8|4|9|5|10|9|9|7|8|8|9|5|4|7|7...
# 23  1|10|10|10|10|9|8|4|9|5|10|9|9|7|8|8|9|5|4|7|7...
# 24  1|10|10|10|10|9|8|4|9|5|10|9|9|7|8|8|9|5|4|7|7...
# 0   9|3|3|8|3|3|7|1|3|9|8|9|1|2|2|3|7|2|3|6|2|6|2|...
# 1   9|3|3|8|3|3|7|1|3|9|8|9|1|2|2|3|7|2|3|6|2|6|2|...
# 2   9|3|3|8|3|3|7|1|3|9|8|9|1|2|2|3|7|2|3|6|2|6|2|...
# 3   9|3|3|8|3|3|7|1|3|9|8|9|1|2|2|3|7|2|3|6|2|6|2|...
# 4   9|3|3|8|3|3|7|1|3|9|8|9|1|2|2|3|7|2|3|6|2|6|2|...
# 5                                                   7
# 6                                                   7
# 7                                                   7
# 8                                                   7
# 9                                                   7
# 10  9|2|7|8|9|10|10|10|9|6|0|10|9|4|7|6|2|10|2|6|1...
# 11  9|2|7|8|9|10|10|10|9|6|0|10|9|4|7|6|2|10|2|6|1...
# 12  9|2|7|8|9|10|10|10|9|6|0|10|9|4|7|6|2|10|2|6|1...
# 13  9|2|7|8|9|10|10|10|9|6|0|10|9|4|7|6|2|10|2|6|1...
# 14  9|2|7|8|9|10|10|10|9|6|0|10|9|4|7|6|2|10|2|6|1...
# 15  7|7|2|6|2|10|7|2|4|3|2|8|9|10|7|10|1|3|7|7|2|8...
# 16  7|7|2|6|2|10|7|2|4|3|2|8|9|10|7|10|1|3|7|7|2|8...
# 17  7|7|2|6|2|10|7|2|4|3|2|8|9|10|7|10|1|3|7|7|2|8...
# 18  7|7|2|6|2|10|7|2|4|3|2|8|9|10|7|10|1|3|7|7|2|8...
# 19  7|7|2|6|2|10|7|2|4|3|2|8|9|10|7|10|1|3|7|7|2|8...
# 20  1|10|10|10|10|9|8|4|9|5|10|9|9|7|8|8|9|5|4|7|7...
# 21  1|10|10|10|10|9|8|4|9|5|10|9|9|7|8|8|9|5|4|7|7...
# 22  1|10|10|10|10|9|8|4|9|5|10|9|9|7|8|8|9|5|4|7|7...
# 23  1|10|10|10|10|9|8|4|9|5|10|9|9|7|8|8|9|5|4|7|7...
# 24  1|10|10|10|10|9|8|4|9|5|10|9|9|7|8|8|9|5|4|7|7...
#
#                                              victimId  \
# 0   5|7|10|2|8|8|2|7|10|3|5|2|6|8|8|7|3|10|7|1|9|5...
# 1   5|7|10|2|8|8|2|7|10|3|5|2|6|8|8|7|3|10|7|1|9|5...
# 2   5|7|10|2|8|8|2|7|10|3|5|2|6|8|8|7|3|10|7|1|9|5...
# 3   5|7|10|2|8|8|2|7|10|3|5|2|6|8|8|7|3|10|7|1|9|5...
# 4   5|7|10|2|8|8|2|7|10|3|5|2|6|8|8|7|3|10|7|1|9|5...
# 5                                                   2
# 6                                                   2
# 7                                                   2
# 8                                                   2
# 9                                                   2
# 10  5|7|2|3|5|4|2|5|4|1|6|5|4|9|3|1|6|5|8|3|6|2|1|...
# 11  5|7|2|3|5|4|2|5|4|1|6|5|4|9|3|1|6|5|8|3|6|2|1|...
# 12  5|7|2|3|5|4|2|5|4|1|6|5|4|9|3|1|6|5|8|3|6|2|1|...
# 13  5|7|2|3|5|4|2|5|4|1|6|5|4|9|3|1|6|5|8|3|6|2|1|...
# 14  5|7|2|3|5|4|2|5|4|1|6|5|4|9|3|1|6|5|8|3|6|2|1|...
# 15  3|2|8|1|10|5|1|10|9|6|8|2|4|5|3|2|6|8|1|1|6|3|...
# 16  3|2|8|1|10|5|1|10|9|6|8|2|4|5|3|2|6|8|1|1|6|3|...
# 17  3|2|8|1|10|5|1|10|9|6|8|2|4|5|3|2|6|8|1|1|6|3|...
# 18  3|2|8|1|10|5|1|10|9|6|8|2|4|5|3|2|6|8|1|1|6|3|...
# 19  3|2|8|1|10|5|1|10|9|6|8|2|4|5|3|2|6|8|1|1|6|3|...
# 20  6|3|1|2|1|3|5|7|1|6|3|4|2|5|2|1|2|6|9|4|5|7|1|...
# 21  6|3|1|2|1|3|5|7|1|6|3|4|2|5|2|1|2|6|9|4|5|7|1|...
# 22  6|3|1|2|1|3|5|7|1|6|3|4|2|5|2|1|2|6|9|4|5|7|1|...
# 23  6|3|1|2|1|3|5|7|1|6|3|4|2|5|2|1|2|6|9|4|5|7|1|...
# 24  6|3|1|2|1|3|5|7|1|6|3|4|2|5|2|1|2|6|9|4|5|7|1|...
# 0   5|7|10|2|8|8|2|7|10|3|5|2|6|8|8|7|3|10|7|1|9|5...
# 1   5|7|10|2|8|8|2|7|10|3|5|2|6|8|8|7|3|10|7|1|9|5...
# 2   5|7|10|2|8|8|2|7|10|3|5|2|6|8|8|7|3|10|7|1|9|5...
# 3   5|7|10|2|8|8|2|7|10|3|5|2|6|8|8|7|3|10|7|1|9|5...
# 4   5|7|10|2|8|8|2|7|10|3|5|2|6|8|8|7|3|10|7|1|9|5...
# 5                                                   2
# 6                                                   2
# 7                                                   2
# 8                                                   2
# 9                                                   2
# 10  5|7|2|3|5|4|2|5|4|1|6|5|4|9|3|1|6|5|8|3|6|2|1|...
# 11  5|7|2|3|5|4|2|5|4|1|6|5|4|9|3|1|6|5|8|3|6|2|1|...
# 12  5|7|2|3|5|4|2|5|4|1|6|5|4|9|3|1|6|5|8|3|6|2|1|...
# 13  5|7|2|3|5|4|2|5|4|1|6|5|4|9|3|1|6|5|8|3|6|2|1|...
# 14  5|7|2|3|5|4|2|5|4|1|6|5|4|9|3|1|6|5|8|3|6|2|1|...
# 15  3|2|8|1|10|5|1|10|9|6|8|2|4|5|3|2|6|8|1|1|6|3|...
# 16  3|2|8|1|10|5|1|10|9|6|8|2|4|5|3|2|6|8|1|1|6|3|...
# 17  3|2|8|1|10|5|1|10|9|6|8|2|4|5|3|2|6|8|1|1|6|3|...
# 18  3|2|8|1|10|5|1|10|9|6|8|2|4|5|3|2|6|8|1|1|6|3|...
# 19  3|2|8|1|10|5|1|10|9|6|8|2|4|5|3|2|6|8|1|1|6|3|...
# 20  6|3|1|2|1|3|5|7|1|6|3|4|2|5|2|1|2|6|9|4|5|7|1|...
# 21  6|3|1|2|1|3|5|7|1|6|3|4|2|5|2|1|2|6|9|4|5|7|1|...
# 22  6|3|1|2|1|3|5|7|1|6|3|4|2|5|2|1|2|6|9|4|5|7|1|...
# 23  6|3|1|2|1|3|5|7|1|6|3|4|2|5|2|1|2|6|9|4|5|7|1|...
# 24  6|3|1|2|1|3|5|7|1|6|3|4|2|5|2|1|2|6|9|4|5|7|1|...
#
#                                              assistId   G15 enemy_champ  \
# 0   7,10|2|2|7,10|5|2||2,3|2,5|7,8,10|7,9,10|7,8,1...  4378         Jax
# 1   7,10|2|2|7,10|5|2||2,3|2,5|7,8,10|7,9,10|7,8,1...  6446      LeeSin
# 2   7,10|2|2|7,10|5|2||2,3|2,5|7,8,10|7,9,10|7,8,1...  6415        Yone
# 3   7,10|2|2|7,10|5|2||2,3|2,5|7,8,10|7,9,10|7,8,1...  5489       Ziggs
# 4   7,10|2|2|7,10|5|2||2,3|2,5|7,8,10|7,9,10|7,8,1...  3281       Rakan
# 5                                              6,9,10     0        Ryze
# 6                                              6,9,10     0        Nunu
# 7                                              6,9,10     0       Yasuo
# 8                                              6,9,10     0       Sivir
# 9                                              6,9,10     0      Thresh
# 10  10|3|8|7|10|9|7,8|7||||9|10||8||1||1,3|7|2|6|8...  4367    Renekton
# 11  10|3|8|7|10|9|7,8|7||||9|10||8||1||1,3|7|2|6|8...  5315     Karthus
# 12  10|3|8|7|10|9|7,8|7||||9|10||8||1||1,3|7|2|6|8...  4194    Pantheon
# 13  10|3|8|7|10|9|7,8|7||||9|10||8||1||1,3|7|2|6|8...  5393       Xayah
# 14  10|3|8|7|10|9|7,8|7||||9|10||8||1||1,3|7|2|6|8...  2720         Zoe
# 15  8|8|3||4,5|9|6|4,5|2,5||3|||7,9|8|7,8||5|10|6,...  4967      Kennen
# 16  8|8|3||4,5|9|6|4,5|2,5||3|||7,9|8|7,8||5|10|6,...  5002       Elise
# 17  8|8|3||4,5|9|6|4,5|2,5||3|||7,9|8|7,8||5|10|6,...  5546    Nocturne
# 18  8|8|3||4,5|9|6|4,5|2,5||3|||7,9|8|7,8||5|10|6,...  5243       Kaisa
# 19  8|8|3||4,5|9|6|4,5|2,5||3|||7,9|8|7,8||5|10|6,...  3079    Pantheon
# 20  3,5|9|9|8|6,9|6,10||2,3|10|3,4|7|10|7,10|9,10|...  4709        Jhin
# 21  3,5|9|9|8|6,9|6,10||2,3|10|3,4|7|10|7,10|9,10|...  3796      KSante
# 22  3,5|9|9|8|6,9|6,10||2,3|10|3,4|7|10|7,10|9,10|...  3168      Maokai
# 23  3,5|9|9|8|6,9|6,10||2,3|10|3,4|7|10|7,10|9,10|...  5116        Yone
# 24  3,5|9|9|8|6,9|6,10||2,3|10|3,4|7|10|7,10|9,10|...  4855    JarvanIV
# 0   7,10|2|2|7,10|5|2||2,3|2,5|7,8,10|7,9,10|7,8,1...  5471        Kled
# 1   7,10|2|2|7,10|5|2||2,3|2,5|7,8,10|7,9,10|7,8,1...  4923       Sylas
# 2   7,10|2|2|7,10|5|2||2,3|2,5|7,8,10|7,9,10|7,8,1...  5241        Sett
# 3   7,10|2|2|7,10|5|2||2,3|2,5|7,8,10|7,9,10|7,8,1...  5954       Xayah
# 4   7,10|2|2|7,10|5|2||2,3|2,5|7,8,10|7,9,10|7,8,1...  3157    Nautilus
# 5                                              6,9,10     0      Irelia
# 6                                              6,9,10     0     Karthus
# 7                                              6,9,10     0     Leblanc
# 8                                              6,9,10     0    Aphelios
# 9                                              6,9,10     0        Pyke
# 10  10|3|8|7|10|9|7,8|7||||9|10||8||1||1,3|7|2|6|8...  7280        Sion
# 11  10|3|8|7|10|9|7,8|7||||9|10||8||1||1,3|7|2|6|8...  8120     Sejuani
# 12  10|3|8|7|10|9|7,8|7||||9|10||8||1||1,3|7|2|6|8...  6439       Yasuo
# 13  10|3|8|7|10|9|7,8|7||||9|10||8||1||1,3|7|2|6|8...  7245        Jinx
# 14  10|3|8|7|10|9|7,8|7||||9|10||8||1||1,3|7|2|6|8...  5400       Milio
# 15  8|8|3||4,5|9|6|4,5|2,5||3|||7,9|8|7,8||5|10|6,...  4978      Irelia
# 16  8|8|3||4,5|9|6|4,5|2,5||3|||7,9|8|7,8||5|10|6,...  7163  MonkeyKing
# 17  8|8|3||4,5|9|6|4,5|2,5||3|||7,9|8|7,8||5|10|6,...  7132        Fizz
# 18  8|8|3||4,5|9|6|4,5|2,5||3|||7,9|8|7,8||5|10|6,...  5035        Zeri
# 19  8|8|3||4,5|9|6|4,5|2,5||3|||7,9|8|7,8||5|10|6,...  4131        Pyke
# 20  3,5|9|9|8|6,9|6,10||2,3|10|3,4|7|10|7,10|9,10|...  3169       Leona
# 21  3,5|9|9|8|6,9|6,10||2,3|10|3,4|7|10|7,10|9,10|...  5854        Ahri
# 22  3,5|9|9|8|6,9|6,10||2,3|10|3,4|7|10|7,10|9,10|...  6336        Shen
# 23  3,5|9|9|8|6,9|6,10||2,3|10|3,4|7|10|7,10|9,10|...  6039        Jinx
# 24  3,5|9|9|8|6,9|6,10||2,3|10|3,4|7|10|7,10|9,10|...  7358      LeeSin
#
#    enemy_G15
# 0       5471
# 1       4923
# 2       5241
# 3       5954
# 4       3157
# 5          0
# 6          0
# 7          0
# 8          0
# 9          0
# 10      7280
# 11      8120
# 12      6439
# 13      7245
# 14      5400
# 15      4978
# 16      7163
# 17      7132
# 18      5035
# 19      4131
# 20      6039
# 21      6336
# 22      3169
# 23      5854
# 24      7358
# 0       4378
# 1       6446
# 2       6415
# 3       5489
# 4       3281
# 5          0
# 6          0
# 7          0
# 8          0
# 9          0
# 10      4367
# 11      5315
# 12      4194
# 13      5393
# 14      2720
# 15      4967
# 16      5002
# 17      5546
# 18      5243
# 19      3079
# 20      3168
# 21      5116
# 22      3796
# 23      4709
# 24      4855
#
# [50 rows x 23 columns]

# %% [markdown]
# # champion_kill -> kill_log
#
# # BUILDING_KILL - > tower_log

# %% [markdown]
# tower_log = BUILDING_KILL

# %%
tmp = df[:5]

# %%
tmp_list = list(map(lambda x: x['events'],tmp.iloc[0].timelines['info']['frames']))

# %%
event_list = [element for array in tmp_list for element in array]

# %%
tower_log = list(filter(lambda x: x['type'] == 'BUILDING_KILL' ,event_list))

# %%
tower_log = list(map(lambda x: list(filter(lambda z:z['type']=='BUILDING_KILL',x['events'])),tmp.iloc[0].timelines['info']['frames']))

# %%
tower_log = [element for array in tower_log for element in array]

# %%
tower_log[-1]
# Out:
# {'assistingParticipantIds': [3],
#  'bounty': 0,
#  'buildingType': 'TOWER_BUILDING',
#  'killerId': 0,
#  'laneType': 'MID_LANE',
#  'position': {'x': 13052, 'y': 12612},
#  'teamId': 200,
#  'timestamp': 1890884,
#  'towerType': 'NEXUS_TURRET',
#  'type': 'BUILDING_KILL'}

# %%
Firsttower -> 어떤 라인이 부셔졌는지 (레드팀의 bot라인이 첫 타워킬을 먹혔네요) -> (첫 타워골드를 블루팀이 먹었다.)

tower ->각팀별로 1차타워가 부셔진 라인이 어딘지 (레드 봇, 레드 미드, 블루 봇, 레드 탑, 블루 탑, 레드 미드 2차타워, 블루 1차 레드 2차 봇, )

# %%
df_creates = []
for i in range(len(df)):
    match = df.iloc[i].matches['info']['participants']
    for j in range(len(match)):
        match_id = df.iloc[i].match_id
        game_duration = df.iloc[i].matches['info']['gameDuration']
        game_version = df.iloc[i].matches['info']['gameVersion']
        try:
            riotIdGameName = match[j]['riotIdGameName']
        except:
            riotIdGameName = ''
        try:
            riotIdTagline = match[j]['riotIdTagline']
        except:
            riotIdTagline = ''
        summoner_level = match[j]['summonerLevel']
        participants_id = match[j]['participantId']
        champion_name = match[j]['championName']
        champ_experience = match[j]['champExperience']
        team_position = match[j]['teamPosition']
        team_id = match[j]['teamId']
        win = match[j]['win']
        kills = match[j]['kills']
        deaths = match[j]['deaths']
        assists = match[j]['assists']
        total_damage_dealt = match[j]['totalDamageDealtToChampions']
        total_damage_taken = match[j]['totalDamageTaken']
        df_creates.append([match_id,game_duration,game_version,riotIdGameName,riotIdTagline,summoner_level,participants_id,
                          champion_name,champ_experience,team_position,team_id,win,kills,deaths,assists,total_damage_dealt,total_damage_taken])
columns =['matchId', 'gameDuration', 'gameVersion', 'riotIdGameName','riotIdTagline', 
           'summonerLevel', 'participantId', 'championName', 'champExperience', 
           'teamPosition', 'teamId', 'win', 'kills', 'deaths', 'assists', 'totalDamageDealtToChampions', 'totalDamageTaken']
df2 = pd.DataFrame(df_creates , columns = columns)

# %%
df2
# Out:
#            matchId  gameDuration     gameVersion riotIdGameName riotIdTagline  \
# 0    KR_6791383560          1902  13.22.541.9804
# 1    KR_6791383560          1902  13.22.541.9804
# 2    KR_6791383560          1902  13.22.541.9804
# 3    KR_6791383560          1902  13.22.541.9804
# 4    KR_6791383560          1902  13.22.541.9804
# ..             ...           ...             ...            ...           ...
# 353  KR_6828405837          1515  13.23.544.5515           웅고메드           KR1
# 354  KR_6828405837          1515  13.23.544.5515        왜 이게 되지           KR1
# 355  KR_6828405837          1515  13.23.544.5515            관통맨           KR1
# 356  KR_6828405837          1515  13.23.544.5515            각똘똘           KR1
# 357  KR_6828405837          1515  13.23.544.5515         수진이잘해요           KR1
#
#      summonerLevel  participantId championName  champExperience teamPosition  \
# 0              212              1       Darius            14334          TOP
# 1              417              2     MasterYi            18637       JUNGLE
# 2              102              3        Akali            12999       MIDDLE
# 3              344              4     Tristana            14960       BOTTOM
# 4              212              5      Morgana            13029      UTILITY
# ..             ...            ...          ...              ...          ...
# 353            173              6          Zac             8420          TOP
# 354            139              7        Viego             9548       JUNGLE
# 355            575              8        Galio            10323       MIDDLE
# 356            205              9       Ezreal             9722       BOTTOM
# 357            122             10       Kennen             8637      UTILITY
#
#      teamId    win  kills  deaths  assists  totalDamageDealtToChampions  \
# 0       100   True      3       9        2                        16392
# 1       100   True     10       7        6                        35210
# 2       100   True      3      11        2                        21591
# 3       100   True     12       4        5                        23112
# 4       100   True      2       3       12                        10780
# ..      ...    ...    ...     ...      ...                          ...
# 353     200  False      8      10        2                        12295
# 354     200  False      6       7        7                        15125
# 355     200  False      1       8        9                        13824
# 356     200  False      2       5        8                        15735
# 357     200  False      5       7        8                        16690
#
#      totalDamageTaken
# 0               31214
# 1               33148
# 2               34111
# 3               18695
# 4               13611
# ..                ...
# 353             33854
# 354             25607
# 355             25376
# 356             18770
# 357             21197
#
# [358 rows x 17 columns]
